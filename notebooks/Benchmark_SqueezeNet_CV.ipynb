# %%
# Import necessary libraries
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Subset, DataLoader, Dataset
from torchvision import datasets, transforms, models
from torchvision.models import efficientnet_b0
from torchvision.models.efficientnet import SqueezeExcitation
import matplotlib.pyplot as plt
import multiprocessing
import numpy as np
from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score,  roc_auc_score, 
    cohen_kappa_score, matthews_corrcoef, confusion_matrix, average_precision_score, fbeta_score,
    precision_recall_curve, balanced_accuracy_score)
import pandas as pd
from sklearn.utils import shuffle
import random
import albumentations as A
from albumentations.pytorch import ToTensorV2
import pandas as pd
import torch_optimizer
import cv2
from skimage import measure
from torchvision.utils import make_grid
# %matplotlib inline
# Out:
# /home/pxk409/Skin_EfficientNet/GCCcore-11.3.0/lib/python3.10/site-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 1.4.23 (you have 1.4.21). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
# Check for GPU availability
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# !nvidia-smi
# Out:
# Thu Dec 19 14:53:58 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.54.03              Driver Version: 535.54.03    CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-PCIE-32GB           On  | 00000000:3B:00.0 Off |                    0 |
# | N/A   27C    P0              22W / 250W |      4MiB / 32768MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
file_name = "Benchmark_SqueezeNet_CV"

# %%
import os

# Define directories of where the datasets reside
base_dir = '/home/pxk409/skin_lesions_13k'

# Define directories of where the training, validation and test sets reside
train_dir = os.path.join(base_dir, 'train')
test_dir = os.path.join(base_dir, 'test')

# Define directories of where the benign and malignant images reside
train_benign_dir = os.path.join(base_dir, 'train/benign')
train_malignant_dir = os.path.join(base_dir, 'train/malignant')
test_benign_dir = os.path.join(base_dir, 'test/benign')
test_malignant_dir = os.path.join(base_dir, 'test/malignant')

# %%
# Let's check the number of images in each set
print('Total training benign images:', len(os.listdir(train_benign_dir)))
print('Total training malignant images:', len(os.listdir(train_malignant_dir)))
print('Total test benign images:', len(os.listdir(test_benign_dir)))
print('Total test malignant images:', len(os.listdir(test_malignant_dir)))
# Out:
# Total training benign images: 5000
# Total training malignant images: 5000
# Total test benign images: 1500
# Total test malignant images: 1500

# %%
# Load full dataset
full_dataset = datasets.ImageFolder(root=train_dir)

# Extract labels from the dataset
#labels = [label for _, label in full_dataset.samples]

# Stratified split (80% train, 20% validation)
#split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=123456)
#train_idx, val_idx = next(split.split(np.zeros(len(labels)), labels))

# Create training and validation subsets
#train_dataset = Subset(full_dataset, train_idx)
#val_dataset = Subset(full_dataset, val_idx)

#print(f"Training set: {len(train_idx)} samples")
#print(f"Validation set: {len(val_idx)} samples")

# Count the number of samples per class in each split
#train_classes = [full_dataset.targets[idx] for idx in train_dataset.indices]
#val_classes = [full_dataset.targets[idx] for idx in val_dataset.indices]

#print(f"Training set class counts: {np.bincount(train_classes)}")
#print(f"Validation set class counts: {np.bincount(val_classes)}")

# %%
# Custom transform to integrate Albumentations with PyTorch
class AlbumentationsTransform:
    def __init__(self, augmentations):
        self.augmentations = A.Compose(augmentations)

    def __call__(self, image):
        image = np.array(image)  # Convert PIL Image to NumPy array
        augmented = self.augmentations(image=image)
        return augmented["image"]

# Simple augmentations for training
simple_transform = AlbumentationsTransform([
    A.RandomResizedCrop(height=224, width=224, scale=(0.8, 1.0), p=1.0),  # Random crop and resize
    A.HorizontalFlip(p=0.5),  # Horizontal flip
    A.VerticalFlip(p=0.5),  # Vertical flip
    #A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1, p=0.5),  # Color jitter
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  # Normalize to match pre-trained model
    ToTensorV2(),  # Convert to PyTorch tensor and ensure dtype=torch.float32
])


# Use AlbumentationsTransform directly in the loaders for consistency
train_transform = simple_transform

# Albumentations augmentations for validation and test
albumentations_val_test_transform = AlbumentationsTransform([
    A.Resize(height=224, width=224),  # Resize to EfficientNet input size
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  # Normalize to match pre-trained model
    ToTensorV2()  # Convert to PyTorch tensor
])

test_val_transform = albumentations_val_test_transform

# %%
class TransformDataset(Dataset):
    def __init__(self, dataset, transform):
        """
        Args:
            dataset: Original dataset (e.g., Subset of ImageFolder).
            transform: Transform to be applied to the images in the dataset.
        """
        self.dataset = dataset
        self.transform = transform

    def __getitem__(self, idx):
        image, label = self.dataset[idx]
        if self.transform:
            image = self.transform(image)
        return image, label

    def __len__(self):
        return len(self.dataset)

# %%
# Wrap subsets with the respective transforms
#train_dataset = TransformDataset(train_dataset, train_transform)
#val_dataset = TransformDataset(val_dataset, test_val_transform)

# %%
# Load and prepare the test dataset
#test_dataset = datasets.ImageFolder(root=test_dir, transform=test_val_transform)
test_dataset = datasets.ImageFolder(root=test_dir)
test_dataset = TransformDataset(test_dataset, test_val_transform)

# %%
# Create data loaders
batch_size = 64
#num_cpus = multiprocessing.cpu_count()  # Use all CPU cores
#print(f"Number of CPU cores: {num_cpus}")
#num_workers = 16


#train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
#val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
#train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=True)
#val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=True)
#test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=True)

# %%
def initialize_model():
    # Load pre-trained SqueezeNet
    model = models.squeezenet1_0(weights=models.SqueezeNet1_0_Weights.DEFAULT)

    # Freeze the convolutional part (feature extractor)
    for param in model.features.parameters():
        param.requires_grad = False

    # Replace the classifier with a custom one
    # SqueezeNet's classifier is a Conv2d layer followed by adaptive average pooling
    model.classifier = nn.Sequential(
        nn.Dropout(p=0.5),
        nn.Conv2d(512, 2, kernel_size=1),  # Replace for binary classification
        nn.AdaptiveAvgPool2d((1, 1))  # Ensures output size is (N, 2, 1, 1)
    )

    # Ensure the classifier remains trainable
    for param in model.classifier.parameters():
        param.requires_grad = True

    # Move model to device
    model = model.to(device)
    return model

model = initialize_model()

# %%
# Function to count trainable and non-trainable parameters
def count_trainable_non_trainable_parameters(model):
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    non_trainable = sum(p.numel() for p in model.parameters() if not p.requires_grad)
    return trainable, non_trainable

# Count parameters in the convolutional part
conv_trainable, conv_non_trainable = count_trainable_non_trainable_parameters(model.features)
print(f"Convolutional part (features):\n"
      f"  Trainable parameters: {conv_trainable:,}\n"
      f"  Non-trainable parameters: {conv_non_trainable:,}")

# Count parameters in the classifier part
classifier_trainable, classifier_non_trainable = count_trainable_non_trainable_parameters(model.classifier)
print(f"Classifier part:\n"
      f"  Trainable parameters: {classifier_trainable:,}\n"
      f"  Non-trainable parameters: {classifier_non_trainable:,}")

# Count parameters in the entire model
total_trainable, total_non_trainable = count_trainable_non_trainable_parameters(model)
print(f"Whole model:\n"
      f"  Trainable parameters: {total_trainable:,}\n"
      f"  Non-trainable parameters: {total_non_trainable:,}")
# Out:
# Convolutional part (features):
#   Trainable parameters: 0
#   Non-trainable parameters: 735,424
# Classifier part:
#   Trainable parameters: 1,026
#   Non-trainable parameters: 0
# Whole model:
#   Trainable parameters: 1,026
#   Non-trainable parameters: 735,424

# %%
# Early Stopping
class EarlyStopping:
    def __init__(self, patience, delta, path):
        """
        Args:
            patience (int): Number of epochs to wait after last improvement.
            delta (float): Minimum change in monitored metric to qualify as an improvement.
            path (str): Path to save the best model.
        """
        self.patience = patience
        self.delta = delta
        self.path = path
        self.counter = 0
        self.best_score = None
        self.early_stop = False

    def __call__(self, val_loss, model):
        score = -val_loss  # Early stopping is based on minimizing validation loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f"EarlyStopping counter: {self.counter} out of {self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        """Saves model when validation loss decreases."""
        print(f"Validation loss decreased. Saving model to {self.path}")
        torch.save(model.state_dict(), self.path)


# Set the path for saving best_model.pth
#current_dir = os.getcwd()
#model_save_path = os.path.join(current_dir, 'best_model2.pth')

# Initialize EarlyStopping
#early_stopping = EarlyStopping(patience=5, delta=0.001, path=model_save_path)

# %%
# Helper function to evaluate a dataset
def evaluate_model(model, data_loader, device):
    model.eval()  # Set model to evaluation mode
    all_labels = []
    all_preds = []
    all_probs = []

    with torch.no_grad():
        for images, labels in data_loader:
            images, labels = images.to(device), labels.to(device)

            # Forward pass
            outputs = model(images)
            probs = torch.softmax(outputs, dim=1)[:, 1]  # Probabilities for the positive class
            _, preds = torch.max(outputs, 1)

            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())

    return np.array(all_labels), np.array(all_preds), np.array(all_probs)

# Helper function to calculate selected metrics
def calculate_metrics(labels, preds, probs):
    accuracy = accuracy_score(labels, preds)
    precision = precision_score(labels, preds)
    recall = recall_score(labels, preds)
    f1 = f1_score(labels, preds)
    f2 = fbeta_score(labels, preds, beta=2)
    auc = roc_auc_score(labels, probs)
    specificity = recall_score(labels, preds, pos_label=0)
    npv = precision_score(labels, preds, pos_label=0)

    return recall, precision, accuracy, f1, f2, auc, specificity, npv

# %%
# Training loop with 5-fold cross-validation
cv_results = []
cv_metrics = []
n_splits = 5
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=123456)

# Extract labels from the dataset
labels = [label for _, label in full_dataset.samples]

# Cross-validation loop
for fold, (train_idx, val_idx) in enumerate(skf.split(np.zeros(len(labels)), labels), 1):
    print(f"\n========== Fold {fold} ==========\n")
    
    # Create training and validation subsets for this fold
    train_dataset = Subset(full_dataset, train_idx)
    val_dataset = Subset(full_dataset, val_idx)
    
    # Apply transformations
    train_dataset = TransformDataset(train_dataset, train_transform)
    val_dataset = TransformDataset(val_dataset, test_val_transform)
    
    # Create data loaders
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    
    # Initialize model and optimizer for each fold
    model = initialize_model()
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    # EarlyStopping initialization
    early_stopping = EarlyStopping(patience=10, delta=0.0001, path=os.path.join(os.getcwd(), f"{file_name}_fold_{fold}.pth"))

    # Training loop
    num_epochs = 100
    train_losses = []
    val_losses = []
    
    for epoch in range(num_epochs):
        # Training phase
        model.train()
        train_loss = 0
        train_correct = 0
        
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            
            # Forward pass
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            train_correct += torch.sum(preds == labels)
        
        train_loss /= len(train_loader)
        train_accuracy = train_correct.double() / len(train_dataset)
        train_losses.append(train_loss)
        
        # Validation phase
        model.eval()
        val_loss = 0
        val_correct = 0
        
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                
                outputs = model(images)
                loss = criterion(outputs, labels)
                
                val_loss += loss.item()
                _, preds = torch.max(outputs, 1)
                val_correct += torch.sum(preds == labels)
        
        val_loss /= len(val_loader)
        val_accuracy = val_correct.double() / len(val_dataset)
        val_losses.append(val_loss)
        
        print(f"Epoch {epoch + 1}/{num_epochs} | "
              f"Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.4f} | "
              f"Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.4f}")
        
        # Call EarlyStopping
        early_stopping(val_loss, model)
        if early_stopping.early_stop:
            print("Early stopping triggered. Ending training.")
            break
    
    # Store results for this fold
    cv_results.append({
        "fold": fold,
        "train_loss": train_loss,
        "train_accuracy": train_accuracy.item(),
        "val_loss": val_loss,
        "val_accuracy": val_accuracy.item()
        })
        
    # Load the best model for evaluation
    model.load_state_dict(torch.load(f"{file_name}_fold_{fold}.pth", weights_only=True))

    # Evaluate on validation set
    labels, preds, probs = evaluate_model(model, val_loader, device)
    metrics = calculate_metrics(labels, preds, probs)
    recall, precision, accuracy, f1, f2, auc, specificity, npv = metrics

    # Record metrics for the fold
    cv_metrics.append({
        "Fold": fold,
        "Recall": recall,
        "Precision": precision,
        "Accuracy": accuracy,
        "F1 Score": f1,
        "F2 Score": f2,
        "AUC": auc,
        "Specificity": specificity,
        "NPV": npv,
    })

# Summarize cross-validation results
df_cv_results = pd.DataFrame(cv_results)
print("\n========== Cross-Validation Results ==========\n")
print(df_cv_results)

print("\nAverage Validation Accuracy: {:.4f}".format(df_cv_results["val_accuracy"].mean()))
# Out:
# ========== Fold 1 ==========
#
# Epoch 1/100 | Train Loss: 0.5768, Train Acc: 0.7101 | Val Loss: 0.4875, Val Acc: 0.7695
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_1.pth
# Epoch 2/100 | Train Loss: 0.5032, Train Acc: 0.7589 | Val Loss: 0.4723, Val Acc: 0.7780
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_1.pth
# Epoch 3/100 | Train Loss: 0.4859, Train Acc: 0.7668 | Val Loss: 0.4702, Val Acc: 0.7645
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_1.pth
# Epoch 4/100 | Train Loss: 0.4800, Train Acc: 0.7692 | Val Loss: 0.4537, Val Acc: 0.7830
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_1.pth
# Epoch 5/100 | Train Loss: 0.4751, Train Acc: 0.7699 | Val Loss: 0.4688, Val Acc: 0.7660
# EarlyStopping counter: 1 out of 10
# Epoch 6/100 | Train Loss: 0.4617, Train Acc: 0.7796 | Val Loss: 0.4512, Val Acc: 0.7810
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_1.pth
# Epoch 7/100 | Train Loss: 0.4689, Train Acc: 0.7745 | Val Loss: 0.4485, Val Acc: 0.7785
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_1.pth
# Epoch 8/100 | Train Loss: 0.4569, Train Acc: 0.7775 | Val Loss: 0.4455, Val Acc: 0.7910
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_1.pth
# Epoch 9/100 | Train Loss: 0.4627, Train Acc: 0.7809 | Val Loss: 0.4523, Val Acc: 0.7885
# EarlyStopping counter: 1 out of 10
# Epoch 10/100 | Train Loss: 0.4559, Train Acc: 0.7798 | Val Loss: 0.4576, Val Acc: 0.7820
# EarlyStopping counter: 2 out of 10
# Epoch 11/100 | Train Loss: 0.4592, Train Acc: 0.7781 | Val Loss: 0.4525, Val Acc: 0.7905
# EarlyStopping counter: 3 out of 10
# Epoch 12/100 | Train Loss: 0.4597, Train Acc: 0.7776 | Val Loss: 0.5152, Val Acc: 0.7520
# EarlyStopping counter: 4 out of 10
# Epoch 13/100 | Train Loss: 0.4624, Train Acc: 0.7819 | Val Loss: 0.4480, Val Acc: 0.7850
# EarlyStopping counter: 5 out of 10
# Epoch 14/100 | Train Loss: 0.4566, Train Acc: 0.7854 | Val Loss: 0.4428, Val Acc: 0.7890
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_1.pth
# Epoch 15/100 | Train Loss: 0.4571, Train Acc: 0.7805 | Val Loss: 0.4455, Val Acc: 0.7780
# EarlyStopping counter: 1 out of 10
# Epoch 16/100 | Train Loss: 0.4597, Train Acc: 0.7800 | Val Loss: 0.4432, Val Acc: 0.7930
# EarlyStopping counter: 2 out of 10
# Epoch 17/100 | Train Loss: 0.4587, Train Acc: 0.7784 | Val Loss: 0.4438, Val Acc: 0.7950
# EarlyStopping counter: 3 out of 10
# Epoch 18/100 | Train Loss: 0.4658, Train Acc: 0.7745 | Val Loss: 0.5133, Val Acc: 0.7535
# EarlyStopping counter: 4 out of 10
# Epoch 19/100 | Train Loss: 0.4647, Train Acc: 0.7769 | Val Loss: 0.4532, Val Acc: 0.7830
# EarlyStopping counter: 5 out of 10
# Epoch 20/100 | Train Loss: 0.4587, Train Acc: 0.7858 | Val Loss: 0.4813, Val Acc: 0.7735
# EarlyStopping counter: 6 out of 10
# Epoch 21/100 | Train Loss: 0.4682, Train Acc: 0.7788 | Val Loss: 0.4441, Val Acc: 0.7910
# EarlyStopping counter: 7 out of 10
# Epoch 22/100 | Train Loss: 0.4575, Train Acc: 0.7844 | Val Loss: 0.4487, Val Acc: 0.7880
# EarlyStopping counter: 8 out of 10
# Epoch 23/100 | Train Loss: 0.4608, Train Acc: 0.7811 | Val Loss: 0.4459, Val Acc: 0.7820
# EarlyStopping counter: 9 out of 10
# Epoch 24/100 | Train Loss: 0.4586, Train Acc: 0.7823 | Val Loss: 0.4505, Val Acc: 0.7790
# EarlyStopping counter: 10 out of 10
# Early stopping triggered. Ending training.
#
# ========== Fold 2 ==========
#
# Epoch 1/100 | Train Loss: 0.5828, Train Acc: 0.7104 | Val Loss: 0.5169, Val Acc: 0.7450
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_2.pth
# Epoch 2/100 | Train Loss: 0.5062, Train Acc: 0.7530 | Val Loss: 0.4899, Val Acc: 0.7655
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_2.pth
# Epoch 3/100 | Train Loss: 0.4827, Train Acc: 0.7736 | Val Loss: 0.4923, Val Acc: 0.7625
# EarlyStopping counter: 1 out of 10
# Epoch 4/100 | Train Loss: 0.4745, Train Acc: 0.7682 | Val Loss: 0.4682, Val Acc: 0.7720
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_2.pth
# Epoch 5/100 | Train Loss: 0.4633, Train Acc: 0.7770 | Val Loss: 0.4709, Val Acc: 0.7725
# EarlyStopping counter: 1 out of 10
# Epoch 6/100 | Train Loss: 0.4616, Train Acc: 0.7758 | Val Loss: 0.4750, Val Acc: 0.7675
# EarlyStopping counter: 2 out of 10
# Epoch 7/100 | Train Loss: 0.4639, Train Acc: 0.7814 | Val Loss: 0.4733, Val Acc: 0.7620
# EarlyStopping counter: 3 out of 10
# Epoch 8/100 | Train Loss: 0.4648, Train Acc: 0.7754 | Val Loss: 0.5022, Val Acc: 0.7545
# EarlyStopping counter: 4 out of 10
# Epoch 9/100 | Train Loss: 0.4537, Train Acc: 0.7839 | Val Loss: 0.4663, Val Acc: 0.7705
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_2.pth
# Epoch 10/100 | Train Loss: 0.4547, Train Acc: 0.7798 | Val Loss: 0.4769, Val Acc: 0.7710
# EarlyStopping counter: 1 out of 10
# Epoch 11/100 | Train Loss: 0.4654, Train Acc: 0.7716 | Val Loss: 0.4779, Val Acc: 0.7680
# EarlyStopping counter: 2 out of 10
# Epoch 12/100 | Train Loss: 0.4548, Train Acc: 0.7836 | Val Loss: 0.4819, Val Acc: 0.7700
# EarlyStopping counter: 3 out of 10
# Epoch 13/100 | Train Loss: 0.4610, Train Acc: 0.7774 | Val Loss: 0.4683, Val Acc: 0.7745
# EarlyStopping counter: 4 out of 10
# Epoch 14/100 | Train Loss: 0.4496, Train Acc: 0.7821 | Val Loss: 0.4686, Val Acc: 0.7725
# EarlyStopping counter: 5 out of 10
# Epoch 15/100 | Train Loss: 0.4564, Train Acc: 0.7844 | Val Loss: 0.4822, Val Acc: 0.7700
# EarlyStopping counter: 6 out of 10
# Epoch 16/100 | Train Loss: 0.4589, Train Acc: 0.7818 | Val Loss: 0.4793, Val Acc: 0.7640
# EarlyStopping counter: 7 out of 10
# Epoch 17/100 | Train Loss: 0.4549, Train Acc: 0.7845 | Val Loss: 0.4820, Val Acc: 0.7655
# EarlyStopping counter: 8 out of 10
# Epoch 18/100 | Train Loss: 0.4538, Train Acc: 0.7840 | Val Loss: 0.4742, Val Acc: 0.7705
# EarlyStopping counter: 9 out of 10
# Epoch 19/100 | Train Loss: 0.4497, Train Acc: 0.7848 | Val Loss: 0.4676, Val Acc: 0.7705
# EarlyStopping counter: 10 out of 10
# Early stopping triggered. Ending training.
#
# ========== Fold 3 ==========
#
# Epoch 1/100 | Train Loss: 0.5782, Train Acc: 0.7105 | Val Loss: 0.5239, Val Acc: 0.7490
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_3.pth
# Epoch 2/100 | Train Loss: 0.4947, Train Acc: 0.7624 | Val Loss: 0.4850, Val Acc: 0.7680
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_3.pth
# Epoch 3/100 | Train Loss: 0.4766, Train Acc: 0.7632 | Val Loss: 0.4659, Val Acc: 0.7785
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_3.pth
# Epoch 4/100 | Train Loss: 0.4747, Train Acc: 0.7692 | Val Loss: 0.4553, Val Acc: 0.7825
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_3.pth
# Epoch 5/100 | Train Loss: 0.4728, Train Acc: 0.7681 | Val Loss: 0.4669, Val Acc: 0.7765
# EarlyStopping counter: 1 out of 10
# Epoch 6/100 | Train Loss: 0.4699, Train Acc: 0.7751 | Val Loss: 0.4512, Val Acc: 0.7920
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_3.pth
# Epoch 7/100 | Train Loss: 0.4665, Train Acc: 0.7722 | Val Loss: 0.4474, Val Acc: 0.7895
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_3.pth
# Epoch 8/100 | Train Loss: 0.4637, Train Acc: 0.7796 | Val Loss: 0.4516, Val Acc: 0.7790
# EarlyStopping counter: 1 out of 10
# Epoch 9/100 | Train Loss: 0.4588, Train Acc: 0.7814 | Val Loss: 0.4665, Val Acc: 0.7780
# EarlyStopping counter: 2 out of 10
# Epoch 10/100 | Train Loss: 0.4608, Train Acc: 0.7816 | Val Loss: 0.4611, Val Acc: 0.7840
# EarlyStopping counter: 3 out of 10
# Epoch 11/100 | Train Loss: 0.4607, Train Acc: 0.7815 | Val Loss: 0.4774, Val Acc: 0.7675
# EarlyStopping counter: 4 out of 10
# Epoch 12/100 | Train Loss: 0.4591, Train Acc: 0.7834 | Val Loss: 0.4399, Val Acc: 0.7920
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_3.pth
# Epoch 13/100 | Train Loss: 0.4643, Train Acc: 0.7744 | Val Loss: 0.4641, Val Acc: 0.7740
# EarlyStopping counter: 1 out of 10
# Epoch 14/100 | Train Loss: 0.4532, Train Acc: 0.7853 | Val Loss: 0.4381, Val Acc: 0.7900
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_3.pth
# Epoch 15/100 | Train Loss: 0.4605, Train Acc: 0.7811 | Val Loss: 0.4828, Val Acc: 0.7635
# EarlyStopping counter: 1 out of 10
# Epoch 16/100 | Train Loss: 0.4576, Train Acc: 0.7799 | Val Loss: 0.4404, Val Acc: 0.7835
# EarlyStopping counter: 2 out of 10
# Epoch 17/100 | Train Loss: 0.4529, Train Acc: 0.7820 | Val Loss: 0.4436, Val Acc: 0.7870
# EarlyStopping counter: 3 out of 10
# Epoch 18/100 | Train Loss: 0.4558, Train Acc: 0.7816 | Val Loss: 0.4410, Val Acc: 0.7885
# EarlyStopping counter: 4 out of 10
# Epoch 19/100 | Train Loss: 0.4585, Train Acc: 0.7761 | Val Loss: 0.4613, Val Acc: 0.7740
# EarlyStopping counter: 5 out of 10
# Epoch 20/100 | Train Loss: 0.4583, Train Acc: 0.7829 | Val Loss: 0.4408, Val Acc: 0.7955
# EarlyStopping counter: 6 out of 10
# Epoch 21/100 | Train Loss: 0.4556, Train Acc: 0.7831 | Val Loss: 0.4559, Val Acc: 0.7830
# EarlyStopping counter: 7 out of 10
# Epoch 22/100 | Train Loss: 0.4643, Train Acc: 0.7789 | Val Loss: 0.4445, Val Acc: 0.7920
# EarlyStopping counter: 8 out of 10
# Epoch 23/100 | Train Loss: 0.4601, Train Acc: 0.7778 | Val Loss: 0.4461, Val Acc: 0.7845
# EarlyStopping counter: 9 out of 10
# Epoch 24/100 | Train Loss: 0.4539, Train Acc: 0.7834 | Val Loss: 0.4469, Val Acc: 0.7855
# EarlyStopping counter: 10 out of 10
# Early stopping triggered. Ending training.
#
# ========== Fold 4 ==========
#
# Epoch 1/100 | Train Loss: 0.5863, Train Acc: 0.7006 | Val Loss: 0.5157, Val Acc: 0.7465
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_4.pth
# Epoch 2/100 | Train Loss: 0.5006, Train Acc: 0.7510 | Val Loss: 0.4680, Val Acc: 0.7800
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_4.pth
# Epoch 3/100 | Train Loss: 0.4763, Train Acc: 0.7656 | Val Loss: 0.4910, Val Acc: 0.7655
# EarlyStopping counter: 1 out of 10
# Epoch 4/100 | Train Loss: 0.4719, Train Acc: 0.7692 | Val Loss: 0.4651, Val Acc: 0.7800
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_4.pth
# Epoch 5/100 | Train Loss: 0.4759, Train Acc: 0.7658 | Val Loss: 0.4846, Val Acc: 0.7660
# EarlyStopping counter: 1 out of 10
# Epoch 6/100 | Train Loss: 0.4610, Train Acc: 0.7785 | Val Loss: 0.4664, Val Acc: 0.7850
# EarlyStopping counter: 2 out of 10
# Epoch 7/100 | Train Loss: 0.4586, Train Acc: 0.7760 | Val Loss: 0.4601, Val Acc: 0.7840
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_4.pth
# Epoch 8/100 | Train Loss: 0.4630, Train Acc: 0.7762 | Val Loss: 0.4521, Val Acc: 0.7885
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_4.pth
# Epoch 9/100 | Train Loss: 0.4675, Train Acc: 0.7774 | Val Loss: 0.4566, Val Acc: 0.7915
# EarlyStopping counter: 1 out of 10
# Epoch 10/100 | Train Loss: 0.4544, Train Acc: 0.7826 | Val Loss: 0.4680, Val Acc: 0.7865
# EarlyStopping counter: 2 out of 10
# Epoch 11/100 | Train Loss: 0.4589, Train Acc: 0.7748 | Val Loss: 0.4717, Val Acc: 0.7725
# EarlyStopping counter: 3 out of 10
# Epoch 12/100 | Train Loss: 0.4615, Train Acc: 0.7835 | Val Loss: 0.4726, Val Acc: 0.7740
# EarlyStopping counter: 4 out of 10
# Epoch 13/100 | Train Loss: 0.4605, Train Acc: 0.7776 | Val Loss: 0.4612, Val Acc: 0.7825
# EarlyStopping counter: 5 out of 10
# Epoch 14/100 | Train Loss: 0.4607, Train Acc: 0.7795 | Val Loss: 0.4825, Val Acc: 0.7765
# EarlyStopping counter: 6 out of 10
# Epoch 15/100 | Train Loss: 0.4527, Train Acc: 0.7833 | Val Loss: 0.4638, Val Acc: 0.7865
# EarlyStopping counter: 7 out of 10
# Epoch 16/100 | Train Loss: 0.4574, Train Acc: 0.7821 | Val Loss: 0.4601, Val Acc: 0.7800
# EarlyStopping counter: 8 out of 10
# Epoch 17/100 | Train Loss: 0.4498, Train Acc: 0.7844 | Val Loss: 0.4561, Val Acc: 0.7850
# EarlyStopping counter: 9 out of 10
# Epoch 18/100 | Train Loss: 0.4665, Train Acc: 0.7759 | Val Loss: 0.4715, Val Acc: 0.7720
# EarlyStopping counter: 10 out of 10
# Early stopping triggered. Ending training.
#
# ========== Fold 5 ==========
#
# Epoch 1/100 | Train Loss: 0.5861, Train Acc: 0.7104 | Val Loss: 0.5198, Val Acc: 0.7520
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_5.pth
# Epoch 2/100 | Train Loss: 0.4932, Train Acc: 0.7570 | Val Loss: 0.4852, Val Acc: 0.7670
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_5.pth
# Epoch 3/100 | Train Loss: 0.4796, Train Acc: 0.7662 | Val Loss: 0.4940, Val Acc: 0.7695
# EarlyStopping counter: 1 out of 10
# Epoch 4/100 | Train Loss: 0.4725, Train Acc: 0.7722 | Val Loss: 0.4896, Val Acc: 0.7710
# EarlyStopping counter: 2 out of 10
# Epoch 5/100 | Train Loss: 0.4594, Train Acc: 0.7771 | Val Loss: 0.4911, Val Acc: 0.7725
# EarlyStopping counter: 3 out of 10
# Epoch 6/100 | Train Loss: 0.4657, Train Acc: 0.7760 | Val Loss: 0.4961, Val Acc: 0.7730
# EarlyStopping counter: 4 out of 10
# Epoch 7/100 | Train Loss: 0.4591, Train Acc: 0.7762 | Val Loss: 0.4790, Val Acc: 0.7760
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_5.pth
# Epoch 8/100 | Train Loss: 0.4554, Train Acc: 0.7836 | Val Loss: 0.4866, Val Acc: 0.7750
# EarlyStopping counter: 1 out of 10
# Epoch 9/100 | Train Loss: 0.4654, Train Acc: 0.7790 | Val Loss: 0.4899, Val Acc: 0.7825
# EarlyStopping counter: 2 out of 10
# Epoch 10/100 | Train Loss: 0.4587, Train Acc: 0.7809 | Val Loss: 0.4769, Val Acc: 0.7750
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_5.pth
# Epoch 11/100 | Train Loss: 0.4548, Train Acc: 0.7860 | Val Loss: 0.4899, Val Acc: 0.7790
# EarlyStopping counter: 1 out of 10
# Epoch 12/100 | Train Loss: 0.4543, Train Acc: 0.7829 | Val Loss: 0.5057, Val Acc: 0.7675
# EarlyStopping counter: 2 out of 10
# Epoch 13/100 | Train Loss: 0.4528, Train Acc: 0.7871 | Val Loss: 0.4904, Val Acc: 0.7730
# EarlyStopping counter: 3 out of 10
# Epoch 14/100 | Train Loss: 0.4453, Train Acc: 0.7883 | Val Loss: 0.4781, Val Acc: 0.7810
# EarlyStopping counter: 4 out of 10
# Epoch 15/100 | Train Loss: 0.4486, Train Acc: 0.7884 | Val Loss: 0.4785, Val Acc: 0.7835
# EarlyStopping counter: 5 out of 10
# Epoch 16/100 | Train Loss: 0.4579, Train Acc: 0.7804 | Val Loss: 0.4849, Val Acc: 0.7750
# EarlyStopping counter: 6 out of 10
# Epoch 17/100 | Train Loss: 0.4522, Train Acc: 0.7828 | Val Loss: 0.4784, Val Acc: 0.7750
# EarlyStopping counter: 7 out of 10
# Epoch 18/100 | Train Loss: 0.4485, Train Acc: 0.7850 | Val Loss: 0.5160, Val Acc: 0.7540
# EarlyStopping counter: 8 out of 10
# Epoch 19/100 | Train Loss: 0.4482, Train Acc: 0.7863 | Val Loss: 0.4766, Val Acc: 0.7830
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_5.pth
# Epoch 20/100 | Train Loss: 0.4478, Train Acc: 0.7944 | Val Loss: 0.4734, Val Acc: 0.7805
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SqueezeNet_CV_fold_5.pth
# Epoch 21/100 | Train Loss: 0.4544, Train Acc: 0.7798 | Val Loss: 0.4906, Val Acc: 0.7840
# EarlyStopping counter: 1 out of 10
# Epoch 22/100 | Train Loss: 0.4568, Train Acc: 0.7871 | Val Loss: 0.4764, Val Acc: 0.7865
# EarlyStopping counter: 2 out of 10
# Epoch 23/100 | Train Loss: 0.4539, Train Acc: 0.7854 | Val Loss: 0.4755, Val Acc: 0.7765
# EarlyStopping counter: 3 out of 10
# Epoch 24/100 | Train Loss: 0.4678, Train Acc: 0.7765 | Val Loss: 0.4857, Val Acc: 0.7870
# EarlyStopping counter: 4 out of 10
# Epoch 25/100 | Train Loss: 0.4594, Train Acc: 0.7843 | Val Loss: 0.4881, Val Acc: 0.7800
# EarlyStopping counter: 5 out of 10
# Epoch 26/100 | Train Loss: 0.4600, Train Acc: 0.7811 | Val Loss: 0.4902, Val Acc: 0.7735
# EarlyStopping counter: 6 out of 10
# Epoch 27/100 | Train Loss: 0.4497, Train Acc: 0.7874 | Val Loss: 0.4865, Val Acc: 0.7725
# EarlyStopping counter: 7 out of 10
# Epoch 28/100 | Train Loss: 0.4564, Train Acc: 0.7821 | Val Loss: 0.4918, Val Acc: 0.7725
# EarlyStopping counter: 8 out of 10
# Epoch 29/100 | Train Loss: 0.4542, Train Acc: 0.7819 | Val Loss: 0.4804, Val Acc: 0.7815
# EarlyStopping counter: 9 out of 10
# Epoch 30/100 | Train Loss: 0.4570, Train Acc: 0.7840 | Val Loss: 0.4975, Val Acc: 0.7760
# EarlyStopping counter: 10 out of 10
# Early stopping triggered. Ending training.
#
# ========== Cross-Validation Results ==========
#
#    fold  train_loss  train_accuracy  val_loss  val_accuracy
# 0     1    0.458632        0.782250  0.450517        0.7790
# 1     2    0.449718        0.784750  0.467588        0.7705
# 2     3    0.453871        0.783375  0.446860        0.7855
# 3     4    0.466524        0.775875  0.471539        0.7720
# 4     5    0.457042        0.784000  0.497490        0.7760
#
# Average Validation Accuracy: 0.7766

# %%
# Convert results to DataFrame
cv_metrics_df = pd.DataFrame(cv_metrics)

# Calculate average metrics
avg_metrics = cv_metrics_df.mean().to_dict()
avg_metrics["Fold"] = "Average"

# Add the average metrics to the DataFrame
cv_metrics_df = cv_metrics_df.append(avg_metrics, ignore_index=True)

# Save results to CSV file
csv_file_name = f"CV_Results/{file_name}.csv"
cv_metrics_df.to_csv(csv_file_name, index=False)

print(f"Cross-validation metrics saved to {csv_file_name}")
# Out:
# Cross-validation metrics saved to CV_Results/Benchmark_SqueezeNet_CV.csv
# /tmp/job.2295369.hpc/ipykernel_2595043/1908723448.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cv_metrics_df = cv_metrics_df.append(avg_metrics, ignore_index=True)
