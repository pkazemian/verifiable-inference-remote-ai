# %%
# Import necessary libraries
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Subset, DataLoader, Dataset
from torchvision import datasets, transforms, models
from torchvision.models import efficientnet_b0
from torchvision.models.efficientnet import SqueezeExcitation
import matplotlib.pyplot as plt
import multiprocessing
import numpy as np
from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score,  roc_auc_score, 
    cohen_kappa_score, matthews_corrcoef, confusion_matrix, average_precision_score, fbeta_score,
    precision_recall_curve, balanced_accuracy_score)
import pandas as pd
from sklearn.utils import shuffle
import random
import albumentations as A
from albumentations.pytorch import ToTensorV2
import pandas as pd
import torch_optimizer
import cv2
from skimage import measure
from torchvision.utils import make_grid
# %matplotlib inline
# Out:
# /home/pxk409/Skin_EfficientNet/GCCcore-11.3.0/lib/python3.10/site-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 1.4.23 (you have 1.4.21). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
# Check for GPU availability
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# !nvidia-smi
# Out:
# Wed Dec 18 13:35:30 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.54.03              Driver Version: 535.54.03    CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-PCIE-32GB           On  | 00000000:3B:00.0 Off |                    0 |
# | N/A   34C    P0              39W / 250W |   1530MiB / 32768MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A   2584432      C   ...on/3.10.4-GCCcore-11.3.0/bin/python     1526MiB |
# +---------------------------------------------------------------------------------------+

# %%
file_name = "Benchmark_MobileNet_CV"

# %%
import os

# Define directories of where the datasets reside
base_dir = '/home/pxk409/skin_lesions_13k'

# Define directories of where the training, validation and test sets reside
train_dir = os.path.join(base_dir, 'train')
test_dir = os.path.join(base_dir, 'test')

# Define directories of where the benign and malignant images reside
train_benign_dir = os.path.join(base_dir, 'train/benign')
train_malignant_dir = os.path.join(base_dir, 'train/malignant')
test_benign_dir = os.path.join(base_dir, 'test/benign')
test_malignant_dir = os.path.join(base_dir, 'test/malignant')

# %%
# Let's check the number of images in each set
print('Total training benign images:', len(os.listdir(train_benign_dir)))
print('Total training malignant images:', len(os.listdir(train_malignant_dir)))
print('Total test benign images:', len(os.listdir(test_benign_dir)))
print('Total test malignant images:', len(os.listdir(test_malignant_dir)))
# Out:
# Total training benign images: 5000
# Total training malignant images: 5000
# Total test benign images: 1500
# Total test malignant images: 1500

# %%
# Load full dataset
full_dataset = datasets.ImageFolder(root=train_dir)

# Extract labels from the dataset
#labels = [label for _, label in full_dataset.samples]

# Stratified split (80% train, 20% validation)
#split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=123456)
#train_idx, val_idx = next(split.split(np.zeros(len(labels)), labels))

# Create training and validation subsets
#train_dataset = Subset(full_dataset, train_idx)
#val_dataset = Subset(full_dataset, val_idx)

#print(f"Training set: {len(train_idx)} samples")
#print(f"Validation set: {len(val_idx)} samples")

# Count the number of samples per class in each split
#train_classes = [full_dataset.targets[idx] for idx in train_dataset.indices]
#val_classes = [full_dataset.targets[idx] for idx in val_dataset.indices]

#print(f"Training set class counts: {np.bincount(train_classes)}")
#print(f"Validation set class counts: {np.bincount(val_classes)}")

# %%
# Custom transform to integrate Albumentations with PyTorch
class AlbumentationsTransform:
    def __init__(self, augmentations):
        self.augmentations = A.Compose(augmentations)

    def __call__(self, image):
        image = np.array(image)  # Convert PIL Image to NumPy array
        augmented = self.augmentations(image=image)
        return augmented["image"]

# Simple augmentations for training
simple_transform = AlbumentationsTransform([
    A.RandomResizedCrop(height=224, width=224, scale=(0.8, 1.0), p=1.0),  # Random crop and resize
    A.HorizontalFlip(p=0.5),  # Horizontal flip
    A.VerticalFlip(p=0.5),  # Vertical flip
    #A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1, p=0.5),  # Color jitter
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  # Normalize to match pre-trained model
    ToTensorV2(),  # Convert to PyTorch tensor and ensure dtype=torch.float32
])


# Use AlbumentationsTransform directly in the loaders for consistency
train_transform = simple_transform

# Albumentations augmentations for validation and test
albumentations_val_test_transform = AlbumentationsTransform([
    A.Resize(height=224, width=224),  # Resize to EfficientNet input size
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  # Normalize to match pre-trained model
    ToTensorV2()  # Convert to PyTorch tensor
])

test_val_transform = albumentations_val_test_transform

# %%
class TransformDataset(Dataset):
    def __init__(self, dataset, transform):
        """
        Args:
            dataset: Original dataset (e.g., Subset of ImageFolder).
            transform: Transform to be applied to the images in the dataset.
        """
        self.dataset = dataset
        self.transform = transform

    def __getitem__(self, idx):
        image, label = self.dataset[idx]
        if self.transform:
            image = self.transform(image)
        return image, label

    def __len__(self):
        return len(self.dataset)

# %%
# Wrap subsets with the respective transforms
#train_dataset = TransformDataset(train_dataset, train_transform)
#val_dataset = TransformDataset(val_dataset, test_val_transform)

# %%
# Load and prepare the test dataset
#test_dataset = datasets.ImageFolder(root=test_dir, transform=test_val_transform)
test_dataset = datasets.ImageFolder(root=test_dir)
test_dataset = TransformDataset(test_dataset, test_val_transform)

# %%
# Create data loaders
batch_size = 64
#num_cpus = multiprocessing.cpu_count()  # Use all CPU cores
#print(f"Number of CPU cores: {num_cpus}")
#num_workers = 16


#train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
#val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
#train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=True)
#val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=True)
#test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=True)

# %%
def initialize_model():
    # Load pre-trained MobileNetV2
    model = models.mobilenet_v2(weights=models.MobileNet_V2_Weights.DEFAULT)

    # Freeze the convolutional part (feature extractor)
    for param in model.features.parameters():
        param.requires_grad = False

    # Replace the classifier with a custom one
    # MobileNetV2's last convolutional output has 1280 features
    model.classifier = nn.Sequential(
        nn.Dropout(0.5),
        nn.Linear(1280, 512),  # MobileNetV2's feature size is 1280
        nn.ReLU(),
        nn.Dropout(0.5),
        nn.Linear(512, 256),
        nn.ReLU(),
        nn.Linear(256, 2)  # Output layer for binary classification
    )

    # Ensure the classifier remains trainable
    for param in model.classifier.parameters():
        param.requires_grad = True

    # Move model to device
    model = model.to(device)
    return model

model = initialize_model()

# %%
# Function to count trainable and non-trainable parameters
def count_trainable_non_trainable_parameters(model):
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    non_trainable = sum(p.numel() for p in model.parameters() if not p.requires_grad)
    return trainable, non_trainable

# Count parameters in the convolutional part
conv_trainable, conv_non_trainable = count_trainable_non_trainable_parameters(model.features)
print(f"Convolutional part (features):\n"
      f"  Trainable parameters: {conv_trainable:,}\n"
      f"  Non-trainable parameters: {conv_non_trainable:,}")

# Count parameters in the classifier part
classifier_trainable, classifier_non_trainable = count_trainable_non_trainable_parameters(model.classifier)
print(f"Classifier part:\n"
      f"  Trainable parameters: {classifier_trainable:,}\n"
      f"  Non-trainable parameters: {classifier_non_trainable:,}")

# Count parameters in the entire model
total_trainable, total_non_trainable = count_trainable_non_trainable_parameters(model)
print(f"Whole model:\n"
      f"  Trainable parameters: {total_trainable:,}\n"
      f"  Non-trainable parameters: {total_non_trainable:,}")
# Out:
# Convolutional part (features):
#   Trainable parameters: 0
#   Non-trainable parameters: 2,223,872
# Classifier part:
#   Trainable parameters: 787,714
#   Non-trainable parameters: 0
# Whole model:
#   Trainable parameters: 787,714
#   Non-trainable parameters: 2,223,872

# %%
# Early Stopping
class EarlyStopping:
    def __init__(self, patience, delta, path):
        """
        Args:
            patience (int): Number of epochs to wait after last improvement.
            delta (float): Minimum change in monitored metric to qualify as an improvement.
            path (str): Path to save the best model.
        """
        self.patience = patience
        self.delta = delta
        self.path = path
        self.counter = 0
        self.best_score = None
        self.early_stop = False

    def __call__(self, val_loss, model):
        score = -val_loss  # Early stopping is based on minimizing validation loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f"EarlyStopping counter: {self.counter} out of {self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        """Saves model when validation loss decreases."""
        print(f"Validation loss decreased. Saving model to {self.path}")
        torch.save(model.state_dict(), self.path)


# Set the path for saving best_model.pth
#current_dir = os.getcwd()
#model_save_path = os.path.join(current_dir, 'best_model2.pth')

# Initialize EarlyStopping
#early_stopping = EarlyStopping(patience=5, delta=0.001, path=model_save_path)

# %%
# Helper function to evaluate a dataset
def evaluate_model(model, data_loader, device):
    model.eval()  # Set model to evaluation mode
    all_labels = []
    all_preds = []
    all_probs = []

    with torch.no_grad():
        for images, labels in data_loader:
            images, labels = images.to(device), labels.to(device)

            # Forward pass
            outputs = model(images)
            probs = torch.softmax(outputs, dim=1)[:, 1]  # Probabilities for the positive class
            _, preds = torch.max(outputs, 1)

            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())

    return np.array(all_labels), np.array(all_preds), np.array(all_probs)

# Helper function to calculate selected metrics
def calculate_metrics(labels, preds, probs):
    accuracy = accuracy_score(labels, preds)
    precision = precision_score(labels, preds)
    recall = recall_score(labels, preds)
    f1 = f1_score(labels, preds)
    f2 = fbeta_score(labels, preds, beta=2)
    auc = roc_auc_score(labels, probs)
    specificity = recall_score(labels, preds, pos_label=0)
    npv = precision_score(labels, preds, pos_label=0)

    return recall, precision, accuracy, f1, f2, auc, specificity, npv

# %%
# Training loop with 5-fold cross-validation
cv_results = []
cv_metrics = []
n_splits = 5
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=123456)

# Extract labels from the dataset
labels = [label for _, label in full_dataset.samples]

# Cross-validation loop
for fold, (train_idx, val_idx) in enumerate(skf.split(np.zeros(len(labels)), labels), 1):
    print(f"\n========== Fold {fold} ==========\n")
    
    # Create training and validation subsets for this fold
    train_dataset = Subset(full_dataset, train_idx)
    val_dataset = Subset(full_dataset, val_idx)
    
    # Apply transformations
    train_dataset = TransformDataset(train_dataset, train_transform)
    val_dataset = TransformDataset(val_dataset, test_val_transform)
    
    # Create data loaders
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    
    # Initialize model and optimizer for each fold
    model = initialize_model()
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    # EarlyStopping initialization
    early_stopping = EarlyStopping(patience=10, delta=0.0001, path=os.path.join(os.getcwd(), f"{file_name}_fold_{fold}.pth"))

    # Training loop
    num_epochs = 100
    train_losses = []
    val_losses = []
    
    for epoch in range(num_epochs):
        # Training phase
        model.train()
        train_loss = 0
        train_correct = 0
        
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            
            # Forward pass
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            train_correct += torch.sum(preds == labels)
        
        train_loss /= len(train_loader)
        train_accuracy = train_correct.double() / len(train_dataset)
        train_losses.append(train_loss)
        
        # Validation phase
        model.eval()
        val_loss = 0
        val_correct = 0
        
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                
                outputs = model(images)
                loss = criterion(outputs, labels)
                
                val_loss += loss.item()
                _, preds = torch.max(outputs, 1)
                val_correct += torch.sum(preds == labels)
        
        val_loss /= len(val_loader)
        val_accuracy = val_correct.double() / len(val_dataset)
        val_losses.append(val_loss)
        
        print(f"Epoch {epoch + 1}/{num_epochs} | "
              f"Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.4f} | "
              f"Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.4f}")
        
        # Call EarlyStopping
        early_stopping(val_loss, model)
        if early_stopping.early_stop:
            print("Early stopping triggered. Ending training.")
            break
    
    # Store results for this fold
    cv_results.append({
        "fold": fold,
        "train_loss": train_loss,
        "train_accuracy": train_accuracy.item(),
        "val_loss": val_loss,
        "val_accuracy": val_accuracy.item()
        })
        
    # Load the best model for evaluation
    model.load_state_dict(torch.load(f"{file_name}_fold_{fold}.pth", weights_only=True))

    # Evaluate on validation set
    labels, preds, probs = evaluate_model(model, val_loader, device)
    metrics = calculate_metrics(labels, preds, probs)
    recall, precision, accuracy, f1, f2, auc, specificity, npv = metrics

    # Record metrics for the fold
    cv_metrics.append({
        "Fold": fold,
        "Recall": recall,
        "Precision": precision,
        "Accuracy": accuracy,
        "F1 Score": f1,
        "F2 Score": f2,
        "AUC": auc,
        "Specificity": specificity,
        "NPV": npv,
    })

# Summarize cross-validation results
df_cv_results = pd.DataFrame(cv_results)
print("\n========== Cross-Validation Results ==========\n")
print(df_cv_results)

print("\nAverage Validation Accuracy: {:.4f}".format(df_cv_results["val_accuracy"].mean()))
# Out:
# ========== Fold 1 ==========
#
# Epoch 1/100 | Train Loss: 0.5608, Train Acc: 0.7146 | Val Loss: 0.4923, Val Acc: 0.7620
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_1.pth
# Epoch 2/100 | Train Loss: 0.5047, Train Acc: 0.7502 | Val Loss: 0.4682, Val Acc: 0.7715
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_1.pth
# Epoch 3/100 | Train Loss: 0.4910, Train Acc: 0.7576 | Val Loss: 0.4617, Val Acc: 0.7775
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_1.pth
# Epoch 4/100 | Train Loss: 0.4867, Train Acc: 0.7665 | Val Loss: 0.4534, Val Acc: 0.7805
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_1.pth
# Epoch 5/100 | Train Loss: 0.4771, Train Acc: 0.7645 | Val Loss: 0.4455, Val Acc: 0.7880
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_1.pth
# Epoch 6/100 | Train Loss: 0.4723, Train Acc: 0.7689 | Val Loss: 0.4399, Val Acc: 0.7895
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_1.pth
# Epoch 7/100 | Train Loss: 0.4707, Train Acc: 0.7734 | Val Loss: 0.4412, Val Acc: 0.7895
# EarlyStopping counter: 1 out of 10
# Epoch 8/100 | Train Loss: 0.4640, Train Acc: 0.7728 | Val Loss: 0.4417, Val Acc: 0.7885
# EarlyStopping counter: 2 out of 10
# Epoch 9/100 | Train Loss: 0.4645, Train Acc: 0.7770 | Val Loss: 0.4426, Val Acc: 0.7885
# EarlyStopping counter: 3 out of 10
# Epoch 10/100 | Train Loss: 0.4569, Train Acc: 0.7761 | Val Loss: 0.4534, Val Acc: 0.7860
# EarlyStopping counter: 4 out of 10
# Epoch 11/100 | Train Loss: 0.4555, Train Acc: 0.7712 | Val Loss: 0.4444, Val Acc: 0.7925
# EarlyStopping counter: 5 out of 10
# Epoch 12/100 | Train Loss: 0.4522, Train Acc: 0.7823 | Val Loss: 0.4329, Val Acc: 0.7990
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_1.pth
# Epoch 13/100 | Train Loss: 0.4396, Train Acc: 0.7896 | Val Loss: 0.4299, Val Acc: 0.7955
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_1.pth
# Epoch 14/100 | Train Loss: 0.4349, Train Acc: 0.7929 | Val Loss: 0.4267, Val Acc: 0.7940
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_1.pth
# Epoch
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_1.pth
# Epoch 39/100 | Train Loss: 0.3791, Train Acc: 0.8250 | Val Loss: 0.4007, Val Acc: 0.8080
# EarlyStopping counter: 1 out of 10
# Epoch 40/100 | Train Loss: 0.3791, Train Acc: 0.8247 | Val Loss: 0.3983, Val Acc: 0.8120
# EarlyStopping counter: 2 out of 10
# Epoch 41/100 | Train Loss: 0.3818, Train Acc: 0.8243 | Val Loss: 0.3955, Val Acc: 0.8130
# EarlyStopping counter: 3 out of 10
# Epoch 42/100 | Train Loss: 0.3789, Train Acc: 0.8269 | Val Loss: 0.3970, Val Acc: 0.8090
# EarlyStopping counter: 4 out of 10
# Epoch 43/100 | Train Loss: 0.3766, Train Acc: 0.8340 | Val Loss: 0.3990, Val Acc: 0.8080
# EarlyStopping counter: 5 out of 10
# Epoch 44/100 | Train Loss: 0.3774, Train Acc: 0.8265 | Val Loss: 0.3970, Val Acc: 0.8145
# EarlyStopping counter: 6 out of 10
# Epoch 45/100 | Train Loss: 0.3707, Train Acc: 0.8330 | Val Loss: 0.4022, Val Acc: 0.8075
# EarlyStopping counter: 7 out of 10
# Epoch 46/100 | Train Loss: 0.3673, Train Acc: 0.8284 | Val Loss: 0.3872, Val Acc: 0.8205
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_1.pth
# Epoch 47/100 | Train Loss: 0.3765, Train Acc: 0.8244 | Val Loss: 0.4031, Val Acc: 0.8135
# EarlyStopping counter: 1 out of 10
# Epoch 48/100 | Train Loss: 0.3636, Train Acc: 0.8323 | Val Loss: 0.3991, Val Acc: 0.8195
# EarlyStopping counter: 2 out of 10
# Epoch 49/100 | Train Loss: 0.3636, Train Acc: 0.8325 | Val Loss: 0.3944, Val Acc: 0.8120
# EarlyStopping counter: 3 out of 10
# Epoch 50/100 | Train Loss: 0.3678, Train Acc: 0.8321 | Val Loss: 0.3904, Val Acc: 0.8190
# EarlyStopping counter: 4 out of 10
# Epoch 51/100 | Train Loss: 0.3645, Train Acc: 0.8360 | Val Loss: 0.3922, Val Acc: 0.8180
# EarlyStopping counter: 5 out of 10
# Epoch 52/100 | Train Loss: 0.3606, Train Acc: 0.8374 | Val Loss: 0.3909, Val Acc: 0.8185
# EarlyStopping counter: 6 out of 10
# Epoch 53/100 | Train Loss: 0.3652, Train Acc: 0.8330 | Val Loss: 0.3914, Val Acc: 0.8160
# EarlyStopping counter: 7 out of 10
# Epoch 54/100 | Train Loss: 0.3561, Train Acc: 0.8395 | Val Loss: 0.3845, Val Acc: 0.8190
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_1.pth
# Epoch 55/100 | Train Loss: 0.3679, Train Acc: 0.8319 | Val Loss: 0.3894, Val Acc: 0.8165
# EarlyStopping counter: 1 out of 10
# Epoch 56/100 | Train Loss: 0.3549, Train Acc: 0.8360 | Val Loss: 0.3785, Val Acc: 0.8290
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_1.pth
# Epoch 57/100 | Train Loss: 0.3640, Train Acc: 0.8313 | Val Loss: 0.3874, Val Acc: 0.8265
# EarlyStopping counter: 1 out of 10
# Epoch 58/100 | Train Loss: 0.3600, Train Acc: 0.8370 | Val Loss: 0.3826, Val Acc: 0.8220
# EarlyStopping counter: 2 out of 10
# Epoch 59/100 | Train Loss: 0.3627, Train Acc: 0.8299 | Val Loss: 0.3862, Val Acc: 0.8180
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_3.pth
# Epoch 43/100 | Train Loss: 0.3723, Train Acc: 0.8283 | Val Loss: 0.3970, Val Acc: 0.8240
# EarlyStopping counter: 1 out of 10
# Epoch 44/100 | Train Loss: 0.3854, Train Acc: 0.8189 | Val Loss: 0.3923, Val Acc: 0.8220
# EarlyStopping counter: 2 out of 10
# Epoch 45/100 | Train Loss: 0.3772, Train Acc: 0.8254 | Val Loss: 0.3957, Val Acc: 0.8240
# EarlyStopping counter: 3 out of 10
# Epoch 46/100 | Train Loss: 0.3717, Train Acc: 0.8247 | Val Loss: 0.3797, Val Acc: 0.8190
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_3.pth
# Epoch 47/100 | Train Loss: 0.3813, Train Acc: 0.8249 | Val Loss: 0.3877, Val Acc: 0.8190
# EarlyStopping counter: 1 out of 10
# Epoch 48/100 | Train Loss: 0.3759, Train Acc: 0.8326 | Val Loss: 0.3819, Val Acc: 0.8225
# EarlyStopping counter: 2 out of 10
# Epoch 49/100 | Train Loss: 0.3733, Train Acc: 0.8300 | Val Loss: 0.3940, Val Acc: 0.8205
# EarlyStopping counter: 3 out of 10
# Epoch 50/100 | Train Loss: 0.3759, Train Acc: 0.8269 | Val Loss: 0.3855, Val Acc: 0.8205
# EarlyStopping counter: 4 out of 10
# Epoch 51/100 | Train Loss: 0.3761, Train Acc: 0.8307 | Val Loss: 0.3783, Val Acc: 0.8265
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_3.pth
# Epoch 52/100 | Train Loss: 0.3758, Train Acc: 0.8273 | Val Loss: 0.3788, Val Acc: 0.8310
# EarlyStopping counter: 1 out of 10
# Epoch 53/100 | Train Loss: 0.3763, Train Acc: 0.8274 | Val Loss: 0.3824, Val Acc: 0.8290
# EarlyStopping counter: 2 out of 10
# Epoch 54/100 | Train Loss: 0.3687, Train Acc: 0.8333 | Val Loss: 0.3904, Val Acc: 0.8190
# EarlyStopping counter: 3 out of 10
# Epoch 55/100 | Train Loss: 0.3712, Train Acc: 0.8316 | Val Loss: 0.3828, Val Acc: 0.8305
# EarlyStopping counter: 4 out of 10
# Epoch 56/100 | Train Loss: 0.3674, Train Acc: 0.8255 | Val Loss: 0.3847, Val Acc: 0.8320
# EarlyStopping counter: 5 out of 10
# Epoch 57/100 | Train Loss: 0.3587, Train Acc: 0.8331 | Val Loss: 0.3829, Val Acc: 0.8235
# EarlyStopping counter: 6 out of 10
# Epoch 58/100 | Train Loss: 0.3690, Train Acc: 0.8296 | Val Loss: 0.3825, Val Acc: 0.8240
# EarlyStopping counter: 7 out of 10
# Epoch 59/100 | Train Loss: 0.3674, Train Acc: 0.8336 | Val Loss: 0.3779, Val Acc: 0.8260
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_3.pth
# Epoch 60/100 | Train Loss: 0.3677, Train Acc: 0.8330 | Val Loss: 0.3854, Val Acc: 0.8275
# EarlyStopping counter: 1 out of 10
# Epoch 61/100 | Train Loss: 0.3568, Train Acc: 0.8389 | Val Loss: 0.3828, Val Acc: 0.8175
# EarlyStopping counter: 2 out of 10
# Epoch 62/100 | Train Loss: 0.3590, Train Acc: 0.8341 | Val Loss: 0.3839, Val Acc: 0.8225
# EarlyStopping counter: 3 out of 10
# Epoch 63/100 | Train Loss: 0.3585, Train Acc: 0.8357 | Val Loss: 0.3870, Val Acc: 0.8215
# EarlyStopping counter: 4 out of 10
# Epoch 64/100 | Train Loss: 0.3578, Train Acc: 0.8391 | Val Loss: 0.3828, Val Acc: 0.8280
# EarlyStopping counter: 5 out of 10
# Epoch 65/100 | Train Loss: 0.3542, Train Acc: 0.8404 | Val Loss: 0.3782, Val Acc: 0.8260
# EarlyStopping counter: 6 out of 10
# Epoch 66/100 | Train Loss: 0.3549, Train Acc: 0.8363 | Val Loss: 0.3810, Val Acc: 0.8315
# EarlyStopping counter: 7 out of 10
# Epoch 67/100 | Train Loss: 0.3455, Train Acc: 0.8389 | Val Loss: 0.3771, Val Acc: 0.8270
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_3.pth
# Epoch 68/100 | Train Loss: 0.3540, Train Acc: 0.8346 | Val Loss: 0.3747, Val Acc: 0.8300
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_3.pth
# Epoch 69/100 | Train Loss: 0.3518, Train Acc: 0.8399 | Val Loss: 0.3768, Val Acc: 0.8365
# EarlyStopping counter: 1 out of 10
# Epoch 70/100 | Train Loss: 0.3626, Train Acc: 0.8354 | Val Loss: 0.3843, Val Acc: 0.8345
# EarlyStopping counter: 2 out of 10
# Epoch 71/100 | Train Loss: 0.3411, Train Acc: 0.8427 | Val Loss: 0.3724, Val Acc: 0.8370
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_3.pth
# Epoch 72/100 | Train Loss: 0.3480, Train Acc: 0.8425 | Val Loss: 0.3797, Val Acc: 0.8255
# EarlyStopping counter: 1 out of 10
# Epoch 73/100 | Train Loss: 0.3506, Train Acc: 0.8450 | Val Loss: 0.3759, Val Acc: 0.8275
# EarlyStopping counter: 2 out of 10
# Epoch 74/100 | Train Loss: 0.3420, Train Acc: 0.8419 | Val Loss: 0.3783, Val Acc: 0.8315
# EarlyStopping counter: 3 out of 10
# Epoch 75/100 | Train Loss: 0.3409, Train Acc: 0.8443 | Val Loss: 0.3751, Val Acc: 0.8255
# EarlyStopping counter: 4 out of 10
# Epoch 76/100 | Train Loss: 0.3473, Train Acc: 0.8374 | Val Loss: 0.3731, Val Acc: 0.8355
# EarlyStopping counter: 5 out of 10
# Epoch 77/100 | Train Loss: 0.3428, Train Acc: 0.8441 | Val Loss: 0.3736, Val Acc: 0.8320
# EarlyStopping counter: 6 out of 10
# Epoch 78/100 | Train Loss: 0.3423, Train Acc: 0.8427 | Val Loss: 0.3684, Val Acc: 0.8350
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_3.pth
# Epoch 79/100 | Train Loss: 0.3422, Train Acc: 0.8414 | Val Loss: 0.3687, Val Acc: 0.8385
# EarlyStopping counter: 1 out of 10
# Epoch 80/100 | Train Loss: 0.3356, Train Acc: 0.8455 | Val Loss: 0.3694, Val Acc: 0.8325
# EarlyStopping counter: 2 out of 10
# Epoch 81/100 | Train Loss: 0.3525, Train Acc: 0.8443 | Val Loss: 0.3727, Val Acc: 0.8340
# EarlyStopping counter: 3 out of 10
# Epoch 82/100 | Train Loss: 0.3365, Train Acc: 0.8449 | Val Loss: 0.3725, Val Acc: 0.8360
# EarlyStopping counter: 4 out of 10
# Epoch 83/100 | Train Loss: 0.3350, Train Acc: 0.8455 | Val Loss: 0.3729, Val Acc: 0.8360
# EarlyStopping counter: 5 out of 10
# Epoch 84/100 | Train Loss: 0.3370, Train Acc: 0.8469 | Val Loss: 0.3645, Val Acc: 0.8370
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_3.pth
# Epoch 85/100 | Train Loss: 0.3392, Train Acc: 0.8440 | Val Loss: 0.3700, Val Acc: 0.8370
# EarlyStopping counter: 1 out of 10
# Epoch 86/100 | Train Loss: 0.3420, Train Acc: 0.8433 | Val Loss: 0.3686, Val Acc: 0.8295
# EarlyStopping counter: 2 out of 10
# Epoch 87/100 | Train Loss: 0.3370, Train Acc: 0.8480 | Val Loss: 0.3724, Val Acc: 0.8325
# EarlyStopping counter: 3 out of 10
# Epoch 88/100 | Train Loss: 0.3271, Train Acc: 0.8510 | Val Loss: 0.3677, Val Acc: 0.8355
# EarlyStopping counter: 4 out of 10
# Epoch 89/100 | Train Loss: 0.3331, Train Acc: 0.8498 | Val Loss: 0.3655, Val Acc: 0.8410
# EarlyStopping counter: 5 out of 10
# Epoch 90/100 | Train Loss: 0.3281, Train Acc: 0.8495 | Val Loss: 0.3653, Val Acc: 0.8395
# EarlyStopping counter: 6 out of 10
# Epoch 91/100 | Train Loss: 0.3335, Train Acc: 0.8469 | Val Loss: 0.3666, Val Acc: 0.8360
# EarlyStopping counter: 7 out of 10
# Epoch 92/100 | Train Loss: 0.3266, Train Acc: 0.8519 | Val Loss: 0.3649, Val Acc: 0.8390
# EarlyStopping counter: 8 out of 10
# Epoch 93/100 | Train Loss: 0.3306, Train Acc: 0.8524 | Val Loss: 0.3635, Val Acc: 0.8330
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_3.pth
# Epoch 94/100 | Train Loss: 0.3349, Train Acc: 0.8494 | Val Loss: 0.3815, Val Acc: 0.8265
# EarlyStopping counter: 1 out of 10
# Epoch 95/100 | Train Loss: 0.3255, Train Acc: 0.8538 | Val Loss: 0.3644, Val Acc: 0.8300
# EarlyStopping counter: 2 out of 10
# Epoch 96/100 | Train Loss: 0.3372, Train Acc: 0.8490 | Val Loss: 0.3743, Val Acc: 0.8360
# EarlyStopping counter: 3 out of 10
# Epoch 97/100 | Train Loss: 0.3310, Train Acc: 0.8504 | Val Loss: 0.3648, Val Acc: 0.8370
# EarlyStopping counter: 4 out of 10
# Epoch 98/100 | Train Loss: 0.3283, Train Acc: 0.8508 | Val Loss: 0.3654, Val Acc: 0.8375
# EarlyStopping counter: 5 out of 10
# Epoch 99/100 | Train Loss: 0.3206, Train Acc: 0.8574 | Val Loss: 0.3727, Val Acc: 0.8300
# EarlyStopping counter: 6 out of 10
# Epoch 100/100 | Train Loss: 0.3219, Train Acc: 0.8586 | Val Loss: 0.3657, Val Acc: 0.8320
# EarlyStopping counter: 7 out of 10
#
# ========== Fold 4 ==========
#
# Epoch 1/100 | Train Loss: 0.5498, Train Acc: 0.7131 | Val Loss: 0.4733, Val Acc: 0.7700
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_4.pth
# Epoch 2/100 | Train Loss: 0.5028, Train Acc: 0.7479 | Val Loss: 0.4601, Val Acc: 0.7770
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_4.pth
# Epoch 3/100 | Train Loss: 0.4998, Train Acc: 0.7562 | Val Loss: 0.4662, Val Acc: 0.7910
# EarlyStopping counter: 1 out of 10
# Epoch 4/100 | Train Loss: 0.4850, Train Acc: 0.7598 | Val Loss: 0.4589, Val Acc: 0.7810
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_4.pth
# Epoch 5/100 | Train Loss: 0.4828, Train Acc: 0.7609 | Val Loss: 0.4459, Val Acc: 0.7910
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_4.pth
# Epoch 6/100 | Train Loss: 0.4692, Train Acc: 0.7695 | Val Loss: 0.4444, Val Acc: 0.7850
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_4.pth
# Epoch 7/100 | Train Loss: 0.4668, Train Acc: 0.7722 | Val Loss: 0.4428, Val Acc: 0.7940
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_4.pth
# Epoch
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_4.pth
# Epoch 55/100 | Train Loss: 0.3649, Train Acc: 0.8314 | Val Loss: 0.3852, Val Acc: 0.8285
# EarlyStopping counter: 1 out of 10
# Epoch 56/100 | Train Loss: 0.3566, Train Acc: 0.8364 | Val Loss: 0.3868, Val Acc: 0.8320
# EarlyStopping counter: 2 out of 10
# Epoch 57/100 | Train Loss: 0.3632, Train Acc: 0.8329 | Val Loss: 0.3783, Val Acc: 0.8285
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_4.pth
# Epoch 58/100 | Train Loss: 0.3668, Train Acc: 0.8281 | Val Loss: 0.3854, Val Acc: 0.8280
# EarlyStopping counter: 1 out of 10
# Epoch 59/100 | Train Loss: 0.3616, Train Acc: 0.8356 | Val Loss: 0.3832, Val Acc: 0.8295
# EarlyStopping counter: 2 out of 10
# Epoch 60/100 | Train Loss: 0.3546, Train Acc: 0.8407 | Val Loss: 0.3821, Val Acc: 0.8355
# EarlyStopping counter: 3 out of 10
# Epoch 61/100 | Train Loss: 0.3595, Train Acc: 0.8359 | Val Loss: 0.3872, Val Acc: 0.8315
# EarlyStopping counter: 4 out of 10
# Epoch 62/100 | Train Loss: 0.3549, Train Acc: 0.8399 | Val Loss: 0.3794, Val Acc: 0.8325
# EarlyStopping counter: 5 out of 10
# Epoch 63/100 | Train Loss: 0.3532, Train Acc: 0.8389 | Val Loss: 0.3792, Val Acc: 0.8355
# EarlyStopping counter: 6 out of 10
# Epoch 64/100 | Train Loss: 0.3520, Train Acc: 0.8406 | Val Loss: 0.3870, Val Acc: 0.8285
# EarlyStopping counter: 7 out of 10
# Epoch 65/100 | Train Loss: 0.3560, Train Acc: 0.8395 | Val Loss: 0.3850, Val Acc: 0.8325
# EarlyStopping counter: 8 out of 10
# Epoch 66/100 | Train Loss: 0.3533, Train Acc: 0.8371 | Val Loss: 0.3835, Val Acc: 0.8335
# EarlyStopping counter: 9 out of 10
# Epoch 67/100 | Train Loss: 0.3553, Train Acc: 0.8354 | Val Loss: 0.3806, Val Acc: 0.8310
# EarlyStopping counter: 10 out of 10
# Early stopping triggered. Ending training.
# ========== Fold 5 ==========
#
# Epoch 1/100 | Train Loss: 0.5538, Train Acc: 0.7123 | Val Loss: 0.4982, Val Acc: 0.7575
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_5.pth
# Epoch 2/100 | Train Loss: 0.5058, Train Acc: 0.7504 | Val Loss: 0.4812, Val Acc: 0.7615
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_5.pth
# Epoch 3/100 | Train Loss: 0.4888, Train Acc: 0.7611 | Val Loss: 0.4899, Val Acc: 0.7545
# EarlyStopping counter: 1 out of 10
# Epoch 4/100 | Train Loss: 0.4908, Train Acc: 0.7634 | Val Loss: 0.4698, Val Acc: 0.7635
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_5.pth
# Epoch 5/100 | Train Loss: 0.4777, Train Acc: 0.7598 | Val Loss: 0.4720, Val Acc: 0.7645
# EarlyStopping counter: 1 out of 10
# Epoch 6/100 | Train Loss: 0.4752, Train Acc: 0.7730 | Val Loss: 0.4551, Val Acc: 0.7750
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_5.pth
# Epoch
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_5.pth
# Epoch 29/100 | Train Loss: 0.3990, Train Acc: 0.8139 | Val Loss: 0.4228, Val Acc: 0.7935
# EarlyStopping counter: 1 out of 10
# Epoch 30/100 | Train Loss: 0.4030, Train Acc: 0.8141 | Val Loss: 0.4190, Val Acc: 0.8010
# EarlyStopping counter: 2 out of 10
# Epoch 31/100 | Train Loss: 0.3869, Train Acc: 0.8217 | Val Loss: 0.4186, Val Acc: 0.7980
# EarlyStopping counter: 3 out of 10
# Epoch 32/100 | Train Loss: 0.3987, Train Acc: 0.8115 | Val Loss: 0.4183, Val Acc: 0.8010
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_5.pth
# Epoch 33/100 | Train Loss: 0.4023, Train Acc: 0.8089 | Val Loss: 0.4118, Val Acc: 0.8050
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_5.pth
# Epoch 34/100 | Train Loss: 0.3883, Train Acc: 0.8171 | Val Loss: 0.4150, Val Acc: 0.7975
# EarlyStopping counter: 1 out of 10
# Epoch 35/100 | Train Loss: 0.3914, Train Acc: 0.8191 | Val Loss: 0.4137, Val Acc: 0.8040
# EarlyStopping counter: 2 out of 10
# Epoch 36/100 | Train Loss: 0.3934, Train Acc: 0.8171 | Val Loss: 0.4124, Val Acc: 0.7975
# EarlyStopping counter: 3 out of 10
# Epoch 37/100 | Train Loss: 0.3800, Train Acc: 0.8231 | Val Loss: 0.4132, Val Acc: 0.8000
# EarlyStopping counter: 4 out of 10
# Epoch 38/100 | Train Loss: 0.3824, Train Acc: 0.8185 | Val Loss: 0.4129, Val Acc: 0.8065
# EarlyStopping counter: 5 out of 10
# Epoch 39/100 | Train Loss: 0.3829, Train Acc: 0.8234 | Val Loss: 0.4131, Val Acc: 0.8055
# EarlyStopping counter: 6 out of 10
# Epoch 40/100 | Train Loss: 0.3843, Train Acc: 0.8235 | Val Loss: 0.4184, Val Acc: 0.7950
# EarlyStopping counter: 7 out of 10
# Epoch 41/100 | Train Loss: 0.3871, Train Acc: 0.8211 | Val Loss: 0.4150, Val Acc: 0.8080
# EarlyStopping counter: 8 out of 10
# Epoch 42/100 | Train Loss: 0.3789, Train Acc: 0.8240 | Val Loss: 0.4120, Val Acc: 0.8080
# EarlyStopping counter: 9 out of 10
# Epoch 43/100 | Train Loss: 0.3794, Train Acc: 0.8250 | Val Loss: 0.4108, Val Acc: 0.8005
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_5.pth
# Epoch 44/100 | Train Loss: 0.3774, Train Acc: 0.8255 | Val Loss: 0.4169, Val Acc: 0.8010
# EarlyStopping counter: 1 out of 10
# Epoch 45/100 | Train Loss: 0.3799, Train Acc: 0.8229 | Val Loss: 0.4107, Val Acc: 0.8015
# EarlyStopping counter: 2 out of 10
# Epoch 46/100 | Train Loss: 0.3679, Train Acc: 0.8296 | Val Loss: 0.4036, Val Acc: 0.8085
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_5.pth
# Epoch 47/100 | Train Loss: 0.3681, Train Acc: 0.8305 | Val Loss: 0.4226, Val Acc: 0.8015
# EarlyStopping counter: 1 out of 10
# Epoch 48/100 | Train Loss: 0.3678, Train Acc: 0.8334 | Val Loss: 0.4097, Val Acc: 0.8050
# EarlyStopping counter: 2 out of 10
# Epoch 49/100 | Train Loss: 0.3715, Train Acc: 0.8293 | Val Loss: 0.4128, Val Acc: 0.8090
# EarlyStopping counter: 3 out of 10
# Epoch 50/100 | Train Loss: 0.3680, Train Acc: 0.8316 | Val Loss: 0.4094, Val Acc: 0.8070
# EarlyStopping counter: 4 out of 10
# Epoch 51/100 | Train Loss: 0.3688, Train Acc: 0.8321 | Val Loss: 0.4086, Val Acc: 0.8060
# EarlyStopping counter: 5 out of 10
# Epoch 52/100 | Train Loss: 0.3636, Train Acc: 0.8324 | Val Loss: 0.4072, Val Acc: 0.8025
# EarlyStopping counter: 6 out of 10
# Epoch 53/100 | Train Loss: 0.3647, Train Acc: 0.8363 | Val Loss: 0.3974, Val Acc: 0.8130
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_MobileNet_CV_fold_5.pth
# Epoch 54/100 | Train Loss: 0.3638, Train Acc: 0.8315 | Val Loss: 0.4056, Val Acc: 0.8130
# EarlyStopping counter: 1 out of 10
# Epoch 55/100 | Train Loss: 0.3531, Train Acc: 0.8394 | Val Loss: 0.4015, Val Acc: 0.8175
# EarlyStopping counter: 2 out of 10
# Epoch 56/100 | Train Loss: 0.3617, Train Acc: 0.8356 | Val Loss: 0.4085, Val Acc: 0.8065
# EarlyStopping counter: 3 out of 10
# Epoch 57/100 | Train Loss: 0.3563, Train Acc: 0.8319 | Val Loss: 0.4002, Val Acc: 0.8165
# EarlyStopping counter: 4 out of 10
# Epoch 58/100 | Train Loss: 0.3651, Train Acc: 0.8320 | Val Loss: 0.4007, Val Acc: 0.8125
# EarlyStopping counter: 5 out of 10
# Epoch 59/100 | Train Loss: 0.3650, Train Acc: 0.8336 | Val Loss: 0.4059, Val Acc: 0.8120
# EarlyStopping counter: 6 out of 10
# Epoch 60/100 | Train Loss: 0.3505, Train Acc: 0.8420 | Val Loss: 0.4063, Val Acc: 0.8085
# EarlyStopping counter: 7 out of 10
# Epoch 61/100 | Train Loss: 0.3601, Train Acc: 0.8381 | Val Loss: 0.4058, Val Acc: 0.8100
# EarlyStopping counter: 8 out of 10
# Epoch 62/100 | Train Loss: 0.3501, Train Acc: 0.8410 | Val Loss: 0.3974, Val Acc: 0.8120
# EarlyStopping counter: 9 out of 10
# Epoch 63/100 | Train Loss: 0.3505, Train Acc: 0.8364 | Val Loss: 0.4076, Val Acc: 0.8210
# EarlyStopping counter: 10 out of 10
# Early stopping triggered. Ending training.
#
# ========== Cross-Validation Results ==========
#
#    fold  train_loss  train_accuracy  val_loss  val_accuracy
# 0     1    0.360344        0.830750  0.403227        0.8085
# 1     2    0.380679        0.821500  0.397624        0.8120
# 2     3    0.321924        0.858625  0.365682        0.8320
# 3     4    0.355321        0.835375  0.380574        0.8310
# 4     5    0.350450        0.836375  0.407561        0.8210
#
# Average Validation Accuracy: 0.8209

# %%
# Convert results to DataFrame
cv_metrics_df = pd.DataFrame(cv_metrics)

# Calculate average metrics
avg_metrics = cv_metrics_df.mean().to_dict()
avg_metrics["Fold"] = "Average"

# Add the average metrics to the DataFrame
cv_metrics_df = cv_metrics_df.append(avg_metrics, ignore_index=True)

# Save results to CSV file
csv_file_name = f"CV_Results/{file_name}.csv"
cv_metrics_df.to_csv(csv_file_name, index=False)

print(f"Cross-validation metrics saved to {csv_file_name}")
# Out:
# /tmp/job.2294878.hpc/ipykernel_2585024/1908723448.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cv_metrics_df = cv_metrics_df.append(avg_metrics, ignore_index=True)
# Cross-validation metrics saved to CV_Results/Benchmark_MobileNet_CV.csv
