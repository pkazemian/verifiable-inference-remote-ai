# %%
# Import necessary libraries
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Subset, DataLoader, Dataset
from torchvision import datasets, transforms, models
from torchvision.models import efficientnet_b0
from torchvision.models.efficientnet import SqueezeExcitation
import matplotlib.pyplot as plt
import multiprocessing
import numpy as np
from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score,  roc_auc_score, 
    cohen_kappa_score, matthews_corrcoef, confusion_matrix, average_precision_score, fbeta_score,
    precision_recall_curve, balanced_accuracy_score)
import pandas as pd
from sklearn.utils import shuffle
import random
import albumentations as A
from albumentations.pytorch import ToTensorV2
import pandas as pd
import torch_optimizer
import cv2
from skimage import measure
from torchvision.utils import make_grid
# %matplotlib inline
# Out:
# /home/pxk409/Skin_EfficientNet/GCCcore-11.3.0/lib/python3.10/site-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 1.4.23 (you have 1.4.21). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
# Check for GPU availability
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# !nvidia-smi
# Out:
# Thu Dec 19 15:10:38 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.54.03              Driver Version: 535.54.03    CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-PCIE-32GB           On  | 00000000:3B:00.0 Off |                    0 |
# | N/A   30C    P0              33W / 250W |   1090MiB / 32768MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A   2595043      C   ...on/3.10.4-GCCcore-11.3.0/bin/python     1086MiB |
# +---------------------------------------------------------------------------------------+

# %%
file_name = "Benchmark_SwinTransformer_CV"

# %%
import os

# Define directories of where the datasets reside
base_dir = '/home/pxk409/skin_lesions_13k'

# Define directories of where the training, validation and test sets reside
train_dir = os.path.join(base_dir, 'train')
test_dir = os.path.join(base_dir, 'test')

# Define directories of where the benign and malignant images reside
train_benign_dir = os.path.join(base_dir, 'train/benign')
train_malignant_dir = os.path.join(base_dir, 'train/malignant')
test_benign_dir = os.path.join(base_dir, 'test/benign')
test_malignant_dir = os.path.join(base_dir, 'test/malignant')

# %%
# Let's check the number of images in each set
print('Total training benign images:', len(os.listdir(train_benign_dir)))
print('Total training malignant images:', len(os.listdir(train_malignant_dir)))
print('Total test benign images:', len(os.listdir(test_benign_dir)))
print('Total test malignant images:', len(os.listdir(test_malignant_dir)))
# Out:
# Total training benign images: 5000
# Total training malignant images: 5000
# Total test benign images: 1500
# Total test malignant images: 1500

# %%
# Load full dataset
full_dataset = datasets.ImageFolder(root=train_dir)

# Extract labels from the dataset
#labels = [label for _, label in full_dataset.samples]

# Stratified split (80% train, 20% validation)
#split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=123456)
#train_idx, val_idx = next(split.split(np.zeros(len(labels)), labels))

# Create training and validation subsets
#train_dataset = Subset(full_dataset, train_idx)
#val_dataset = Subset(full_dataset, val_idx)

#print(f"Training set: {len(train_idx)} samples")
#print(f"Validation set: {len(val_idx)} samples")

# Count the number of samples per class in each split
#train_classes = [full_dataset.targets[idx] for idx in train_dataset.indices]
#val_classes = [full_dataset.targets[idx] for idx in val_dataset.indices]

#print(f"Training set class counts: {np.bincount(train_classes)}")
#print(f"Validation set class counts: {np.bincount(val_classes)}")

# %%
# Custom transform to integrate Albumentations with PyTorch
class AlbumentationsTransform:
    def __init__(self, augmentations):
        self.augmentations = A.Compose(augmentations)

    def __call__(self, image):
        image = np.array(image)  # Convert PIL Image to NumPy array
        augmented = self.augmentations(image=image)
        return augmented["image"]

# Simple augmentations for training
simple_transform = AlbumentationsTransform([
    A.RandomResizedCrop(height=224, width=224, scale=(0.8, 1.0), p=1.0),  # Random crop and resize
    A.HorizontalFlip(p=0.5),  # Horizontal flip
    A.VerticalFlip(p=0.5),  # Vertical flip
    #A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1, p=0.5),  # Color jitter
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  # Normalize to match pre-trained model
    ToTensorV2(),  # Convert to PyTorch tensor and ensure dtype=torch.float32
])


# Use AlbumentationsTransform directly in the loaders for consistency
train_transform = simple_transform

# Albumentations augmentations for validation and test
albumentations_val_test_transform = AlbumentationsTransform([
    A.Resize(height=224, width=224),  # Resize to EfficientNet input size
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  # Normalize to match pre-trained model
    ToTensorV2()  # Convert to PyTorch tensor
])

test_val_transform = albumentations_val_test_transform

# %%
class TransformDataset(Dataset):
    def __init__(self, dataset, transform):
        """
        Args:
            dataset: Original dataset (e.g., Subset of ImageFolder).
            transform: Transform to be applied to the images in the dataset.
        """
        self.dataset = dataset
        self.transform = transform

    def __getitem__(self, idx):
        image, label = self.dataset[idx]
        if self.transform:
            image = self.transform(image)
        return image, label

    def __len__(self):
        return len(self.dataset)

# %%
# Wrap subsets with the respective transforms
#train_dataset = TransformDataset(train_dataset, train_transform)
#val_dataset = TransformDataset(val_dataset, test_val_transform)

# %%
# Load and prepare the test dataset
#test_dataset = datasets.ImageFolder(root=test_dir, transform=test_val_transform)
test_dataset = datasets.ImageFolder(root=test_dir)
test_dataset = TransformDataset(test_dataset, test_val_transform)

# %%
# Create data loaders
batch_size = 64
#num_cpus = multiprocessing.cpu_count()  # Use all CPU cores
#print(f"Number of CPU cores: {num_cpus}")
#num_workers = 16


#train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
#val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
#train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=True)
#val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=True)
#test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=True)

# %%
def initialize_model():
    # Load pre-trained Swin Transformer Base
    model = models.swin_b(weights=models.Swin_B_Weights.DEFAULT)  # Swin Transformer Base

    # Freeze the feature extractor (encoder)
    for param in model.parameters():
        param.requires_grad = False

    # Replace the classifier (head) for binary classification
    # Swin Transformer uses a "head" with a Linear layer for classification
    model.head = nn.Sequential(
        nn.Linear(model.head.in_features, 512),  # Custom intermediate layer
        nn.ReLU(),
        nn.Dropout(0.5),
        nn.Linear(512, 256),  # Another intermediate layer
        nn.ReLU(),
        nn.Dropout(0.5),
        nn.Linear(256, 2)  # Output layer for binary classification
    )

    # Ensure the classifier (head) remains trainable
    for param in model.head.parameters():
        param.requires_grad = True

    # Move model to device
    model = model.to(device)
    return model

model = initialize_model()

# %%
# Function to count trainable and non-trainable parameters
def count_trainable_non_trainable_parameters(model):
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    non_trainable = sum(p.numel() for p in model.parameters() if not p.requires_grad)
    return trainable, non_trainable

# Count parameters in the Swin Transformer backbone (feature extractor)
backbone_trainable, backbone_non_trainable = count_trainable_non_trainable_parameters(model.features)
print(f"Backbone (feature extractor):\n"
      f"  Trainable parameters: {backbone_trainable:,}\n"
      f"  Non-trainable parameters: {backbone_non_trainable:,}")

# Count parameters in the classifier head
classifier_trainable, classifier_non_trainable = count_trainable_non_trainable_parameters(model.head)
print(f"Classifier head:\n"
      f"  Trainable parameters: {classifier_trainable:,}\n"
      f"  Non-trainable parameters: {classifier_non_trainable:,}")

# Count parameters in the entire model
total_trainable, total_non_trainable = count_trainable_non_trainable_parameters(model)
print(f"Whole model:\n"
      f"  Trainable parameters: {total_trainable:,}\n"
      f"  Non-trainable parameters: {total_non_trainable:,}")
# Out:
# Backbone (feature extractor):
#   Trainable parameters: 0
#   Non-trainable parameters: 86,741,176
# Classifier head:
#   Trainable parameters: 656,642
#   Non-trainable parameters: 0
# Whole model:
#   Trainable parameters: 656,642
#   Non-trainable parameters: 86,743,224

# %%
# Early Stopping
class EarlyStopping:
    def __init__(self, patience, delta, path):
        """
        Args:
            patience (int): Number of epochs to wait after last improvement.
            delta (float): Minimum change in monitored metric to qualify as an improvement.
            path (str): Path to save the best model.
        """
        self.patience = patience
        self.delta = delta
        self.path = path
        self.counter = 0
        self.best_score = None
        self.early_stop = False

    def __call__(self, val_loss, model):
        score = -val_loss  # Early stopping is based on minimizing validation loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f"EarlyStopping counter: {self.counter} out of {self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        """Saves model when validation loss decreases."""
        print(f"Validation loss decreased. Saving model to {self.path}")
        torch.save(model.state_dict(), self.path)


# Set the path for saving best_model.pth
#current_dir = os.getcwd()
#model_save_path = os.path.join(current_dir, 'best_model2.pth')

# Initialize EarlyStopping
#early_stopping = EarlyStopping(patience=5, delta=0.001, path=model_save_path)

# %%
# Helper function to evaluate a dataset
def evaluate_model(model, data_loader, device):
    model.eval()  # Set model to evaluation mode
    all_labels = []
    all_preds = []
    all_probs = []

    with torch.no_grad():
        for images, labels in data_loader:
            images, labels = images.to(device), labels.to(device)

            # Forward pass
            outputs = model(images)
            probs = torch.softmax(outputs, dim=1)[:, 1]  # Probabilities for the positive class
            _, preds = torch.max(outputs, 1)

            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())

    return np.array(all_labels), np.array(all_preds), np.array(all_probs)

# Helper function to calculate selected metrics
def calculate_metrics(labels, preds, probs):
    accuracy = accuracy_score(labels, preds)
    precision = precision_score(labels, preds)
    recall = recall_score(labels, preds)
    f1 = f1_score(labels, preds)
    f2 = fbeta_score(labels, preds, beta=2)
    auc = roc_auc_score(labels, probs)
    specificity = recall_score(labels, preds, pos_label=0)
    npv = precision_score(labels, preds, pos_label=0)

    return recall, precision, accuracy, f1, f2, auc, specificity, npv

# %%
# Training loop with 5-fold cross-validation
cv_results = []
cv_metrics = []
n_splits = 5
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=123456)

# Extract labels from the dataset
labels = [label for _, label in full_dataset.samples]

# Cross-validation loop
for fold, (train_idx, val_idx) in enumerate(skf.split(np.zeros(len(labels)), labels), 1):
    print(f"\n========== Fold {fold} ==========\n")
    
    # Create training and validation subsets for this fold
    train_dataset = Subset(full_dataset, train_idx)
    val_dataset = Subset(full_dataset, val_idx)
    
    # Apply transformations
    train_dataset = TransformDataset(train_dataset, train_transform)
    val_dataset = TransformDataset(val_dataset, test_val_transform)
    
    # Create data loaders
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    
    # Initialize model and optimizer for each fold
    model = initialize_model()
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    # EarlyStopping initialization
    early_stopping = EarlyStopping(patience=10, delta=0.0001, path=os.path.join(os.getcwd(), f"{file_name}_fold_{fold}.pth"))

    # Training loop
    num_epochs = 100
    train_losses = []
    val_losses = []
    
    for epoch in range(num_epochs):
        # Training phase
        model.train()
        train_loss = 0
        train_correct = 0
        
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            
            # Forward pass
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            train_correct += torch.sum(preds == labels)
        
        train_loss /= len(train_loader)
        train_accuracy = train_correct.double() / len(train_dataset)
        train_losses.append(train_loss)
        
        # Validation phase
        model.eval()
        val_loss = 0
        val_correct = 0
        
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                
                outputs = model(images)
                loss = criterion(outputs, labels)
                
                val_loss += loss.item()
                _, preds = torch.max(outputs, 1)
                val_correct += torch.sum(preds == labels)
        
        val_loss /= len(val_loader)
        val_accuracy = val_correct.double() / len(val_dataset)
        val_losses.append(val_loss)
        
        print(f"Epoch {epoch + 1}/{num_epochs} | "
              f"Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.4f} | "
              f"Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.4f}")
        
        # Call EarlyStopping
        early_stopping(val_loss, model)
        if early_stopping.early_stop:
            print("Early stopping triggered. Ending training.")
            break
    
    # Store results for this fold
    cv_results.append({
        "fold": fold,
        "train_loss": train_loss,
        "train_accuracy": train_accuracy.item(),
        "val_loss": val_loss,
        "val_accuracy": val_accuracy.item()
        })
        
    # Load the best model for evaluation
    model.load_state_dict(torch.load(f"{file_name}_fold_{fold}.pth", weights_only=True))

    # Evaluate on validation set
    labels, preds, probs = evaluate_model(model, val_loader, device)
    metrics = calculate_metrics(labels, preds, probs)
    recall, precision, accuracy, f1, f2, auc, specificity, npv = metrics

    # Record metrics for the fold
    cv_metrics.append({
        "Fold": fold,
        "Recall": recall,
        "Precision": precision,
        "Accuracy": accuracy,
        "F1 Score": f1,
        "F2 Score": f2,
        "AUC": auc,
        "Specificity": specificity,
        "NPV": npv,
    })

# Summarize cross-validation results
df_cv_results = pd.DataFrame(cv_results)
print("\n========== Cross-Validation Results ==========\n")
print(df_cv_results)

print("\nAverage Validation Accuracy: {:.4f}".format(df_cv_results["val_accuracy"].mean()))
# Out:
# ========== Fold 1 ==========
#
# Epoch 1/100 | Train Loss: 0.5481, Train Acc: 0.7195 | Val Loss: 0.4551, Val Acc: 0.7885
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_1.pth
# Epoch 2/100 | Train Loss: 0.4993, Train Acc: 0.7572 | Val Loss: 0.4578, Val Acc: 0.7790
# EarlyStopping counter: 1 out of 10
# Epoch 3/100 | Train Loss: 0.4822, Train Acc: 0.7630 | Val Loss: 0.4234, Val Acc: 0.7935
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_1.pth
# Epoch 4/100 | Train Loss: 0.4710, Train Acc: 0.7730 | Val Loss: 0.4192, Val Acc: 0.8035
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_1.pth
# Epoch 5/100 | Train Loss: 0.4621, Train Acc: 0.7774 | Val Loss: 0.4136, Val Acc: 0.8065
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_1.pth
# Epoch 6/100 | Train Loss: 0.4601, Train Acc: 0.7776 | Val Loss: 0.4259, Val Acc: 0.8105
# EarlyStopping counter: 1 out of 10
# Epoch 7/100 | Train Loss: 0.4535, Train Acc: 0.7823 | Val Loss: 0.3963, Val Acc: 0.8135
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_1.pth
# Epoch 8/100 | Train Loss: 0.4422, Train Acc: 0.7896 | Val Loss: 0.4178, Val Acc: 0.8000
# EarlyStopping counter: 1 out of 10
# Epoch 9/100 | Train Loss: 0.4391, Train Acc: 0.7941 | Val Loss: 0.3967, Val Acc: 0.8140
# EarlyStopping counter: 2 out of 10
# Epoch 10/100 | Train Loss: 0.4390, Train Acc: 0.7906 | Val Loss: 0.4079, Val Acc: 0.8020
# EarlyStopping counter: 3 out of 10
# Epoch 11/100 | Train Loss: 0.4357, Train Acc: 0.7910 | Val Loss: 0.3961, Val Acc: 0.8185
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_1.pth
# Epoch 12/100 | Train Loss: 0.4270, Train Acc: 0.7988 | Val Loss: 0.3891, Val Acc: 0.8220
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_1.pth
# Epoch 13/100 | Train Loss: 0.4266, Train Acc: 0.7966 | Val Loss: 0.3935, Val Acc: 0.8200
# EarlyStopping counter: 1 out of 10
# Epoch 14/100 | Train Loss: 0.4228, Train Acc: 0.8039 | Val Loss: 0.3877, Val Acc: 0.8225
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_1.pth
# Epoch 15/100 | Train Loss: 0.4185, Train Acc: 0.8026 | Val Loss: 0.3909, Val Acc: 0.8215
# EarlyStopping counter: 1 out of 10
# Epoch 16/100 | Train Loss: 0.4208, Train Acc: 0.8046 | Val Loss: 0.3865, Val Acc: 0.8240
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_1.pth
# Epoch 17/100 | Train Loss: 0.4092, Train Acc: 0.8101 | Val Loss: 0.3803, Val Acc: 0.8325
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_1.pth
# Epoch 18/100 | Train Loss: 0.4061, Train Acc: 0.8096 | Val Loss: 0.3768, Val Acc: 0.8250
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_1.pth
# Epoch 19/100 | Train Loss: 0.4068, Train Acc: 0.8115 | Val Loss: 0.3726, Val Acc: 0.8320
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_1.pth
# Epoch 20/100 | Train Loss: 0.3976, Train Acc: 0.8100 | Val Loss: 0.3724, Val Acc: 0.8365
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_1.pth
# Epoch 21/100 | Train Loss: 0.3993, Train Acc: 0.8135 | Val Loss: 0.3940, Val Acc: 0.8235
# EarlyStopping counter: 1 out of 10
# Epoch 22/100 | Train Loss: 0.3978, Train Acc: 0.8185 | Val Loss: 0.4044, Val Acc: 0.8155
# EarlyStopping counter: 2 out of 10
# Epoch 23/100 | Train Loss: 0.3953, Train Acc: 0.8211 | Val Loss: 0.3772, Val Acc: 0.8315
# EarlyStopping counter: 3 out of 10
# Epoch 24/100 | Train Loss: 0.3939, Train Acc: 0.8193 | Val Loss: 0.3719, Val Acc: 0.8335
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_1.pth
# Epoch 25/100 | Train Loss: 0.3833, Train Acc: 0.8193 | Val Loss: 0.3822, Val Acc: 0.8275
# EarlyStopping counter: 1 out of 10
# Epoch 26/100 | Train Loss: 0.3871, Train Acc: 0.8209 | Val Loss: 0.3778, Val Acc: 0.8275
# EarlyStopping counter: 2 out of 10
# Epoch 27/100 | Train Loss: 0.3794, Train Acc: 0.8239 | Val Loss: 0.3795, Val Acc: 0.8310
# EarlyStopping counter: 3 out of 10
# Epoch 28/100 | Train Loss: 0.3864, Train Acc: 0.8207 | Val Loss: 0.3689, Val Acc: 0.8320
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_1.pth
# Epoch 29/100 | Train Loss: 0.3799, Train Acc: 0.8319 | Val Loss: 0.3683, Val Acc: 0.8345
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_1.pth
# Epoch 30/100 | Train Loss: 0.3807, Train Acc: 0.8233 | Val Loss: 0.3685, Val Acc: 0.8400
# EarlyStopping counter: 1 out of 10
# Epoch 31/100 | Train Loss: 0.3711, Train Acc: 0.8266 | Val Loss: 0.3856, Val Acc: 0.8250
# EarlyStopping counter: 2 out of 10
# Epoch 32/100 | Train Loss: 0.3755, Train Acc: 0.8236 | Val Loss: 0.3666, Val Acc: 0.8380
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_1.pth
# Epoch 33/100 | Train Loss: 0.3716, Train Acc: 0.8286 | Val Loss: 0.3771, Val Acc: 0.8280
# EarlyStopping counter: 1 out of 10
# Epoch 34/100 | Train Loss: 0.3750, Train Acc: 0.8310 | Val Loss: 0.3790, Val Acc: 0.8300
# EarlyStopping counter: 2 out of 10
# Epoch 35/100 | Train Loss: 0.3717, Train Acc: 0.8296 | Val Loss: 0.3752, Val Acc: 0.8340
# EarlyStopping counter: 3 out of 10
# Epoch 36/100 | Train Loss: 0.3720, Train Acc: 0.8277 | Val Loss: 0.3647, Val Acc: 0.8445
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_1.pth
# Epoch 37/100 | Train Loss: 0.3615, Train Acc: 0.8326 | Val Loss: 0.3586, Val Acc: 0.8460
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_1.pth
# Epoch 38/100 | Train Loss: 0.3725, Train Acc: 0.8314 | Val Loss: 0.3665, Val Acc: 0.8410
# EarlyStopping counter: 1 out of 10
# Epoch 39/100 | Train Loss: 0.3702, Train Acc: 0.8290 | Val Loss: 0.3690, Val Acc: 0.8375
# EarlyStopping counter: 2 out of 10
# Epoch 40/100 | Train Loss: 0.3658, Train Acc: 0.8339 | Val Loss: 0.3753, Val Acc: 0.8335
# EarlyStopping counter: 3 out of 10
# Epoch 41/100 | Train Loss: 0.3591, Train Acc: 0.8403 | Val Loss: 0.3548, Val Acc: 0.8485
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_1.pth
# Epoch 42/100 | Train Loss: 0.3641, Train Acc: 0.8324 | Val Loss: 0.3603, Val Acc: 0.8470
# EarlyStopping counter: 1 out of 10
# Epoch 43/100 | Train Loss: 0.3560, Train Acc: 0.8445 | Val Loss: 0.3633, Val Acc: 0.8480
# EarlyStopping counter: 2 out of 10
# Epoch 44/100 | Train Loss: 0.3516, Train Acc: 0.8385 | Val Loss: 0.3549, Val Acc: 0.8415
# EarlyStopping counter: 3 out of 10
# Epoch 45/100 | Train Loss: 0.3470, Train Acc: 0.8390 | Val Loss: 0.3595, Val Acc: 0.8385
# EarlyStopping counter: 4 out of 10
# Epoch 46/100 | Train Loss: 0.3523, Train Acc: 0.8420 | Val Loss: 0.3619, Val Acc: 0.8440
# EarlyStopping counter: 5 out of 10
# Epoch 47/100 | Train Loss: 0.3489, Train Acc: 0.8375 | Val Loss: 0.3627, Val Acc: 0.8440
# EarlyStopping counter: 6 out of 10
# Epoch 48/100 | Train Loss: 0.3472, Train Acc: 0.8415 | Val Loss: 0.3593, Val Acc: 0.8445
# EarlyStopping counter: 7 out of 10
# Epoch 49/100 | Train Loss: 0.3535, Train Acc: 0.8414 | Val Loss: 0.3532, Val Acc: 0.8440
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_1.pth
# Epoch 50/100 | Train Loss: 0.3462, Train Acc: 0.8427 | Val Loss: 0.3523, Val Acc: 0.8470
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_1.pth
# Epoch 51/100 | Train Loss: 0.3490, Train Acc: 0.8425 | Val Loss: 0.3579, Val Acc: 0.8415
# EarlyStopping counter: 1 out of 10
# Epoch 52/100 | Train Loss: 0.3477, Train Acc: 0.8453 | Val Loss: 0.3645, Val Acc: 0.8375
# EarlyStopping counter: 2 out of 10
# Epoch 53/100 | Train Loss: 0.3417, Train Acc: 0.8415 | Val Loss: 0.3522, Val Acc: 0.8415
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_1.pth
# Epoch 54/100 | Train Loss: 0.3353, Train Acc: 0.8463 | Val Loss: 0.3527, Val Acc: 0.8460
# EarlyStopping counter: 1 out of 10
# Epoch 55/100 | Train Loss: 0.3413, Train Acc: 0.8453 | Val Loss: 0.3598, Val Acc: 0.8505
# EarlyStopping counter: 2 out of 10
# Epoch 56/100 | Train Loss: 0.3334, Train Acc: 0.8498 | Val Loss: 0.3629, Val Acc: 0.8450
# EarlyStopping counter: 3 out of 10
# Epoch 57/100 | Train Loss: 0.3408, Train Acc: 0.8471 | Val Loss: 0.3758, Val Acc: 0.8420
# EarlyStopping counter: 4 out of 10
# Epoch 58/100 | Train Loss: 0.3433, Train Acc: 0.8501 | Val Loss: 0.3569, Val Acc: 0.8395
# EarlyStopping counter: 5 out of 10
# Epoch 59/100 | Train Loss: 0.3260, Train Acc: 0.8546 | Val Loss: 0.3466, Val Acc: 0.8480
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_1.pth
# Epoch 60/100 | Train Loss: 0.3345, Train Acc: 0.8544 | Val Loss: 0.3598, Val Acc: 0.8435
# EarlyStopping counter: 1 out of 10
# Epoch 61/100 | Train Loss: 0.3350, Train Acc: 0.8485 | Val Loss: 0.3547, Val Acc: 0.8490
# EarlyStopping counter: 2 out of 10
# Epoch 62/100 | Train Loss: 0.3361, Train Acc: 0.8471 | Val Loss: 0.3539, Val Acc: 0.8485
# EarlyStopping counter: 3 out of 10
# Epoch 63/100 | Train Loss: 0.3400, Train Acc: 0.8484 | Val Loss: 0.3544, Val Acc: 0.8465
# EarlyStopping counter: 4 out of 10
# Epoch 64/100 | Train Loss: 0.3252, Train Acc: 0.8511 | Val Loss: 0.3504, Val Acc: 0.8445
# EarlyStopping counter: 5 out of 10
# Epoch 65/100 | Train Loss: 0.3275, Train Acc: 0.8509 | Val Loss: 0.3597, Val Acc: 0.8405
# EarlyStopping counter: 6 out of 10
# Epoch 66/100 | Train Loss: 0.3281, Train Acc: 0.8498 | Val Loss: 0.3591, Val Acc: 0.8425
# EarlyStopping counter: 7 out of 10
# Epoch 67/100 | Train Loss: 0.3280, Train Acc: 0.8515 | Val Loss: 0.3578, Val Acc: 0.8440
# EarlyStopping counter: 8 out of 10
# Epoch 68/100 | Train Loss: 0.3232, Train Acc: 0.8565 | Val Loss: 0.3545, Val Acc: 0.8475
# EarlyStopping counter: 9 out of 10
# Epoch 69/100 | Train Loss: 0.3277, Train Acc: 0.8524 | Val Loss: 0.3555, Val Acc: 0.8465
# EarlyStopping counter: 10 out of 10
# Early stopping triggered. Ending training.
#
# ========== Fold 2 ==========
#
# Epoch 1/100 | Train Loss: 0.5487, Train Acc: 0.7215 | Val Loss: 0.4725, Val Acc: 0.7790
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_2.pth
# Epoch 2/100 | Train Loss: 0.4979, Train Acc: 0.7538 | Val Loss: 0.4720, Val Acc: 0.7750
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_2.pth
# Epoch 3/100 | Train Loss: 0.4788, Train Acc: 0.7696 | Val Loss: 0.4722, Val Acc: 0.7735
# EarlyStopping counter: 1 out of 10
# Epoch 4/100 | Train Loss: 0.4760, Train Acc: 0.7679 | Val Loss: 0.4618, Val Acc: 0.7855
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_2.pth
# Epoch 5/100 | Train Loss: 0.4606, Train Acc: 0.7835 | Val Loss: 0.4467, Val Acc: 0.7860
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_2.pth
# Epoch 6/100 | Train Loss: 0.4501, Train Acc: 0.7820 | Val Loss: 0.4437, Val Acc: 0.7935
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_2.pth
# Epoch 7/100 | Train Loss: 0.4458, Train Acc: 0.7861 | Val Loss: 0.4375, Val Acc: 0.7950
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_2.pth
# Epoch 8/100 | Train Loss: 0.4414, Train Acc: 0.7890 | Val Loss: 0.4333, Val Acc: 0.7965
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_2.pth
# Epoch 9/100 | Train Loss: 0.4326, Train Acc: 0.7975 | Val Loss: 0.4617, Val Acc: 0.7655
# EarlyStopping counter: 1 out of 10
# Epoch 10/100 | Train Loss: 0.4335, Train Acc: 0.8007 | Val Loss: 0.4378, Val Acc: 0.7990
# EarlyStopping counter: 2 out of 10
# Epoch 11/100 | Train Loss: 0.4275, Train Acc: 0.7999 | Val Loss: 0.4318, Val Acc: 0.7995
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_2.pth
# Epoch 12/100 | Train Loss: 0.4362, Train Acc: 0.7943 | Val Loss: 0.4246, Val Acc: 0.8020
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_2.pth
# Epoch 13/100 | Train Loss: 0.4220, Train Acc: 0.8025 | Val Loss: 0.4178, Val Acc: 0.8050
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_2.pth
# Epoch 14/100 | Train Loss: 0.4105, Train Acc: 0.8094 | Val Loss: 0.4296, Val Acc: 0.7915
# EarlyStopping counter: 1 out of 10
# Epoch 15/100 | Train Loss: 0.4189, Train Acc: 0.8016 | Val Loss: 0.4181, Val Acc: 0.8060
# EarlyStopping counter: 2 out of 10
# Epoch 16/100 | Train Loss: 0.4039, Train Acc: 0.8111 | Val Loss: 0.4135, Val Acc: 0.8050
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_2.pth
# Epoch 17/100 | Train Loss: 0.4101, Train Acc: 0.8084 | Val Loss: 0.4146, Val Acc: 0.8035
# EarlyStopping counter: 1 out of 10
# Epoch 18/100 | Train Loss: 0.4064, Train Acc: 0.8066 | Val Loss: 0.4183, Val Acc: 0.8065
# EarlyStopping counter: 2 out of 10
# Epoch 19/100 | Train Loss: 0.4083, Train Acc: 0.8104 | Val Loss: 0.4150, Val Acc: 0.8020
# EarlyStopping counter: 3 out of 10
# Epoch 20/100 | Train Loss: 0.3989, Train Acc: 0.8146 | Val Loss: 0.4261, Val Acc: 0.7980
# EarlyStopping counter: 4 out of 10
# Epoch 21/100 | Train Loss: 0.3925, Train Acc: 0.8219 | Val Loss: 0.4056, Val Acc: 0.8040
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_2.pth
# Epoch 22/100 | Train Loss: 0.3933, Train Acc: 0.8151 | Val Loss: 0.4036, Val Acc: 0.8130
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_2.pth
# Epoch 23/100 | Train Loss: 0.3993, Train Acc: 0.8187 | Val Loss: 0.4050, Val Acc: 0.8095
# EarlyStopping counter: 1 out of 10
# Epoch 24/100 | Train Loss: 0.3881, Train Acc: 0.8143 | Val Loss: 0.4160, Val Acc: 0.8050
# EarlyStopping counter: 2 out of 10
# Epoch 25/100 | Train Loss: 0.3927, Train Acc: 0.8255 | Val Loss: 0.4038, Val Acc: 0.8170
# EarlyStopping counter: 3 out of 10
# Epoch 26/100 | Train Loss: 0.3815, Train Acc: 0.8235 | Val Loss: 0.4139, Val Acc: 0.8040
# EarlyStopping counter: 4 out of 10
# Epoch 27/100 | Train Loss: 0.3856, Train Acc: 0.8215 | Val Loss: 0.3985, Val Acc: 0.8170
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_2.pth
# Epoch 28/100 | Train Loss: 0.3832, Train Acc: 0.8207 | Val Loss: 0.3911, Val Acc: 0.8215
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_2.pth
# Epoch 29/100 | Train Loss: 0.3808, Train Acc: 0.8285 | Val Loss: 0.3966, Val Acc: 0.8220
# EarlyStopping counter: 1 out of 10
# Epoch 30/100 | Train Loss: 0.3799, Train Acc: 0.8227 | Val Loss: 0.3973, Val Acc: 0.8095
# EarlyStopping counter: 2 out of 10
# Epoch 31/100 | Train Loss: 0.3860, Train Acc: 0.8183 | Val Loss: 0.3989, Val Acc: 0.8125
# EarlyStopping counter: 3 out of 10
# Epoch 32/100 | Train Loss: 0.3735, Train Acc: 0.8277 | Val Loss: 0.4003, Val Acc: 0.8115
# EarlyStopping counter: 4 out of 10
# Epoch 33/100 | Train Loss: 0.3582, Train Acc: 0.8383 | Val Loss: 0.3914, Val Acc: 0.8230
# EarlyStopping counter: 5 out of 10
# Epoch 34/100 | Train Loss: 0.3630, Train Acc: 0.8355 | Val Loss: 0.3901, Val Acc: 0.8200
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_2.pth
# Epoch 35/100 | Train Loss: 0.3693, Train Acc: 0.8319 | Val Loss: 0.3924, Val Acc: 0.8235
# EarlyStopping counter: 1 out of 10
# Epoch 36/100 | Train Loss: 0.3685, Train Acc: 0.8317 | Val Loss: 0.3917, Val Acc: 0.8185
# EarlyStopping counter: 2 out of 10
# Epoch 37/100 | Train Loss: 0.3564, Train Acc: 0.8334 | Val Loss: 0.3949, Val Acc: 0.8175
# EarlyStopping counter: 3 out of 10
# Epoch 38/100 | Train Loss: 0.3712, Train Acc: 0.8325 | Val Loss: 0.4079, Val Acc: 0.8140
# EarlyStopping counter: 4 out of 10
# Epoch 39/100 | Train Loss: 0.3576, Train Acc: 0.8343 | Val Loss: 0.3920, Val Acc: 0.8265
# EarlyStopping counter: 5 out of 10
# Epoch 40/100 | Train Loss: 0.3591, Train Acc: 0.8373 | Val Loss: 0.4009, Val Acc: 0.8230
# EarlyStopping counter: 6 out of 10
# Epoch 41/100 | Train Loss: 0.3531, Train Acc: 0.8395 | Val Loss: 0.4104, Val Acc: 0.8030
# EarlyStopping counter: 7 out of 10
# Epoch 42/100 | Train Loss: 0.3605, Train Acc: 0.8340 | Val Loss: 0.3908, Val Acc: 0.8280
# EarlyStopping counter: 8 out of 10
# Epoch 43/100 | Train Loss: 0.3499, Train Acc: 0.8396 | Val Loss: 0.3942, Val Acc: 0.8200
# EarlyStopping counter: 9 out of 10
# Epoch 44/100 | Train Loss: 0.3559, Train Acc: 0.8370 | Val Loss: 0.4020, Val Acc: 0.8140
# EarlyStopping counter: 10 out of 10
# Early stopping triggered. Ending training.
#
# ========== Fold 3 ==========
#
# Epoch 1/100 | Train Loss: 0.5472, Train Acc: 0.7234 | Val Loss: 0.4874, Val Acc: 0.7535
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_3.pth
# Epoch 2/100 | Train Loss: 0.4871, Train Acc: 0.7645 | Val Loss: 0.4629, Val Acc: 0.7830
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_3.pth
# Epoch 3/100 | Train Loss: 0.4836, Train Acc: 0.7648 | Val Loss: 0.4544, Val Acc: 0.7830
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_3.pth
# Epoch 4/100 | Train Loss: 0.4683, Train Acc: 0.7745 | Val Loss: 0.4360, Val Acc: 0.7845
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_3.pth
# Epoch 5/100 | Train Loss: 0.4580, Train Acc: 0.7816 | Val Loss: 0.4407, Val Acc: 0.7955
# EarlyStopping counter: 1 out of 10
# Epoch 6/100 | Train Loss: 0.4511, Train Acc: 0.7893 | Val Loss: 0.4289, Val Acc: 0.7980
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_3.pth
# Epoch 7/100 | Train Loss: 0.4449, Train Acc: 0.7926 | Val Loss: 0.4228, Val Acc: 0.7895
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_3.pth
# Epoch 8/100 | Train Loss: 0.4423, Train Acc: 0.7911 | Val Loss: 0.4234, Val Acc: 0.8030
# EarlyStopping counter: 1 out of 10
# Epoch 9/100 | Train Loss: 0.4356, Train Acc: 0.7908 | Val Loss: 0.4336, Val Acc: 0.7860
# EarlyStopping counter: 2 out of 10
# Epoch 10/100 | Train Loss: 0.4303, Train Acc: 0.7986 | Val Loss: 0.4195, Val Acc: 0.8015
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_3.pth
# Epoch 11/100 | Train Loss: 0.4285, Train Acc: 0.7948 | Val Loss: 0.4033, Val Acc: 0.8110
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_3.pth
# Epoch 12/100 | Train Loss: 0.4264, Train Acc: 0.7993 | Val Loss: 0.4082, Val Acc: 0.8065
# EarlyStopping counter: 1 out of 10
# Epoch 13/100 | Train Loss: 0.4223, Train Acc: 0.8061 | Val Loss: 0.4083, Val Acc: 0.8015
# EarlyStopping counter: 2 out of 10
# Epoch 14/100 | Train Loss: 0.4208, Train Acc: 0.8035 | Val Loss: 0.4108, Val Acc: 0.8020
# EarlyStopping counter: 3 out of 10
# Epoch 15/100 | Train Loss: 0.4222, Train Acc: 0.7981 | Val Loss: 0.3985, Val Acc: 0.8135
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_3.pth
# Epoch 16/100 | Train Loss: 0.4038, Train Acc: 0.8121 | Val Loss: 0.3972, Val Acc: 0.8125
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_3.pth
# Epoch 17/100 | Train Loss: 0.4047, Train Acc: 0.8149 | Val Loss: 0.4025, Val Acc: 0.8080
# EarlyStopping counter: 1 out of 10
# Epoch 18/100 | Train Loss: 0.4037, Train Acc: 0.8090 | Val Loss: 0.4056, Val Acc: 0.8195
# EarlyStopping counter: 2 out of 10
# Epoch 19/100 | Train Loss: 0.4069, Train Acc: 0.8101 | Val Loss: 0.4033, Val Acc: 0.8130
# EarlyStopping counter: 3 out of 10
# Epoch 20/100 | Train Loss: 0.4002, Train Acc: 0.8085 | Val Loss: 0.4028, Val Acc: 0.8130
# EarlyStopping counter: 4 out of 10
# Epoch 21/100 | Train Loss: 0.3983, Train Acc: 0.8156 | Val Loss: 0.3877, Val Acc: 0.8195
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_3.pth
# Epoch 22/100 | Train Loss: 0.4040, Train Acc: 0.8059 | Val Loss: 0.3952, Val Acc: 0.8220
# EarlyStopping counter: 1 out of 10
# Epoch 23/100 | Train Loss: 0.3919, Train Acc: 0.8187 | Val Loss: 0.4113, Val Acc: 0.8110
# EarlyStopping counter: 2 out of 10
# Epoch 24/100 | Train Loss: 0.3929, Train Acc: 0.8144 | Val Loss: 0.3870, Val Acc: 0.8185
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_3.pth
# Epoch 25/100 | Train Loss: 0.3885, Train Acc: 0.8193 | Val Loss: 0.3932, Val Acc: 0.8175
# EarlyStopping counter: 1 out of 10
# Epoch 26/100 | Train Loss: 0.3901, Train Acc: 0.8147 | Val Loss: 0.3780, Val Acc: 0.8310
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_3.pth
# Epoch 27/100 | Train Loss: 0.3819, Train Acc: 0.8197 | Val Loss: 0.3946, Val Acc: 0.8265
# EarlyStopping counter: 1 out of 10
# Epoch 28/100 | Train Loss: 0.3861, Train Acc: 0.8210 | Val Loss: 0.3968, Val Acc: 0.8220
# EarlyStopping counter: 2 out of 10
# Epoch 29/100 | Train Loss: 0.3861, Train Acc: 0.8185 | Val Loss: 0.3908, Val Acc: 0.8215
# EarlyStopping counter: 3 out of 10
# Epoch 30/100 | Train Loss: 0.3883, Train Acc: 0.8189 | Val Loss: 0.3764, Val Acc: 0.8340
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_3.pth
# Epoch 31/100 | Train Loss: 0.3739, Train Acc: 0.8260 | Val Loss: 0.3716, Val Acc: 0.8370
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_3.pth
# Epoch 32/100 | Train Loss: 0.3713, Train Acc: 0.8277 | Val Loss: 0.3836, Val Acc: 0.8270
# EarlyStopping counter: 1 out of 10
# Epoch 33/100 | Train Loss: 0.3765, Train Acc: 0.8291 | Val Loss: 0.3824, Val Acc: 0.8260
# EarlyStopping counter: 2 out of 10
# Epoch 34/100 | Train Loss: 0.3749, Train Acc: 0.8285 | Val Loss: 0.3848, Val Acc: 0.8330
# EarlyStopping counter: 3 out of 10
# Epoch 35/100 | Train Loss: 0.3776, Train Acc: 0.8283 | Val Loss: 0.3749, Val Acc: 0.8315
# EarlyStopping counter: 4 out of 10
# Epoch 36/100 | Train Loss: 0.3666, Train Acc: 0.8324 | Val Loss: 0.3719, Val Acc: 0.8360
# EarlyStopping counter: 5 out of 10
# Epoch 37/100 | Train Loss: 0.3610, Train Acc: 0.8367 | Val Loss: 0.3752, Val Acc: 0.8345
# EarlyStopping counter: 6 out of 10
# Epoch 38/100 | Train Loss: 0.3619, Train Acc: 0.8341 | Val Loss: 0.3732, Val Acc: 0.8265
# EarlyStopping counter: 7 out of 10
# Epoch 39/100 | Train Loss: 0.3619, Train Acc: 0.8327 | Val Loss: 0.3844, Val Acc: 0.8350
# EarlyStopping counter: 8 out of 10
# Epoch 40/100 | Train Loss: 0.3667, Train Acc: 0.8294 | Val Loss: 0.3743, Val Acc: 0.8340
# EarlyStopping counter: 9 out of 10
# Epoch 41/100 | Train Loss: 0.3679, Train Acc: 0.8320 | Val Loss: 0.3855, Val Acc: 0.8210
# EarlyStopping counter: 10 out of 10
# Early stopping triggered. Ending training.
#
# ========== Fold 4 ==========
#
# Epoch 1/100 | Train Loss: 0.5438, Train Acc: 0.7229 | Val Loss: 0.4820, Val Acc: 0.7630
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_4.pth
# Epoch 2/100 | Train Loss: 0.4920, Train Acc: 0.7628 | Val Loss: 0.4626, Val Acc: 0.7855
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_4.pth
# Epoch 3/100 | Train Loss: 0.4836, Train Acc: 0.7666 | Val Loss: 0.4524, Val Acc: 0.7925
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_4.pth
# Epoch 4/100 | Train Loss: 0.4689, Train Acc: 0.7734 | Val Loss: 0.4395, Val Acc: 0.7830
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_4.pth
# Epoch 5/100 | Train Loss: 0.4580, Train Acc: 0.7824 | Val Loss: 0.4276, Val Acc: 0.8010
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_4.pth
# Epoch 6/100 | Train Loss: 0.4498, Train Acc: 0.7859 | Val Loss: 0.4218, Val Acc: 0.8005
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_4.pth
# Epoch 7/100 | Train Loss: 0.4432, Train Acc: 0.7911 | Val Loss: 0.4264, Val Acc: 0.7840
# EarlyStopping counter: 1 out of 10
# Epoch 8/100 | Train Loss: 0.4472, Train Acc: 0.7860 | Val Loss: 0.4236, Val Acc: 0.7940
# EarlyStopping counter: 2 out of 10
# Epoch 9/100 | Train Loss: 0.4491, Train Acc: 0.7909 | Val Loss: 0.4173, Val Acc: 0.8115
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_4.pth
# Epoch 10/100 | Train Loss: 0.4328, Train Acc: 0.7913 | Val Loss: 0.4050, Val Acc: 0.8085
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_4.pth
# Epoch 11/100 | Train Loss: 0.4256, Train Acc: 0.8026 | Val Loss: 0.4108, Val Acc: 0.8070
# EarlyStopping counter: 1 out of 10
# Epoch 12/100 | Train Loss: 0.4217, Train Acc: 0.8024 | Val Loss: 0.4029, Val Acc: 0.8105
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_4.pth
# Epoch 13/100 | Train Loss: 0.4264, Train Acc: 0.8006 | Val Loss: 0.4093, Val Acc: 0.8035
# EarlyStopping counter: 1 out of 10
# Epoch 14/100 | Train Loss: 0.4225, Train Acc: 0.8059 | Val Loss: 0.4032, Val Acc: 0.8030
# EarlyStopping counter: 2 out of 10
# Epoch 15/100 | Train Loss: 0.4176, Train Acc: 0.8017 | Val Loss: 0.4109, Val Acc: 0.8090
# EarlyStopping counter: 3 out of 10
# Epoch 16/100 | Train Loss: 0.4087, Train Acc: 0.8105 | Val Loss: 0.3958, Val Acc: 0.8050
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_4.pth
# Epoch 17/100 | Train Loss: 0.4070, Train Acc: 0.8075 | Val Loss: 0.3978, Val Acc: 0.8155
# EarlyStopping counter: 1 out of 10
# Epoch 18/100 | Train Loss: 0.4142, Train Acc: 0.8054 | Val Loss: 0.4016, Val Acc: 0.8105
# EarlyStopping counter: 2 out of 10
# Epoch 19/100 | Train Loss: 0.3983, Train Acc: 0.8126 | Val Loss: 0.3848, Val Acc: 0.8185
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_4.pth
# Epoch 20/100 | Train Loss: 0.4039, Train Acc: 0.8141 | Val Loss: 0.3891, Val Acc: 0.8150
# EarlyStopping counter: 1 out of 10
# Epoch 21/100 | Train Loss: 0.4006, Train Acc: 0.8130 | Val Loss: 0.3902, Val Acc: 0.8190
# EarlyStopping counter: 2 out of 10
# Epoch 22/100 | Train Loss: 0.3943, Train Acc: 0.8140 | Val Loss: 0.3891, Val Acc: 0.8110
# EarlyStopping counter: 3 out of 10
# Epoch 23/100 | Train Loss: 0.3986, Train Acc: 0.8143 | Val Loss: 0.3805, Val Acc: 0.8280
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_4.pth
# Epoch 24/100 | Train Loss: 0.3941, Train Acc: 0.8189 | Val Loss: 0.3809, Val Acc: 0.8235
# EarlyStopping counter: 1 out of 10
# Epoch 25/100 | Train Loss: 0.3878, Train Acc: 0.8171 | Val Loss: 0.3772, Val Acc: 0.8285
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_4.pth
# Epoch 26/100 | Train Loss: 0.3910, Train Acc: 0.8177 | Val Loss: 0.3823, Val Acc: 0.8225
# EarlyStopping counter: 1 out of 10
# Epoch 27/100 | Train Loss: 0.3882, Train Acc: 0.8215 | Val Loss: 0.3710, Val Acc: 0.8360
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_4.pth
# Epoch 28/100 | Train Loss: 0.3895, Train Acc: 0.8219 | Val Loss: 0.3682, Val Acc: 0.8325
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_4.pth
# Epoch 29/100 | Train Loss: 0.3781, Train Acc: 0.8237 | Val Loss: 0.3739, Val Acc: 0.8200
# EarlyStopping counter: 1 out of 10
# Epoch 30/100 | Train Loss: 0.3809, Train Acc: 0.8241 | Val Loss: 0.3765, Val Acc: 0.8250
# EarlyStopping counter: 2 out of 10
# Epoch 31/100 | Train Loss: 0.3735, Train Acc: 0.8301 | Val Loss: 0.3677, Val Acc: 0.8300
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_4.pth
# Epoch 32/100 | Train Loss: 0.3805, Train Acc: 0.8234 | Val Loss: 0.3775, Val Acc: 0.8220
# EarlyStopping counter: 1 out of 10
# Epoch 33/100 | Train Loss: 0.3785, Train Acc: 0.8221 | Val Loss: 0.3784, Val Acc: 0.8290
# EarlyStopping counter: 2 out of 10
# Epoch 34/100 | Train Loss: 0.3720, Train Acc: 0.8239 | Val Loss: 0.3754, Val Acc: 0.8170
# EarlyStopping counter: 3 out of 10
# Epoch 35/100 | Train Loss: 0.3735, Train Acc: 0.8295 | Val Loss: 0.3631, Val Acc: 0.8235
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_4.pth
# Epoch 36/100 | Train Loss: 0.3720, Train Acc: 0.8329 | Val Loss: 0.3777, Val Acc: 0.8200
# EarlyStopping counter: 1 out of 10
# Epoch 37/100 | Train Loss: 0.3715, Train Acc: 0.8307 | Val Loss: 0.3549, Val Acc: 0.8305
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_4.pth
# Epoch 38/100 | Train Loss: 0.3677, Train Acc: 0.8349 | Val Loss: 0.3606, Val Acc: 0.8305
# EarlyStopping counter: 1 out of 10
# Epoch 39/100 | Train Loss: 0.3645, Train Acc: 0.8347 | Val Loss: 0.3673, Val Acc: 0.8400
# EarlyStopping counter: 2 out of 10
# Epoch 40/100 | Train Loss: 0.3553, Train Acc: 0.8351 | Val Loss: 0.3647, Val Acc: 0.8260
# EarlyStopping counter: 3 out of 10
# Epoch 41/100 | Train Loss: 0.3663, Train Acc: 0.8270 | Val Loss: 0.3669, Val Acc: 0.8275
# EarlyStopping counter: 4 out of 10
# Epoch 42/100 | Train Loss: 0.3554, Train Acc: 0.8379 | Val Loss: 0.3590, Val Acc: 0.8300
# EarlyStopping counter: 5 out of 10
# Epoch 43/100 | Train Loss: 0.3611, Train Acc: 0.8309 | Val Loss: 0.3722, Val Acc: 0.8290
# EarlyStopping counter: 6 out of 10
# Epoch 44/100 | Train Loss: 0.3550, Train Acc: 0.8383 | Val Loss: 0.3603, Val Acc: 0.8345
# EarlyStopping counter: 7 out of 10
# Epoch 45/100 | Train Loss: 0.3599, Train Acc: 0.8390 | Val Loss: 0.3649, Val Acc: 0.8335
# EarlyStopping counter: 8 out of 10
# Epoch 46/100 | Train Loss: 0.3615, Train Acc: 0.8385 | Val Loss: 0.3568, Val Acc: 0.8415
# EarlyStopping counter: 9 out of 10
# Epoch 47/100 | Train Loss: 0.3484, Train Acc: 0.8421 | Val Loss: 0.3602, Val Acc: 0.8420
# EarlyStopping counter: 10 out of 10
# Early stopping triggered. Ending training.
#
# ========== Fold 5 ==========
#
# Epoch 1/100 | Train Loss: 0.5500, Train Acc: 0.7136 | Val Loss: 0.4755, Val Acc: 0.7820
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_5.pth
# Epoch 2/100 | Train Loss: 0.4954, Train Acc: 0.7614 | Val Loss: 0.4626, Val Acc: 0.7795
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_5.pth
# Epoch 3/100 | Train Loss: 0.4802, Train Acc: 0.7655 | Val Loss: 0.4616, Val Acc: 0.7865
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_5.pth
# Epoch 4/100 | Train Loss: 0.4727, Train Acc: 0.7760 | Val Loss: 0.4494, Val Acc: 0.7860
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_5.pth
# Epoch 5/100 | Train Loss: 0.4609, Train Acc: 0.7796 | Val Loss: 0.4278, Val Acc: 0.8040
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_5.pth
# Epoch 6/100 | Train Loss: 0.4525, Train Acc: 0.7836 | Val Loss: 0.4294, Val Acc: 0.7940
# EarlyStopping counter: 1 out of 10
# Epoch 7/100 | Train Loss: 0.4420, Train Acc: 0.7886 | Val Loss: 0.4381, Val Acc: 0.8035
# EarlyStopping counter: 2 out of 10
# Epoch 8/100 | Train Loss: 0.4403, Train Acc: 0.7903 | Val Loss: 0.4253, Val Acc: 0.8025
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_5.pth
# Epoch 9/100 | Train Loss: 0.4401, Train Acc: 0.7958 | Val Loss: 0.4223, Val Acc: 0.8000
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_5.pth
# Epoch 10/100 | Train Loss: 0.4291, Train Acc: 0.7970 | Val Loss: 0.4198, Val Acc: 0.8070
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_5.pth
# Epoch 11/100 | Train Loss: 0.4338, Train Acc: 0.7966 | Val Loss: 0.4103, Val Acc: 0.8105
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_5.pth
# Epoch 12/100 | Train Loss: 0.4211, Train Acc: 0.8051 | Val Loss: 0.4119, Val Acc: 0.8080
# EarlyStopping counter: 1 out of 10
# Epoch 13/100 | Train Loss: 0.4236, Train Acc: 0.8011 | Val Loss: 0.4137, Val Acc: 0.8160
# EarlyStopping counter: 2 out of 10
# Epoch 14/100 | Train Loss: 0.4185, Train Acc: 0.8073 | Val Loss: 0.4192, Val Acc: 0.8040
# EarlyStopping counter: 3 out of 10
# Epoch 15/100 | Train Loss: 0.4136, Train Acc: 0.8074 | Val Loss: 0.4034, Val Acc: 0.8140
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_5.pth
# Epoch 16/100 | Train Loss: 0.4119, Train Acc: 0.8106 | Val Loss: 0.4046, Val Acc: 0.8090
# EarlyStopping counter: 1 out of 10
# Epoch 17/100 | Train Loss: 0.4076, Train Acc: 0.8063 | Val Loss: 0.4091, Val Acc: 0.8125
# EarlyStopping counter: 2 out of 10
# Epoch 18/100 | Train Loss: 0.4098, Train Acc: 0.8087 | Val Loss: 0.4047, Val Acc: 0.8135
# EarlyStopping counter: 3 out of 10
# Epoch 19/100 | Train Loss: 0.4038, Train Acc: 0.8119 | Val Loss: 0.4017, Val Acc: 0.8185
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_5.pth
# Epoch 20/100 | Train Loss: 0.3955, Train Acc: 0.8149 | Val Loss: 0.3990, Val Acc: 0.8195
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_5.pth
# Epoch 21/100 | Train Loss: 0.3973, Train Acc: 0.8125 | Val Loss: 0.4106, Val Acc: 0.8120
# EarlyStopping counter: 1 out of 10
# Epoch 22/100 | Train Loss: 0.3961, Train Acc: 0.8155 | Val Loss: 0.3950, Val Acc: 0.8185
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_5.pth
# Epoch 23/100 | Train Loss: 0.3899, Train Acc: 0.8210 | Val Loss: 0.3982, Val Acc: 0.8090
# EarlyStopping counter: 1 out of 10
# Epoch 24/100 | Train Loss: 0.3965, Train Acc: 0.8134 | Val Loss: 0.3949, Val Acc: 0.8110
# EarlyStopping counter: 2 out of 10
# Epoch 25/100 | Train Loss: 0.3853, Train Acc: 0.8160 | Val Loss: 0.3954, Val Acc: 0.8175
# EarlyStopping counter: 3 out of 10
# Epoch 26/100 | Train Loss: 0.3814, Train Acc: 0.8226 | Val Loss: 0.3905, Val Acc: 0.8205
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_5.pth
# Epoch 27/100 | Train Loss: 0.3849, Train Acc: 0.8210 | Val Loss: 0.3929, Val Acc: 0.8165
# EarlyStopping counter: 1 out of 10
# Epoch 28/100 | Train Loss: 0.3811, Train Acc: 0.8199 | Val Loss: 0.3880, Val Acc: 0.8210
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_5.pth
# Epoch 29/100 | Train Loss: 0.3812, Train Acc: 0.8241 | Val Loss: 0.3903, Val Acc: 0.8245
# EarlyStopping counter: 1 out of 10
# Epoch 30/100 | Train Loss: 0.3874, Train Acc: 0.8235 | Val Loss: 0.3860, Val Acc: 0.8315
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_5.pth
# Epoch 31/100 | Train Loss: 0.3757, Train Acc: 0.8293 | Val Loss: 0.3895, Val Acc: 0.8295
# EarlyStopping counter: 1 out of 10
# Epoch 32/100 | Train Loss: 0.3775, Train Acc: 0.8243 | Val Loss: 0.3795, Val Acc: 0.8275
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_5.pth
# Epoch 33/100 | Train Loss: 0.3662, Train Acc: 0.8347 | Val Loss: 0.3912, Val Acc: 0.8255
# EarlyStopping counter: 1 out of 10
# Epoch 34/100 | Train Loss: 0.3692, Train Acc: 0.8273 | Val Loss: 0.3875, Val Acc: 0.8260
# EarlyStopping counter: 2 out of 10
# Epoch 35/100 | Train Loss: 0.3781, Train Acc: 0.8220 | Val Loss: 0.3803, Val Acc: 0.8205
# EarlyStopping counter: 3 out of 10
# Epoch 36/100 | Train Loss: 0.3680, Train Acc: 0.8271 | Val Loss: 0.3819, Val Acc: 0.8305
# EarlyStopping counter: 4 out of 10
# Epoch 37/100 | Train Loss: 0.3624, Train Acc: 0.8337 | Val Loss: 0.3820, Val Acc: 0.8280
# EarlyStopping counter: 5 out of 10
# Epoch 38/100 | Train Loss: 0.3661, Train Acc: 0.8337 | Val Loss: 0.3894, Val Acc: 0.8295
# EarlyStopping counter: 6 out of 10
# Epoch 39/100 | Train Loss: 0.3617, Train Acc: 0.8365 | Val Loss: 0.3711, Val Acc: 0.8310
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_5.pth
# Epoch 40/100 | Train Loss: 0.3653, Train Acc: 0.8360 | Val Loss: 0.3742, Val Acc: 0.8280
# EarlyStopping counter: 1 out of 10
# Epoch 41/100 | Train Loss: 0.3547, Train Acc: 0.8377 | Val Loss: 0.3713, Val Acc: 0.8300
# EarlyStopping counter: 2 out of 10
# Epoch 42/100 | Train Loss: 0.3652, Train Acc: 0.8373 | Val Loss: 0.3732, Val Acc: 0.8345
# EarlyStopping counter: 3 out of 10
# Epoch 43/100 | Train Loss: 0.3546, Train Acc: 0.8407 | Val Loss: 0.3732, Val Acc: 0.8345
# EarlyStopping counter: 4 out of 10
# Epoch 44/100 | Train Loss: 0.3449, Train Acc: 0.8438 | Val Loss: 0.3900, Val Acc: 0.8225
# EarlyStopping counter: 5 out of 10
# Epoch 45/100 | Train Loss: 0.3557, Train Acc: 0.8406 | Val Loss: 0.3701, Val Acc: 0.8330
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_5.pth
# Epoch 46/100 | Train Loss: 0.3540, Train Acc: 0.8340 | Val Loss: 0.3740, Val Acc: 0.8325
# EarlyStopping counter: 1 out of 10
# Epoch 47/100 | Train Loss: 0.3532, Train Acc: 0.8389 | Val Loss: 0.3716, Val Acc: 0.8350
# EarlyStopping counter: 2 out of 10
# Epoch 48/100 | Train Loss: 0.3470, Train Acc: 0.8391 | Val Loss: 0.3690, Val Acc: 0.8330
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_5.pth
# Epoch 49/100 | Train Loss: 0.3524, Train Acc: 0.8439 | Val Loss: 0.3690, Val Acc: 0.8405
# EarlyStopping counter: 1 out of 10
# Epoch 50/100 | Train Loss: 0.3408, Train Acc: 0.8443 | Val Loss: 0.3688, Val Acc: 0.8290
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_5.pth
# Epoch 51/100 | Train Loss: 0.3518, Train Acc: 0.8387 | Val Loss: 0.3768, Val Acc: 0.8305
# EarlyStopping counter: 1 out of 10
# Epoch 52/100 | Train Loss: 0.3431, Train Acc: 0.8465 | Val Loss: 0.3778, Val Acc: 0.8385
# EarlyStopping counter: 2 out of 10
# Epoch 53/100 | Train Loss: 0.3503, Train Acc: 0.8399 | Val Loss: 0.3607, Val Acc: 0.8365
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_5.pth
# Epoch 54/100 | Train Loss: 0.3334, Train Acc: 0.8466 | Val Loss: 0.3697, Val Acc: 0.8410
# EarlyStopping counter: 1 out of 10
# Epoch 55/100 | Train Loss: 0.3415, Train Acc: 0.8490 | Val Loss: 0.3552, Val Acc: 0.8490
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_5.pth
# Epoch 56/100 | Train Loss: 0.3455, Train Acc: 0.8485 | Val Loss: 0.3681, Val Acc: 0.8365
# EarlyStopping counter: 1 out of 10
# Epoch 57/100 | Train Loss: 0.3398, Train Acc: 0.8495 | Val Loss: 0.3546, Val Acc: 0.8410
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_SwinTransformer_CV_fold_5.pth
# Epoch 58/100 | Train Loss: 0.3377, Train Acc: 0.8464 | Val Loss: 0.3642, Val Acc: 0.8335
# EarlyStopping counter: 1 out of 10
# Epoch 59/100 | Train Loss: 0.3369, Train Acc: 0.8521 | Val Loss: 0.3578, Val Acc: 0.8425
# EarlyStopping counter: 2 out of 10
# Epoch 60/100 | Train Loss: 0.3366, Train Acc: 0.8484 | Val Loss: 0.3579, Val Acc: 0.8395
# EarlyStopping counter: 3 out of 10
# Epoch 61/100 | Train Loss: 0.3363, Train Acc: 0.8503 | Val Loss: 0.3651, Val Acc: 0.8395
# EarlyStopping counter: 4 out of 10
# Epoch 62/100 | Train Loss: 0.3323, Train Acc: 0.8530 | Val Loss: 0.3724, Val Acc: 0.8345
# EarlyStopping counter: 5 out of 10
# Epoch 63/100 | Train Loss: 0.3317, Train Acc: 0.8481 | Val Loss: 0.3612, Val Acc: 0.8330
# EarlyStopping counter: 6 out of 10
# Epoch 64/100 | Train Loss: 0.3358, Train Acc: 0.8478 | Val Loss: 0.3564, Val Acc: 0.8360
# EarlyStopping counter: 7 out of 10
# Epoch 65/100 | Train Loss: 0.3331, Train Acc: 0.8511 | Val Loss: 0.3713, Val Acc: 0.8385
# EarlyStopping counter: 8 out of 10
# Epoch 66/100 | Train Loss: 0.3348, Train Acc: 0.8461 | Val Loss: 0.3873, Val Acc: 0.8395
# EarlyStopping counter: 9 out of 10
# Epoch 67/100 | Train Loss: 0.3350, Train Acc: 0.8450 | Val Loss: 0.3625, Val Acc: 0.8330
# EarlyStopping counter: 10 out of 10
# Early stopping triggered. Ending training.
#
# ========== Cross-Validation Results ==========
#
#    fold  train_loss  train_accuracy  val_loss  val_accuracy
# 0     1    0.327733        0.852375  0.355486        0.8465
# 1     2    0.355885        0.837000  0.401990        0.8140
# 2     3    0.367903        0.832000  0.385501        0.8210
# 3     4    0.348413        0.842125  0.360201        0.8420
# 4     5    0.334968        0.845000  0.362548        0.8330
#
# Average Validation Accuracy: 0.8313

# %%
# Convert results to DataFrame
cv_metrics_df = pd.DataFrame(cv_metrics)

# Calculate average metrics
avg_metrics = cv_metrics_df.mean().to_dict()
avg_metrics["Fold"] = "Average"

# Add the average metrics to the DataFrame
cv_metrics_df = cv_metrics_df.append(avg_metrics, ignore_index=True)

# Save results to CSV file
csv_file_name = f"CV_Results/{file_name}.csv"
cv_metrics_df.to_csv(csv_file_name, index=False)

print(f"Cross-validation metrics saved to {csv_file_name}")
# Out:
# /tmp/job.2295369.hpc/ipykernel_2595237/1908723448.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cv_metrics_df = cv_metrics_df.append(avg_metrics, ignore_index=True)
# Cross-validation metrics saved to CV_Results/Benchmark_SwinTransformer_CV.csv
