# %%
# Import necessary libraries
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Subset, DataLoader, Dataset
from torchvision import datasets, transforms, models
from torchvision.models import efficientnet_b0
from torchvision.models.efficientnet import SqueezeExcitation
import matplotlib.pyplot as plt
import multiprocessing
import numpy as np
from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score,  roc_auc_score, 
    cohen_kappa_score, matthews_corrcoef, confusion_matrix, average_precision_score, fbeta_score,
    precision_recall_curve, balanced_accuracy_score)
import pandas as pd
from sklearn.utils import shuffle
import random
import albumentations as A
from albumentations.pytorch import ToTensorV2
import pandas as pd
import torch_optimizer
import cv2
from skimage import measure
from torchvision.utils import make_grid
# %matplotlib inline

# %%
# Check for GPU availability
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# !nvidia-smi
# Out:
# Wed Dec 18 13:46:38 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.54.03              Driver Version: 535.54.03    CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-PCIE-32GB           On  | 00000000:3B:00.0 Off |                    0 |
# | N/A   30C    P0              34W / 250W |   4674MiB / 32768MiB |     18%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A   4141963      C   ...on/3.10.4-GCCcore-11.3.0/bin/python     1430MiB |
# |    0   N/A  N/A   4142396      C   ...on/3.10.4-GCCcore-11.3.0/bin/python     3240MiB |
# +---------------------------------------------------------------------------------------+

# %%
file_name = "Benchmark_InceptionV3_CV"

# %%
import os

# Define directories of where the datasets reside
base_dir = '/home/pxk409/skin_lesions_13k'

# Define directories of where the training, validation and test sets reside
train_dir = os.path.join(base_dir, 'train')
test_dir = os.path.join(base_dir, 'test')

# Define directories of where the benign and malignant images reside
train_benign_dir = os.path.join(base_dir, 'train/benign')
train_malignant_dir = os.path.join(base_dir, 'train/malignant')
test_benign_dir = os.path.join(base_dir, 'test/benign')
test_malignant_dir = os.path.join(base_dir, 'test/malignant')

# %%
# Let's check the number of images in each set
print('Total training benign images:', len(os.listdir(train_benign_dir)))
print('Total training malignant images:', len(os.listdir(train_malignant_dir)))
print('Total test benign images:', len(os.listdir(test_benign_dir)))
print('Total test malignant images:', len(os.listdir(test_malignant_dir)))
# Out:
# Total training benign images: 5000
# Total training malignant images: 5000
# Total test benign images: 1500
# Total test malignant images: 1500

# %%
# Load full dataset
full_dataset = datasets.ImageFolder(root=train_dir)

# Extract labels from the dataset
#labels = [label for _, label in full_dataset.samples]

# Stratified split (80% train, 20% validation)
#split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=123456)
#train_idx, val_idx = next(split.split(np.zeros(len(labels)), labels))

# Create training and validation subsets
#train_dataset = Subset(full_dataset, train_idx)
#val_dataset = Subset(full_dataset, val_idx)

#print(f"Training set: {len(train_idx)} samples")
#print(f"Validation set: {len(val_idx)} samples")

# Count the number of samples per class in each split
#train_classes = [full_dataset.targets[idx] for idx in train_dataset.indices]
#val_classes = [full_dataset.targets[idx] for idx in val_dataset.indices]

#print(f"Training set class counts: {np.bincount(train_classes)}")
#print(f"Validation set class counts: {np.bincount(val_classes)}")

# %%
# Custom transform to integrate Albumentations with PyTorch
class AlbumentationsTransform:
    def __init__(self, augmentations):
        self.augmentations = A.Compose(augmentations)

    def __call__(self, image):
        image = np.array(image)  # Convert PIL Image to NumPy array
        augmented = self.augmentations(image=image)
        return augmented["image"]

# Simple augmentations for training
simple_transform = AlbumentationsTransform([
    A.RandomResizedCrop(height=299, width=299, scale=(0.8, 1.0), p=1.0),  # Random crop and resize
    A.HorizontalFlip(p=0.5),  # Horizontal flip
    A.VerticalFlip(p=0.5),  # Vertical flip
    #A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1, p=0.5),  # Color jitter
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  # Normalize to match pre-trained model
    ToTensorV2(),  # Convert to PyTorch tensor and ensure dtype=torch.float32
])


# Use AlbumentationsTransform directly in the loaders for consistency
train_transform = simple_transform

# Albumentations augmentations for validation and test
albumentations_val_test_transform = AlbumentationsTransform([
    A.Resize(height=299, width=299),  # Resize to EfficientNet input size
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  # Normalize to match pre-trained model
    ToTensorV2()  # Convert to PyTorch tensor
])

test_val_transform = albumentations_val_test_transform

# %%
class TransformDataset(Dataset):
    def __init__(self, dataset, transform):
        """
        Args:
            dataset: Original dataset (e.g., Subset of ImageFolder).
            transform: Transform to be applied to the images in the dataset.
        """
        self.dataset = dataset
        self.transform = transform

    def __getitem__(self, idx):
        image, label = self.dataset[idx]
        if self.transform:
            image = self.transform(image)
        return image, label

    def __len__(self):
        return len(self.dataset)

# %%
# Wrap subsets with the respective transforms
#train_dataset = TransformDataset(train_dataset, train_transform)
#val_dataset = TransformDataset(val_dataset, test_val_transform)

# %%
# Load and prepare the test dataset
#test_dataset = datasets.ImageFolder(root=test_dir, transform=test_val_transform)
test_dataset = datasets.ImageFolder(root=test_dir)
test_dataset = TransformDataset(test_dataset, test_val_transform)

# %%
# Create data loaders
batch_size = 64
#num_cpus = multiprocessing.cpu_count()  # Use all CPU cores
#print(f"Number of CPU cores: {num_cpus}")
#num_workers = 16


#train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
#val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
#train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=True)
#val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=True)
#test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=True)

# %%
def initialize_model():
    # Load pre-trained InceptionV3 model with weights
    model = models.inception_v3(weights=models.Inception_V3_Weights.DEFAULT)

    # Disable aux_logits
    #model.aux_logits = False

    # Replace the classifier (fully connected layers) for binary classification
    model.fc = nn.Sequential(
        nn.Linear(model.fc.in_features, 512),
        nn.ReLU(),
        nn.Dropout(0.5),
        nn.Linear(512, 256),
        nn.ReLU(),
        nn.Dropout(0.5),
        nn.Linear(256, 2)
    )

    # Freeze parameters
    for param in model.parameters():
        param.requires_grad = False

    # Unfreeze the classifier (fc layer)
    for param in model.fc.parameters():
        param.requires_grad = True

    # Move model to device
    model = model.to(device)
    return model

model = initialize_model()

# %%
# Function to count trainable and non-trainable parameters
def count_trainable_non_trainable_parameters(model):
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    non_trainable = sum(p.numel() for p in model.parameters() if not p.requires_grad)
    return trainable, non_trainable

# Count parameters in InceptionV3's feature extractor (convolutional part)
def count_inception_parts(model):
    # Count parameters in the main feature extraction layers
    print("Counting trainable/non-trainable parameters in InceptionV3...")

    # Count parameters in the main feature layers (excluding AuxLogits)
    trainable_main, non_trainable_main = count_trainable_non_trainable_parameters(model)

    # If aux_logits exists, count it separately
    if hasattr(model, 'AuxLogits') and model.AuxLogits is not None:
        aux_trainable, aux_non_trainable = count_trainable_non_trainable_parameters(model.AuxLogits)
        print(f"Auxiliary Classifier (AuxLogits):\n"
              f"  Trainable parameters: {aux_trainable:,}\n"
              f"  Non-trainable parameters: {aux_non_trainable:,}")
    else:
        aux_trainable, aux_non_trainable = 0, 0
        print("Auxiliary Classifier (AuxLogits): Not present or disabled.")

    # Classifier part (fully connected layers at the end)
    trainable_classifier, non_trainable_classifier = count_trainable_non_trainable_parameters(model.fc)

    print(f"Main Feature Extractor (without AuxLogits):\n"
          f"  Trainable parameters: {trainable_main - aux_trainable - trainable_classifier:,}\n"
          f"  Non-trainable parameters: {non_trainable_main - aux_non_trainable - non_trainable_classifier:,}")

    print(f"Final Classifier (fc layer):\n"
          f"  Trainable parameters: {trainable_classifier:,}\n"
          f"  Non-trainable parameters: {non_trainable_classifier:,}")

    print(f"Whole Model:\n"
          f"  Total Trainable parameters: {trainable_main:,}\n"
          f"  Total Non-trainable parameters: {non_trainable_main:,}")


# Call function to count parameters
count_inception_parts(model)
# Out:
# Counting trainable/non-trainable parameters in InceptionV3...
# Auxiliary Classifier (AuxLogits):
#   Trainable parameters: 0
#   Non-trainable parameters: 3,326,696
# Main Feature Extractor (without AuxLogits):
#   Trainable parameters: 0
#   Non-trainable parameters: 21,785,568
# Final Classifier (fc layer):
#   Trainable parameters: 1,180,930
#   Non-trainable parameters: 0
# Whole Model:
#   Total Trainable parameters: 1,180,930
#   Total Non-trainable parameters: 25,112,264

# %%
# Early Stopping
class EarlyStopping:
    def __init__(self, patience, delta, path):
        """
        Args:
            patience (int): Number of epochs to wait after last improvement.
            delta (float): Minimum change in monitored metric to qualify as an improvement.
            path (str): Path to save the best model.
        """
        self.patience = patience
        self.delta = delta
        self.path = path
        self.counter = 0
        self.best_score = None
        self.early_stop = False

    def __call__(self, val_loss, model):
        score = -val_loss  # Early stopping is based on minimizing validation loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f"EarlyStopping counter: {self.counter} out of {self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        """Saves model when validation loss decreases."""
        print(f"Validation loss decreased. Saving model to {self.path}")
        torch.save(model.state_dict(), self.path)


# Set the path for saving best_model.pth
#current_dir = os.getcwd()
#model_save_path = os.path.join(current_dir, 'best_model2.pth')

# Initialize EarlyStopping
#early_stopping = EarlyStopping(patience=5, delta=0.001, path=model_save_path)

# %%
# Helper function to evaluate a dataset
def evaluate_model(model, data_loader, device):
    model.eval()  # Set model to evaluation mode
    all_labels = []
    all_preds = []
    all_probs = []

    with torch.no_grad():
        for images, labels in data_loader:
            images, labels = images.to(device), labels.to(device)

            # Forward pass
            outputs = model(images)
            probs = torch.softmax(outputs, dim=1)[:, 1]  # Probabilities for the positive class
            _, preds = torch.max(outputs, 1)

            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())

    return np.array(all_labels), np.array(all_preds), np.array(all_probs)

# Helper function to calculate selected metrics
def calculate_metrics(labels, preds, probs):
    accuracy = accuracy_score(labels, preds)
    precision = precision_score(labels, preds)
    recall = recall_score(labels, preds)
    f1 = f1_score(labels, preds)
    f2 = fbeta_score(labels, preds, beta=2)
    auc = roc_auc_score(labels, probs)
    specificity = recall_score(labels, preds, pos_label=0)
    npv = precision_score(labels, preds, pos_label=0)

    return recall, precision, accuracy, f1, f2, auc, specificity, npv

# %%
# Training loop with 5-fold cross-validation
cv_results = []
cv_metrics = []
n_splits = 5
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=123456)

# Extract labels from the dataset
labels = [label for _, label in full_dataset.samples]

# Cross-validation loop
for fold, (train_idx, val_idx) in enumerate(skf.split(np.zeros(len(labels)), labels), 1):
    print(f"\n========== Fold {fold} ==========\n")
    
    # Create training and validation subsets for this fold
    train_dataset = Subset(full_dataset, train_idx)
    val_dataset = Subset(full_dataset, val_idx)
    
    # Apply transformations
    train_dataset = TransformDataset(train_dataset, train_transform)
    val_dataset = TransformDataset(val_dataset, test_val_transform)
    
    # Create data loaders
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    
    # Initialize model and optimizer for each fold
    model = initialize_model()
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    # EarlyStopping initialization
    early_stopping = EarlyStopping(patience=10, delta=0.0001, path=os.path.join(os.getcwd(), f"{file_name}_fold_{fold}.pth"))

    # Training loop
    num_epochs = 100
    train_losses = []
    val_losses = []
    
    for epoch in range(num_epochs):
        # Training phase
        model.train()
        train_loss = 0
        train_correct = 0
        
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            
            # Forward pass
            outputs = model(images)

            # If outputs is InceptionOutputs, extract logits
            if isinstance(outputs, models.inception.InceptionOutputs):
                outputs = outputs.logits

            loss = criterion(outputs, labels)
            
            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            train_correct += torch.sum(preds == labels)
        
        train_loss /= len(train_loader)
        train_accuracy = train_correct.double() / len(train_dataset)
        train_losses.append(train_loss)
        
        # Validation phase
        model.eval()
        val_loss = 0
        val_correct = 0
        
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                
                outputs = model(images)
                loss = criterion(outputs, labels)
                
                val_loss += loss.item()
                _, preds = torch.max(outputs, 1)
                val_correct += torch.sum(preds == labels)
        
        val_loss /= len(val_loader)
        val_accuracy = val_correct.double() / len(val_dataset)
        val_losses.append(val_loss)
        
        print(f"Epoch {epoch + 1}/{num_epochs} | "
              f"Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.4f} | "
              f"Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.4f}")
        
        # Call EarlyStopping
        early_stopping(val_loss, model)
        if early_stopping.early_stop:
            print("Early stopping triggered. Ending training.")
            break
    
    # Store results for this fold
    cv_results.append({
        "fold": fold,
        "train_loss": train_loss,
        "train_accuracy": train_accuracy.item(),
        "val_loss": val_loss,
        "val_accuracy": val_accuracy.item()
        })
        
    # Load the best model for evaluation
    model.load_state_dict(torch.load(f"{file_name}_fold_{fold}.pth", weights_only=True))

    # Evaluate on validation set
    labels, preds, probs = evaluate_model(model, val_loader, device)
    metrics = calculate_metrics(labels, preds, probs)
    recall, precision, accuracy, f1, f2, auc, specificity, npv = metrics

    # Record metrics for the fold
    cv_metrics.append({
        "Fold": fold,
        "Recall": recall,
        "Precision": precision,
        "Accuracy": accuracy,
        "F1 Score": f1,
        "F2 Score": f2,
        "AUC": auc,
        "Specificity": specificity,
        "NPV": npv,
    })

# Summarize cross-validation results
df_cv_results = pd.DataFrame(cv_results)
print("\n========== Cross-Validation Results ==========\n")
print(df_cv_results)

print("\nAverage Validation Accuracy: {:.4f}".format(df_cv_results["val_accuracy"].mean()))
# Out:
# ========== Fold 1 ==========
#
# Epoch 1/100 | Train Loss: 0.6362, Train Acc: 0.6396 | Val Loss: 0.5627, Val Acc: 0.7215
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_1.pth
# Epoch 2/100 | Train Loss: 0.5911, Train Acc: 0.6937 | Val Loss: 0.5787, Val Acc: 0.7125
# EarlyStopping counter: 1 out of 10
# Epoch 3/100 | Train Loss: 0.5795, Train Acc: 0.7000 | Val Loss: 0.5362, Val Acc: 0.7370
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_1.pth
# Epoch 4/100 | Train Loss: 0.5718, Train Acc: 0.7067 | Val Loss: 0.5344, Val Acc: 0.7380
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_1.pth
# Epoch 5/100 | Train Loss: 0.5649, Train Acc: 0.7107 | Val Loss: 0.5273, Val Acc: 0.7325
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_1.pth
# Epoch 6/100 | Train Loss: 0.5622, Train Acc: 0.7069 | Val Loss: 0.5365, Val Acc: 0.7260
# EarlyStopping counter: 1 out of 10
# Epoch 7/100 | Train Loss: 0.5557, Train Acc: 0.7139 | Val Loss: 0.5404, Val Acc: 0.7475
# EarlyStopping counter: 2 out of 10
# Epoch 8/100 | Train Loss: 0.5502, Train Acc: 0.7211 | Val Loss: 0.5326, Val Acc: 0.7435
# EarlyStopping counter: 3 out of 10
# Epoch 9/100 | Train Loss: 0.5497, Train Acc: 0.7203 | Val Loss: 0.5396, Val Acc: 0.7270
# EarlyStopping counter: 4 out of 10
# Epoch 10/100 | Train Loss: 0.5499, Train Acc: 0.7160 | Val Loss: 0.5305, Val Acc: 0.7425
# EarlyStopping counter: 5 out of 10
# Epoch 11/100 | Train Loss: 0.5431, Train Acc: 0.7174 | Val Loss: 0.5194, Val Acc: 0.7475
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_1.pth
# Epoch 12/100 | Train Loss: 0.5461, Train Acc: 0.7200 | Val Loss: 0.5406, Val Acc: 0.7270
# EarlyStopping counter: 1 out of 10
# Epoch 13/100 | Train Loss: 0.5433, Train Acc: 0.7226 | Val Loss: 0.5219, Val Acc: 0.7285
# EarlyStopping counter: 2 out of 10
# Epoch 14/100 | Train Loss: 0.5400, Train Acc: 0.7258 | Val Loss: 0.5179, Val Acc: 0.7620
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_1.pth
# Epoch 15/100 | Train Loss: 0.5361, Train Acc: 0.7298 | Val Loss: 0.5077, Val Acc: 0.7620
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_1.pth
# Epoch 16/100 | Train Loss: 0.5314, Train Acc: 0.7362 | Val Loss: 0.5072, Val Acc: 0.7665
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_1.pth
# Epoch 17/100 | Train Loss: 0.5374, Train Acc: 0.7270 | Val Loss: 0.5207, Val Acc: 0.7490
# EarlyStopping counter: 1 out of 10
# Epoch 18/100 | Train Loss: 0.5303, Train Acc: 0.7304 | Val Loss: 0.5054, Val Acc: 0.7500
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_1.pth
# Epoch 19/100 | Train Loss: 0.5349, Train Acc: 0.7243 | Val Loss: 0.5015, Val Acc: 0.7590
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_1.pth
# Epoch 20/100 | Train Loss: 0.5297, Train Acc: 0.7310 | Val Loss: 0.5003, Val Acc: 0.7490
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_1.pth
# Epoch 21/100 | Train Loss: 0.5432, Train Acc: 0.7226 | Val Loss: 0.5104, Val Acc: 0.7615
# EarlyStopping counter: 1 out of 10
# Epoch 22/100 | Train Loss: 0.5344, Train Acc: 0.7326 | Val Loss: 0.5170, Val Acc: 0.7600
# EarlyStopping counter: 2 out of 10
# Epoch 23/100 | Train Loss: 0.5357, Train Acc: 0.7284 | Val Loss: 0.5042, Val Acc: 0.7610
# EarlyStopping counter: 3 out of 10
# Epoch 24/100 | Train Loss: 0.5262, Train Acc: 0.7361 | Val Loss: 0.4933, Val Acc: 0.7730
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_1.pth
# Epoch 25/100 | Train Loss: 0.5224, Train Acc: 0.7360 | Val Loss: 0.4989, Val Acc: 0.7690
# EarlyStopping counter: 1 out of 10
# Epoch 26/100 | Train Loss: 0.5248, Train Acc: 0.7388 | Val Loss: 0.5015, Val Acc: 0.7600
# EarlyStopping counter: 2 out of 10
# Epoch 27/100 | Train Loss: 0.5159, Train Acc: 0.7392 | Val Loss: 0.4867, Val Acc: 0.7615
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_1.pth
# Epoch 28/100 | Train Loss: 0.5202, Train Acc: 0.7444 | Val Loss: 0.4998, Val Acc: 0.7650
# EarlyStopping counter: 1 out of 10
# Epoch 29/100 | Train Loss: 0.5228, Train Acc: 0.7398 | Val Loss: 0.4955, Val Acc: 0.7565
# EarlyStopping counter: 2 out of 10
# Epoch 30/100 | Train Loss: 0.5264, Train Acc: 0.7323 | Val Loss: 0.5009, Val Acc: 0.7610
# EarlyStopping counter: 3 out of 10
# Epoch 31/100 | Train Loss: 0.5152, Train Acc: 0.7408 | Val Loss: 0.4978, Val Acc: 0.7610
# EarlyStopping counter: 4 out of 10
# Epoch 32/100 | Train Loss: 0.5203, Train Acc: 0.7370 | Val Loss: 0.4930, Val Acc: 0.7715
# EarlyStopping counter: 5 out of 10
# Epoch 33/100 | Train Loss: 0.5241, Train Acc: 0.7394 | Val Loss: 0.4970, Val Acc: 0.7695
# EarlyStopping counter: 6 out of 10
# Epoch 34/100 | Train Loss: 0.5221, Train Acc: 0.7360 | Val Loss: 0.5074, Val Acc: 0.7680
# EarlyStopping counter: 7 out of 10
# Epoch 35/100 | Train Loss: 0.5176, Train Acc: 0.7399 | Val Loss: 0.4903, Val Acc: 0.7670
# EarlyStopping counter: 8 out of 10
# Epoch 36/100 | Train Loss: 0.5184, Train Acc: 0.7391 | Val Loss: 0.5016, Val Acc: 0.7675
# EarlyStopping counter: 9 out of 10
# Epoch 37/100 | Train Loss: 0.5170, Train Acc: 0.7378 | Val Loss: 0.5061, Val Acc: 0.7745
# EarlyStopping counter: 10 out of 10
# Early stopping triggered. Ending training.
#
# ========== Fold 2 ==========
#
# Epoch 1/100 | Train Loss: 0.6391, Train Acc: 0.6335 | Val Loss: 0.5719, Val Acc: 0.7250
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_2.pth
# Epoch 2/100 | Train Loss: 0.5885, Train Acc: 0.6913 | Val Loss: 0.5575, Val Acc: 0.7120
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_2.pth
# Epoch 3/100 | Train Loss: 0.5774, Train Acc: 0.6979 | Val Loss: 0.5579, Val Acc: 0.7115
# EarlyStopping counter: 1 out of 10
# Epoch 4/100 | Train Loss: 0.5688, Train Acc: 0.7086 | Val Loss: 0.5261, Val Acc: 0.7430
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_2.pth
# Epoch 5/100 | Train Loss: 0.5556, Train Acc: 0.7143 | Val Loss: 0.5424, Val Acc: 0.7475
# EarlyStopping counter: 1 out of 10
# Epoch 6/100 | Train Loss: 0.5588, Train Acc: 0.7121 | Val Loss: 0.5271, Val Acc: 0.7430
# EarlyStopping counter: 2 out of 10
# Epoch 7/100 | Train Loss: 0.5560, Train Acc: 0.7167 | Val Loss: 0.5315, Val Acc: 0.7350
# EarlyStopping counter: 3 out of 10
# Epoch 8/100 | Train Loss: 0.5499, Train Acc: 0.7193 | Val Loss: 0.5181, Val Acc: 0.7315
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_2.pth
# Epoch 9/100 | Train Loss: 0.5472, Train Acc: 0.7213 | Val Loss: 0.5260, Val Acc: 0.7325
# EarlyStopping counter: 1 out of 10
# Epoch 10/100 | Train Loss: 0.5392, Train Acc: 0.7245 | Val Loss: 0.5224, Val Acc: 0.7375
# EarlyStopping counter: 2 out of 10
# Epoch 11/100 | Train Loss: 0.5470, Train Acc: 0.7218 | Val Loss: 0.5335, Val Acc: 0.7320
# EarlyStopping counter: 3 out of 10
# Epoch 12/100 | Train Loss: 0.5466, Train Acc: 0.7240 | Val Loss: 0.5363, Val Acc: 0.7360
# EarlyStopping counter: 4 out of 10
# Epoch 13/100 | Train Loss: 0.5419, Train Acc: 0.7271 | Val Loss: 0.5188, Val Acc: 0.7335
# EarlyStopping counter: 5 out of 10
# Epoch 14/100 | Train Loss: 0.5454, Train Acc: 0.7271 | Val Loss: 0.5084, Val Acc: 0.7445
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_2.pth
# Epoch 15/100 | Train Loss: 0.5399, Train Acc: 0.7301 | Val Loss: 0.5086, Val Acc: 0.7435
# EarlyStopping counter: 1 out of 10
# Epoch 16/100 | Train Loss: 0.5404, Train Acc: 0.7288 | Val Loss: 0.5217, Val Acc: 0.7380
# EarlyStopping counter: 2 out of 10
# Epoch 17/100 | Train Loss: 0.5377, Train Acc: 0.7303 | Val Loss: 0.5255, Val Acc: 0.7375
# EarlyStopping counter: 3 out of 10
# Epoch 18/100 | Train Loss: 0.5342, Train Acc: 0.7366 | Val Loss: 0.5178, Val Acc: 0.7375
# EarlyStopping counter: 4 out of 10
# Epoch 19/100 | Train Loss: 0.5369, Train Acc: 0.7303 | Val Loss: 0.5115, Val Acc: 0.7535
# EarlyStopping counter: 5 out of 10
# Epoch 20/100 | Train Loss: 0.5278, Train Acc: 0.7361 | Val Loss: 0.5114, Val Acc: 0.7455
# EarlyStopping counter: 6 out of 10
# Epoch 21/100 | Train Loss: 0.5317, Train Acc: 0.7355 | Val Loss: 0.5330, Val Acc: 0.7200
# EarlyStopping counter: 7 out of 10
# Epoch 22/100 | Train Loss: 0.5375, Train Acc: 0.7288 | Val Loss: 0.5217, Val Acc: 0.7355
# EarlyStopping counter: 8 out of 10
# Epoch 23/100 | Train Loss: 0.5238, Train Acc: 0.7374 | Val Loss: 0.4958, Val Acc: 0.7455
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_2.pth
# Epoch 24/100 | Train Loss: 0.5300, Train Acc: 0.7399 | Val Loss: 0.4993, Val Acc: 0.7500
# EarlyStopping counter: 1 out of 10
# Epoch 25/100 | Train Loss: 0.5290, Train Acc: 0.7310 | Val Loss: 0.5134, Val Acc: 0.7535
# EarlyStopping counter: 2 out of 10
# Epoch 26/100 | Train Loss: 0.5243, Train Acc: 0.7404 | Val Loss: 0.4942, Val Acc: 0.7500
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_2.pth
# Epoch 27/100 | Train Loss: 0.5281, Train Acc: 0.7404 | Val Loss: 0.5093, Val Acc: 0.7435
# EarlyStopping counter: 1 out of 10
# Epoch 28/100 | Train Loss: 0.5150, Train Acc: 0.7461 | Val Loss: 0.4977, Val Acc: 0.7585
# EarlyStopping counter: 2 out of 10
# Epoch 29/100 | Train Loss: 0.5272, Train Acc: 0.7351 | Val Loss: 0.5129, Val Acc: 0.7550
# EarlyStopping counter: 3 out of 10
# Epoch 30/100 | Train Loss: 0.5287, Train Acc: 0.7309 | Val Loss: 0.4990, Val Acc: 0.7605
# EarlyStopping counter: 4 out of 10
# Epoch 31/100 | Train Loss: 0.5138, Train Acc: 0.7442 | Val Loss: 0.5176, Val Acc: 0.7610
# EarlyStopping counter: 5 out of 10
# Epoch 32/100 | Train Loss: 0.5215, Train Acc: 0.7409 | Val Loss: 0.4980, Val Acc: 0.7540
# EarlyStopping counter: 6 out of 10
# Epoch 33/100 | Train Loss: 0.5172, Train Acc: 0.7374 | Val Loss: 0.4985, Val Acc: 0.7635
# EarlyStopping counter: 7 out of 10
# Epoch 34/100 | Train Loss: 0.5164, Train Acc: 0.7424 | Val Loss: 0.4975, Val Acc: 0.7595
# EarlyStopping counter: 8 out of 10
# Epoch 35/100 | Train Loss: 0.5226, Train Acc: 0.7394 | Val Loss: 0.5101, Val Acc: 0.7550
# EarlyStopping counter: 9 out of 10
# Epoch 36/100 | Train Loss: 0.5142, Train Acc: 0.7402 | Val Loss: 0.4960, Val Acc: 0.7545
# EarlyStopping counter: 10 out of 10
# Early stopping triggered. Ending training.
#
# ========== Fold 3 ==========
#
# Epoch 1/100 | Train Loss: 0.6354, Train Acc: 0.6349 | Val Loss: 0.5612, Val Acc: 0.7235
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_3.pth
# Epoch 2/100 | Train Loss: 0.5863, Train Acc: 0.6927 | Val Loss: 0.5454, Val Acc: 0.7370
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_3.pth
# Epoch 3/100 | Train Loss: 0.5739, Train Acc: 0.7037 | Val Loss: 0.5268, Val Acc: 0.7440
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_3.pth
# Epoch 4/100 | Train Loss: 0.5660, Train Acc: 0.7026 | Val Loss: 0.5387, Val Acc: 0.7505
# EarlyStopping counter: 1 out of 10
# Epoch 5/100 | Train Loss: 0.5623, Train Acc: 0.7089 | Val Loss: 0.5343, Val Acc: 0.7475
# EarlyStopping counter: 2 out of 10
# Epoch 6/100 | Train Loss: 0.5625, Train Acc: 0.7111 | Val Loss: 0.5292, Val Acc: 0.7540
# EarlyStopping counter: 3 out of 10
# Epoch 7/100 | Train Loss: 0.5533, Train Acc: 0.7163 | Val Loss: 0.5219, Val Acc: 0.7540
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_3.pth
# Epoch 8/100 | Train Loss: 0.5525, Train Acc: 0.7133 | Val Loss: 0.5262, Val Acc: 0.7595
# EarlyStopping counter: 1 out of 10
# Epoch 9/100 | Train Loss: 0.5556, Train Acc: 0.7125 | Val Loss: 0.5206, Val Acc: 0.7600
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_3.pth
# Epoch 10/100 | Train Loss: 0.5509, Train Acc: 0.7147 | Val Loss: 0.5223, Val Acc: 0.7625
# EarlyStopping counter: 1 out of 10
# Epoch 11/100 | Train Loss: 0.5504, Train Acc: 0.7213 | Val Loss: 0.5269, Val Acc: 0.7605
# EarlyStopping counter: 2 out of 10
# Epoch 12/100 | Train Loss: 0.5402, Train Acc: 0.7273 | Val Loss: 0.5289, Val Acc: 0.7630
# EarlyStopping counter: 3 out of 10
# Epoch 13/100 | Train Loss: 0.5400, Train Acc: 0.7216 | Val Loss: 0.5140, Val Acc: 0.7540
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_3.pth
# Epoch 14/100 | Train Loss: 0.5477, Train Acc: 0.7205 | Val Loss: 0.5036, Val Acc: 0.7510
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_3.pth
# Epoch 15/100 | Train Loss: 0.5443, Train Acc: 0.7173 | Val Loss: 0.5080, Val Acc: 0.7550
# EarlyStopping counter: 1 out of 10
# Epoch 16/100 | Train Loss: 0.5422, Train Acc: 0.7209 | Val Loss: 0.5266, Val Acc: 0.7705
# EarlyStopping counter: 2 out of 10
# Epoch 17/100 | Train Loss: 0.5418, Train Acc: 0.7223 | Val Loss: 0.5041, Val Acc: 0.7530
# EarlyStopping counter: 3 out of 10
# Epoch 18/100 | Train Loss: 0.5418, Train Acc: 0.7324 | Val Loss: 0.5007, Val Acc: 0.7700
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_3.pth
# Epoch 19/100 | Train Loss: 0.5340, Train Acc: 0.7321 | Val Loss: 0.5241, Val Acc: 0.7500
# EarlyStopping counter: 1 out of 10
# Epoch 20/100 | Train Loss: 0.5337, Train Acc: 0.7260 | Val Loss: 0.5090, Val Acc: 0.7630
# EarlyStopping counter: 2 out of 10
# Epoch 21/100 | Train Loss: 0.5250, Train Acc: 0.7350 | Val Loss: 0.4911, Val Acc: 0.7625
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_3.pth
# Epoch 22/100 | Train Loss: 0.5287, Train Acc: 0.7348 | Val Loss: 0.4957, Val Acc: 0.7640
# EarlyStopping counter: 1 out of 10
# Epoch 23/100 | Train Loss: 0.5243, Train Acc: 0.7386 | Val Loss: 0.5000, Val Acc: 0.7585
# EarlyStopping counter: 2 out of 10
# Epoch 24/100 | Train Loss: 0.5308, Train Acc: 0.7382 | Val Loss: 0.5256, Val Acc: 0.7605
# EarlyStopping counter: 3 out of 10
# Epoch 25/100 | Train Loss: 0.5300, Train Acc: 0.7376 | Val Loss: 0.4939, Val Acc: 0.7680
# EarlyStopping counter: 4 out of 10
# Epoch 26/100 | Train Loss: 0.5266, Train Acc: 0.7319 | Val Loss: 0.4982, Val Acc: 0.7645
# EarlyStopping counter: 5 out of 10
# Epoch 27/100 | Train Loss: 0.5236, Train Acc: 0.7376 | Val Loss: 0.4898, Val Acc: 0.7705
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_3.pth
# Epoch 28/100 | Train Loss: 0.5222, Train Acc: 0.7349 | Val Loss: 0.4933, Val Acc: 0.7655
# EarlyStopping counter: 1 out of 10
# Epoch 29/100 | Train Loss: 0.5230, Train Acc: 0.7366 | Val Loss: 0.5035, Val Acc: 0.7655
# EarlyStopping counter: 2 out of 10
# Epoch 30/100 | Train Loss: 0.5198, Train Acc: 0.7420 | Val Loss: 0.4917, Val Acc: 0.7755
# EarlyStopping counter: 3 out of 10
# Epoch 31/100 | Train Loss: 0.5161, Train Acc: 0.7434 | Val Loss: 0.4929, Val Acc: 0.7715
# EarlyStopping counter: 4 out of 10
# Epoch 32/100 | Train Loss: 0.5196, Train Acc: 0.7391 | Val Loss: 0.4914, Val Acc: 0.7690
# EarlyStopping counter: 5 out of 10
# Epoch 33/100 | Train Loss: 0.5181, Train Acc: 0.7388 | Val Loss: 0.5092, Val Acc: 0.7665
# EarlyStopping counter: 6 out of 10
# Epoch 34/100 | Train Loss: 0.5244, Train Acc: 0.7365 | Val Loss: 0.4977, Val Acc: 0.7800
# EarlyStopping counter: 7 out of 10
# Epoch 35/100 | Train Loss: 0.5225, Train Acc: 0.7361 | Val Loss: 0.5043, Val Acc: 0.7770
# EarlyStopping counter: 8 out of 10
# Epoch 36/100 | Train Loss: 0.5180, Train Acc: 0.7374 | Val Loss: 0.4845, Val Acc: 0.7785
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_3.pth
# Epoch 37/100 | Train Loss: 0.5175, Train Acc: 0.7388 | Val Loss: 0.4957, Val Acc: 0.7700
# EarlyStopping counter: 1 out of 10
# Epoch 38/100 | Train Loss: 0.5091, Train Acc: 0.7445 | Val Loss: 0.4967, Val Acc: 0.7780
# EarlyStopping counter: 2 out of 10
# Epoch 39/100 | Train Loss: 0.5072, Train Acc: 0.7442 | Val Loss: 0.4876, Val Acc: 0.7635
# EarlyStopping counter: 3 out of 10
# Epoch 40/100 | Train Loss: 0.5068, Train Acc: 0.7451 | Val Loss: 0.4833, Val Acc: 0.7795
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_3.pth
# Epoch 41/100 | Train Loss: 0.5085, Train Acc: 0.7478 | Val Loss: 0.4899, Val Acc: 0.7675
# EarlyStopping counter: 1 out of 10
# Epoch 42/100 | Train Loss: 0.5105, Train Acc: 0.7471 | Val Loss: 0.5013, Val Acc: 0.7690
# EarlyStopping counter: 2 out of 10
# Epoch 43/100 | Train Loss: 0.5132, Train Acc: 0.7489 | Val Loss: 0.5004, Val Acc: 0.7815
# EarlyStopping counter: 3 out of 10
# Epoch 44/100 | Train Loss: 0.5053, Train Acc: 0.7436 | Val Loss: 0.5107, Val Acc: 0.7695
# EarlyStopping counter: 4 out of 10
# Epoch 45/100 | Train Loss: 0.5122, Train Acc: 0.7412 | Val Loss: 0.4844, Val Acc: 0.7845
# EarlyStopping counter: 5 out of 10
# Epoch 46/100 | Train Loss: 0.5075, Train Acc: 0.7448 | Val Loss: 0.4854, Val Acc: 0.7770
# EarlyStopping counter: 6 out of 10
# Epoch 47/100 | Train Loss: 0.5121, Train Acc: 0.7425 | Val Loss: 0.4932, Val Acc: 0.7735
# EarlyStopping counter: 7 out of 10
# Epoch 48/100 | Train Loss: 0.5072, Train Acc: 0.7515 | Val Loss: 0.4767, Val Acc: 0.7770
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_3.pth
# Epoch 49/100 | Train Loss: 0.5086, Train Acc: 0.7469 | Val Loss: 0.4871, Val Acc: 0.7680
# EarlyStopping counter: 1 out of 10
# Epoch 50/100 | Train Loss: 0.5058, Train Acc: 0.7499 | Val Loss: 0.4802, Val Acc: 0.7795
# EarlyStopping counter: 2 out of 10
# Epoch 51/100 | Train Loss: 0.5012, Train Acc: 0.7524 | Val Loss: 0.4904, Val Acc: 0.7840
# EarlyStopping counter: 3 out of 10
# Epoch 52/100 | Train Loss: 0.5109, Train Acc: 0.7481 | Val Loss: 0.4942, Val Acc: 0.7720
# EarlyStopping counter: 4 out of 10
# Epoch 53/100 | Train Loss: 0.5102, Train Acc: 0.7456 | Val Loss: 0.4893, Val Acc: 0.7720
# EarlyStopping counter: 5 out of 10
# Epoch 54/100 | Train Loss: 0.5022, Train Acc: 0.7514 | Val Loss: 0.4820, Val Acc: 0.7810
# EarlyStopping counter: 6 out of 10
# Epoch 55/100 | Train Loss: 0.4992, Train Acc: 0.7565 | Val Loss: 0.4927, Val Acc: 0.7790
# EarlyStopping counter: 7 out of 10
# Epoch 56/100 | Train Loss: 0.4990, Train Acc: 0.7551 | Val Loss: 0.4962, Val Acc: 0.7800
# EarlyStopping counter: 8 out of 10
# Epoch 57/100 | Train Loss: 0.5026, Train Acc: 0.7552 | Val Loss: 0.4971, Val Acc: 0.7770
# EarlyStopping counter: 9 out of 10
# Epoch 58/100 | Train Loss: 0.4965, Train Acc: 0.7521 | Val Loss: 0.4850, Val Acc: 0.7880
# EarlyStopping counter: 10 out of 10
# Early stopping triggered. Ending training.
#
# ========== Fold 4 ==========
#
# Epoch 1/100 | Train Loss: 0.6408, Train Acc: 0.6300 | Val Loss: 0.5743, Val Acc: 0.7105
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_4.pth
# Epoch 2/100 | Train Loss: 0.5784, Train Acc: 0.6993 | Val Loss: 0.5563, Val Acc: 0.7285
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_4.pth
# Epoch 3/100 | Train Loss: 0.5726, Train Acc: 0.7041 | Val Loss: 0.5516, Val Acc: 0.7365
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_4.pth
# Epoch 4/100 | Train Loss: 0.5637, Train Acc: 0.7106 | Val Loss: 0.5461, Val Acc: 0.7285
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_4.pth
# Epoch 5/100 | Train Loss: 0.5585, Train Acc: 0.7126 | Val Loss: 0.5204, Val Acc: 0.7440
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_4.pth
# Epoch 6/100 | Train Loss: 0.5541, Train Acc: 0.7161 | Val Loss: 0.5271, Val Acc: 0.7290
# EarlyStopping counter: 1 out of 10
# Epoch 7/100 | Train Loss: 0.5502, Train Acc: 0.7186 | Val Loss: 0.5195, Val Acc: 0.7445
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_4.pth
# Epoch 8/100 | Train Loss: 0.5546, Train Acc: 0.7114 | Val Loss: 0.5337, Val Acc: 0.7470
# EarlyStopping counter: 1 out of 10
# Epoch 9/100 | Train Loss: 0.5439, Train Acc: 0.7228 | Val Loss: 0.5330, Val Acc: 0.7270
# EarlyStopping counter: 2 out of 10
# Epoch 10/100 | Train Loss: 0.5451, Train Acc: 0.7214 | Val Loss: 0.5389, Val Acc: 0.7315
# EarlyStopping counter: 3 out of 10
# Epoch 11/100 | Train Loss: 0.5397, Train Acc: 0.7333 | Val Loss: 0.5230, Val Acc: 0.7420
# EarlyStopping counter: 4 out of 10
# Epoch 12/100 | Train Loss: 0.5458, Train Acc: 0.7200 | Val Loss: 0.5240, Val Acc: 0.7475
# EarlyStopping counter: 5 out of 10
# Epoch 13/100 | Train Loss: 0.5411, Train Acc: 0.7279 | Val Loss: 0.5151, Val Acc: 0.7470
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_4.pth
# Epoch 14/100 | Train Loss: 0.5388, Train Acc: 0.7286 | Val Loss: 0.5195, Val Acc: 0.7445
# EarlyStopping counter: 1 out of 10
# Epoch 15/100 | Train Loss: 0.5397, Train Acc: 0.7259 | Val Loss: 0.5187, Val Acc: 0.7435
# EarlyStopping counter: 2 out of 10
# Epoch 16/100 | Train Loss: 0.5460, Train Acc: 0.7241 | Val Loss: 0.5064, Val Acc: 0.7485
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_4.pth
# Epoch 17/100 | Train Loss: 0.5388, Train Acc: 0.7301 | Val Loss: 0.5249, Val Acc: 0.7440
# EarlyStopping counter: 1 out of 10
# Epoch 18/100 | Train Loss: 0.5358, Train Acc: 0.7283 | Val Loss: 0.5121, Val Acc: 0.7550
# EarlyStopping counter: 2 out of 10
# Epoch 19/100 | Train Loss: 0.5330, Train Acc: 0.7371 | Val Loss: 0.4959, Val Acc: 0.7635
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_4.pth
# Epoch 20/100 | Train Loss: 0.5363, Train Acc: 0.7293 | Val Loss: 0.5099, Val Acc: 0.7575
# EarlyStopping counter: 1 out of 10
# Epoch 21/100 | Train Loss: 0.5327, Train Acc: 0.7328 | Val Loss: 0.5158, Val Acc: 0.7510
# EarlyStopping counter: 2 out of 10
# Epoch 22/100 | Train Loss: 0.5325, Train Acc: 0.7321 | Val Loss: 0.5172, Val Acc: 0.7600
# EarlyStopping counter: 3 out of 10
# Epoch 23/100 | Train Loss: 0.5306, Train Acc: 0.7314 | Val Loss: 0.5049, Val Acc: 0.7480
# EarlyStopping counter: 4 out of 10
# Epoch 24/100 | Train Loss: 0.5237, Train Acc: 0.7326 | Val Loss: 0.5156, Val Acc: 0.7535
# EarlyStopping counter: 5 out of 10
# Epoch 25/100 | Train Loss: 0.5277, Train Acc: 0.7344 | Val Loss: 0.5004, Val Acc: 0.7510
# EarlyStopping counter: 6 out of 10
# Epoch 26/100 | Train Loss: 0.5222, Train Acc: 0.7384 | Val Loss: 0.5042, Val Acc: 0.7580
# EarlyStopping counter: 7 out of 10
# Epoch 27/100 | Train Loss: 0.5203, Train Acc: 0.7386 | Val Loss: 0.5033, Val Acc: 0.7605
# EarlyStopping counter: 8 out of 10
# Epoch 28/100 | Train Loss: 0.5234, Train Acc: 0.7405 | Val Loss: 0.5137, Val Acc: 0.7605
# EarlyStopping counter: 9 out of 10
# Epoch 29/100 | Train Loss: 0.5219, Train Acc: 0.7379 | Val Loss: 0.5053, Val Acc: 0.7575
# EarlyStopping counter: 10 out of 10
# Early stopping triggered. Ending training.
#
# ========== Fold 5 ==========
#
# Epoch 1/100 | Train Loss: 0.6307, Train Acc: 0.6410 | Val Loss: 0.5657, Val Acc: 0.7120
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_5.pth
# Epoch 2/100 | Train Loss: 0.5856, Train Acc: 0.6904 | Val Loss: 0.5390, Val Acc: 0.7410
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_5.pth
# Epoch 3/100 | Train Loss: 0.5715, Train Acc: 0.7020 | Val Loss: 0.5308, Val Acc: 0.7470
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_5.pth
# Epoch 4/100 | Train Loss: 0.5606, Train Acc: 0.7073 | Val Loss: 0.5486, Val Acc: 0.7120
# EarlyStopping counter: 1 out of 10
# Epoch 5/100 | Train Loss: 0.5676, Train Acc: 0.7075 | Val Loss: 0.5434, Val Acc: 0.7210
# EarlyStopping counter: 2 out of 10
# Epoch 6/100 | Train Loss: 0.5632, Train Acc: 0.7069 | Val Loss: 0.5357, Val Acc: 0.7355
# EarlyStopping counter: 3 out of 10
# Epoch 7/100 | Train Loss: 0.5527, Train Acc: 0.7193 | Val Loss: 0.5581, Val Acc: 0.7115
# EarlyStopping counter: 4 out of 10
# Epoch 8/100 | Train Loss: 0.5519, Train Acc: 0.7189 | Val Loss: 0.5277, Val Acc: 0.7530
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_5.pth
# Epoch 9/100 | Train Loss: 0.5516, Train Acc: 0.7220 | Val Loss: 0.5311, Val Acc: 0.7505
# EarlyStopping counter: 1 out of 10
# Epoch 10/100 | Train Loss: 0.5529, Train Acc: 0.7184 | Val Loss: 0.5247, Val Acc: 0.7390
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_5.pth
# Epoch 11/100 | Train Loss: 0.5515, Train Acc: 0.7208 | Val Loss: 0.5288, Val Acc: 0.7585
# EarlyStopping counter: 1 out of 10
# Epoch 12/100 | Train Loss: 0.5494, Train Acc: 0.7180 | Val Loss: 0.5286, Val Acc: 0.7575
# EarlyStopping counter: 2 out of 10
# Epoch 13/100 | Train Loss: 0.5414, Train Acc: 0.7228 | Val Loss: 0.5345, Val Acc: 0.7585
# EarlyStopping counter: 3 out of 10
# Epoch 14/100 | Train Loss: 0.5456, Train Acc: 0.7236 | Val Loss: 0.5225, Val Acc: 0.7590
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_5.pth
# Epoch 15/100 | Train Loss: 0.5402, Train Acc: 0.7264 | Val Loss: 0.5385, Val Acc: 0.7435
# EarlyStopping counter: 1 out of 10
# Epoch 16/100 | Train Loss: 0.5395, Train Acc: 0.7328 | Val Loss: 0.5222, Val Acc: 0.7560
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_5.pth
# Epoch 17/100 | Train Loss: 0.5329, Train Acc: 0.7341 | Val Loss: 0.5108, Val Acc: 0.7610
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_5.pth
# Epoch 18/100 | Train Loss: 0.5365, Train Acc: 0.7258 | Val Loss: 0.5333, Val Acc: 0.7365
# EarlyStopping counter: 1 out of 10
# Epoch 19/100 | Train Loss: 0.5308, Train Acc: 0.7294 | Val Loss: 0.5108, Val Acc: 0.7620
# EarlyStopping counter: 2 out of 10
# Epoch 20/100 | Train Loss: 0.5355, Train Acc: 0.7283 | Val Loss: 0.5175, Val Acc: 0.7570
# EarlyStopping counter: 3 out of 10
# Epoch 21/100 | Train Loss: 0.5274, Train Acc: 0.7354 | Val Loss: 0.5209, Val Acc: 0.7505
# EarlyStopping counter: 4 out of 10
# Epoch 22/100 | Train Loss: 0.5344, Train Acc: 0.7310 | Val Loss: 0.5090, Val Acc: 0.7635
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_5.pth
# Epoch 23/100 | Train Loss: 0.5297, Train Acc: 0.7345 | Val Loss: 0.5105, Val Acc: 0.7670
# EarlyStopping counter: 1 out of 10
# Epoch 24/100 | Train Loss: 0.5249, Train Acc: 0.7419 | Val Loss: 0.5075, Val Acc: 0.7565
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_5.pth
# Epoch 25/100 | Train Loss: 0.5207, Train Acc: 0.7338 | Val Loss: 0.5020, Val Acc: 0.7670
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_5.pth
# Epoch 26/100 | Train Loss: 0.5222, Train Acc: 0.7360 | Val Loss: 0.5116, Val Acc: 0.7690
# EarlyStopping counter: 1 out of 10
# Epoch 27/100 | Train Loss: 0.5306, Train Acc: 0.7329 | Val Loss: 0.5120, Val Acc: 0.7710
# EarlyStopping counter: 2 out of 10
# Epoch 28/100 | Train Loss: 0.5131, Train Acc: 0.7432 | Val Loss: 0.5137, Val Acc: 0.7625
# EarlyStopping counter: 3 out of 10
# Epoch 29/100 | Train Loss: 0.5175, Train Acc: 0.7409 | Val Loss: 0.5120, Val Acc: 0.7625
# EarlyStopping counter: 4 out of 10
# Epoch 30/100 | Train Loss: 0.5265, Train Acc: 0.7396 | Val Loss: 0.5191, Val Acc: 0.7565
# EarlyStopping counter: 5 out of 10
# Epoch 31/100 | Train Loss: 0.5222, Train Acc: 0.7398 | Val Loss: 0.5142, Val Acc: 0.7695
# EarlyStopping counter: 6 out of 10
# Epoch 32/100 | Train Loss: 0.5218, Train Acc: 0.7364 | Val Loss: 0.5042, Val Acc: 0.7665
# EarlyStopping counter: 7 out of 10
# Epoch 33/100 | Train Loss: 0.5206, Train Acc: 0.7381 | Val Loss: 0.4994, Val Acc: 0.7650
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_5.pth
# Epoch 34/100 | Train Loss: 0.5196, Train Acc: 0.7402 | Val Loss: 0.5451, Val Acc: 0.7245
# EarlyStopping counter: 1 out of 10
# Epoch 35/100 | Train Loss: 0.5116, Train Acc: 0.7409 | Val Loss: 0.5070, Val Acc: 0.7725
# EarlyStopping counter: 2 out of 10
# Epoch 36/100 | Train Loss: 0.5170, Train Acc: 0.7419 | Val Loss: 0.5065, Val Acc: 0.7735
# EarlyStopping counter: 3 out of 10
# Epoch 37/100 | Train Loss: 0.5144, Train Acc: 0.7431 | Val Loss: 0.5171, Val Acc: 0.7745
# EarlyStopping counter: 4 out of 10
# Epoch 38/100 | Train Loss: 0.5187, Train Acc: 0.7411 | Val Loss: 0.5080, Val Acc: 0.7740
# EarlyStopping counter: 5 out of 10
# Epoch 39/100 | Train Loss: 0.5117, Train Acc: 0.7474 | Val Loss: 0.4960, Val Acc: 0.7630
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_5.pth
# Epoch 40/100 | Train Loss: 0.5072, Train Acc: 0.7474 | Val Loss: 0.5015, Val Acc: 0.7660
# EarlyStopping counter: 1 out of 10
# Epoch 41/100 | Train Loss: 0.5131, Train Acc: 0.7426 | Val Loss: 0.5018, Val Acc: 0.7740
# EarlyStopping counter: 2 out of 10
# Epoch 42/100 | Train Loss: 0.5154, Train Acc: 0.7451 | Val Loss: 0.5011, Val Acc: 0.7695
# EarlyStopping counter: 3 out of 10
# Epoch 43/100 | Train Loss: 0.5109, Train Acc: 0.7412 | Val Loss: 0.5048, Val Acc: 0.7625
# EarlyStopping counter: 4 out of 10
# Epoch 44/100 | Train Loss: 0.5097, Train Acc: 0.7455 | Val Loss: 0.5064, Val Acc: 0.7645
# EarlyStopping counter: 5 out of 10
# Epoch 45/100 | Train Loss: 0.5059, Train Acc: 0.7484 | Val Loss: 0.5035, Val Acc: 0.7725
# EarlyStopping counter: 6 out of 10
# Epoch 46/100 | Train Loss: 0.5031, Train Acc: 0.7546 | Val Loss: 0.4933, Val Acc: 0.7775
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_5.pth
# Epoch 47/100 | Train Loss: 0.5019, Train Acc: 0.7475 | Val Loss: 0.4948, Val Acc: 0.7755
# EarlyStopping counter: 1 out of 10
# Epoch 48/100 | Train Loss: 0.5014, Train Acc: 0.7499 | Val Loss: 0.4970, Val Acc: 0.7680
# EarlyStopping counter: 2 out of 10
# Epoch 49/100 | Train Loss: 0.5021, Train Acc: 0.7518 | Val Loss: 0.5028, Val Acc: 0.7710
# EarlyStopping counter: 3 out of 10
# Epoch 50/100 | Train Loss: 0.5076, Train Acc: 0.7491 | Val Loss: 0.4961, Val Acc: 0.7770
# EarlyStopping counter: 4 out of 10
# Epoch 51/100 | Train Loss: 0.4982, Train Acc: 0.7466 | Val Loss: 0.4969, Val Acc: 0.7755
# EarlyStopping counter: 5 out of 10
# Epoch 52/100 | Train Loss: 0.4985, Train Acc: 0.7518 | Val Loss: 0.4926, Val Acc: 0.7765
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_5.pth
# Epoch 53/100 | Train Loss: 0.5000, Train Acc: 0.7560 | Val Loss: 0.5055, Val Acc: 0.7740
# EarlyStopping counter: 1 out of 10
# Epoch 54/100 | Train Loss: 0.4985, Train Acc: 0.7476 | Val Loss: 0.5010, Val Acc: 0.7700
# EarlyStopping counter: 2 out of 10
# Epoch 55/100 | Train Loss: 0.4997, Train Acc: 0.7549 | Val Loss: 0.4957, Val Acc: 0.7745
# EarlyStopping counter: 3 out of 10
# Epoch 56/100 | Train Loss: 0.4969, Train Acc: 0.7521 | Val Loss: 0.5083, Val Acc: 0.7740
# EarlyStopping counter: 4 out of 10
# Epoch 57/100 | Train Loss: 0.4998, Train Acc: 0.7559 | Val Loss: 0.4885, Val Acc: 0.7760
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_5.pth
# Epoch 58/100 | Train Loss: 0.5031, Train Acc: 0.7549 | Val Loss: 0.4921, Val Acc: 0.7685
# EarlyStopping counter: 1 out of 10
# Epoch 59/100 | Train Loss: 0.4984, Train Acc: 0.7538 | Val Loss: 0.4914, Val Acc: 0.7730
# EarlyStopping counter: 2 out of 10
# Epoch 60/100 | Train Loss: 0.4959, Train Acc: 0.7570 | Val Loss: 0.5009, Val Acc: 0.7670
# EarlyStopping counter: 3 out of 10
# Epoch 61/100 | Train Loss: 0.4961, Train Acc: 0.7541 | Val Loss: 0.4852, Val Acc: 0.7735
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_5.pth
# Epoch 62/100 | Train Loss: 0.4901, Train Acc: 0.7559 | Val Loss: 0.4840, Val Acc: 0.7695
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_5.pth
# Epoch 63/100 | Train Loss: 0.4999, Train Acc: 0.7521 | Val Loss: 0.5006, Val Acc: 0.7755
# EarlyStopping counter: 1 out of 10
# Epoch 64/100 | Train Loss: 0.4923, Train Acc: 0.7549 | Val Loss: 0.4930, Val Acc: 0.7720
# EarlyStopping counter: 2 out of 10
# Epoch 65/100 | Train Loss: 0.4979, Train Acc: 0.7494 | Val Loss: 0.4881, Val Acc: 0.7675
# EarlyStopping counter: 3 out of 10
# Epoch 66/100 | Train Loss: 0.4865, Train Acc: 0.7634 | Val Loss: 0.4842, Val Acc: 0.7760
# EarlyStopping counter: 4 out of 10
# Epoch 67/100 | Train Loss: 0.4960, Train Acc: 0.7520 | Val Loss: 0.5051, Val Acc: 0.7705
# EarlyStopping counter: 5 out of 10
# Epoch 68/100 | Train Loss: 0.4941, Train Acc: 0.7594 | Val Loss: 0.5042, Val Acc: 0.7650
# EarlyStopping counter: 6 out of 10
# Epoch 69/100 | Train Loss: 0.4931, Train Acc: 0.7554 | Val Loss: 0.4862, Val Acc: 0.7850
# EarlyStopping counter: 7 out of 10
# Epoch 70/100 | Train Loss: 0.4888, Train Acc: 0.7550 | Val Loss: 0.4847, Val Acc: 0.7825
# EarlyStopping counter: 8 out of 10
# Epoch 71/100 | Train Loss: 0.4866, Train Acc: 0.7536 | Val Loss: 0.4869, Val Acc: 0.7755
# EarlyStopping counter: 9 out of 10
# Epoch 72/100 | Train Loss: 0.4908, Train Acc: 0.7574 | Val Loss: 0.4801, Val Acc: 0.7810
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_5.pth
# Epoch 73/100 | Train Loss: 0.4867, Train Acc: 0.7636 | Val Loss: 0.4900, Val Acc: 0.7735
# EarlyStopping counter: 1 out of 10
# Epoch 74/100 | Train Loss: 0.4908, Train Acc: 0.7570 | Val Loss: 0.4729, Val Acc: 0.7735
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_InceptionV3_CV_fold_5.pth
# Epoch 75/100 | Train Loss: 0.4867, Train Acc: 0.7604 | Val Loss: 0.4787, Val Acc: 0.7815
# EarlyStopping counter: 1 out of 10
# Epoch 76/100 | Train Loss: 0.4911, Train Acc: 0.7546 | Val Loss: 0.4843, Val Acc: 0.7695
# EarlyStopping counter: 2 out of 10
# Epoch 77/100 | Train Loss: 0.4893, Train Acc: 0.7566 | Val Loss: 0.4825, Val Acc: 0.7740
# EarlyStopping counter: 3 out of 10
# Epoch 78/100 | Train Loss: 0.4887, Train Acc: 0.7554 | Val Loss: 0.4815, Val Acc: 0.7745
# EarlyStopping counter: 4 out of 10
# Epoch 79/100 | Train Loss: 0.4884, Train Acc: 0.7612 | Val Loss: 0.4816, Val Acc: 0.7755
# EarlyStopping counter: 5 out of 10
# Epoch 80/100 | Train Loss: 0.4889, Train Acc: 0.7636 | Val Loss: 0.4929, Val Acc: 0.7740
# EarlyStopping counter: 6 out of 10
# Epoch 81/100 | Train Loss: 0.4883, Train Acc: 0.7586 | Val Loss: 0.4836, Val Acc: 0.7705
# EarlyStopping counter: 7 out of 10
# Epoch 82/100 | Train Loss: 0.4868, Train Acc: 0.7628 | Val Loss: 0.4770, Val Acc: 0.7770
# EarlyStopping counter: 8 out of 10
# Epoch 83/100 | Train Loss: 0.4926, Train Acc: 0.7591 | Val Loss: 0.4907, Val Acc: 0.7775
# EarlyStopping counter: 9 out of 10
# Epoch 84/100 | Train Loss: 0.4846, Train Acc: 0.7630 | Val Loss: 0.4921, Val Acc: 0.7750
# EarlyStopping counter: 10 out of 10
# Early stopping triggered. Ending training.
#
# ========== Cross-Validation Results ==========
#
#    fold  train_loss  train_accuracy  val_loss  val_accuracy
# 0     1    0.517002        0.737750  0.506119        0.7745
# 1     2    0.514245        0.740250  0.496045        0.7545
# 2     3    0.496481        0.752125  0.484977        0.7880
# 3     4    0.521891        0.737875  0.505327        0.7575
# 4     5    0.484616        0.763000  0.492054        0.7750
#
# Average Validation Accuracy: 0.7699

# %%
# Convert results to DataFrame
cv_metrics_df = pd.DataFrame(cv_metrics)

# Calculate average metrics
avg_metrics = cv_metrics_df.mean().to_dict()
avg_metrics["Fold"] = "Average"

# Add the average metrics to the DataFrame
cv_metrics_df = cv_metrics_df.append(avg_metrics, ignore_index=True)

# Save results to CSV file
csv_file_name = f"CV_Results/{file_name}.csv"
cv_metrics_df.to_csv(csv_file_name, index=False)

print(f"Cross-validation metrics saved to {csv_file_name}")
# Out:
# Cross-validation metrics saved to CV_Results/Benchmark_InceptionV3_CV.csv
# /tmp/job.2295042.hpc/ipykernel_4142396/1908723448.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cv_metrics_df = cv_metrics_df.append(avg_metrics, ignore_index=True)
