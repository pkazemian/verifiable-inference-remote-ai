# %%
# Import necessary libraries
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Subset, DataLoader, Dataset
from torchvision import datasets, transforms, models
from torchvision.models import efficientnet_b0
from torchvision.models.efficientnet import SqueezeExcitation
import matplotlib.pyplot as plt
import multiprocessing
import numpy as np
from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score,  roc_auc_score, 
    cohen_kappa_score, matthews_corrcoef, confusion_matrix, average_precision_score, fbeta_score,
    precision_recall_curve, balanced_accuracy_score)
import pandas as pd
from sklearn.utils import shuffle
import random
import albumentations as A
from albumentations.pytorch import ToTensorV2
import pandas as pd
import torch_optimizer
import cv2
from skimage import measure
from torchvision.utils import make_grid
# %matplotlib inline
# Out:
# /home/pxk409/Skin_EfficientNet/GCCcore-11.3.0/lib/python3.10/site-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 1.4.23 (you have 1.4.21). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
# Check for GPU availability
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# !nvidia-smi
# Out:
# Thu Dec 19 23:16:03 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.54.03              Driver Version: 535.54.03    CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-PCIE-32GB           On  | 00000000:3B:00.0 Off |                    0 |
# | N/A   35C    P0              41W / 250W |   3950MiB / 32768MiB |     53%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A   4175738      C   ...on/3.10.4-GCCcore-11.3.0/bin/python     3946MiB |
# +---------------------------------------------------------------------------------------+

# %%
file_name = "Benchmark_VisionTransformer_CV"

# %%
import os

# Define directories of where the datasets reside
base_dir = '/home/pxk409/skin_lesions_13k'

# Define directories of where the training, validation and test sets reside
train_dir = os.path.join(base_dir, 'train')
test_dir = os.path.join(base_dir, 'test')

# Define directories of where the benign and malignant images reside
train_benign_dir = os.path.join(base_dir, 'train/benign')
train_malignant_dir = os.path.join(base_dir, 'train/malignant')
test_benign_dir = os.path.join(base_dir, 'test/benign')
test_malignant_dir = os.path.join(base_dir, 'test/malignant')

# %%
# Let's check the number of images in each set
print('Total training benign images:', len(os.listdir(train_benign_dir)))
print('Total training malignant images:', len(os.listdir(train_malignant_dir)))
print('Total test benign images:', len(os.listdir(test_benign_dir)))
print('Total test malignant images:', len(os.listdir(test_malignant_dir)))
# Out:
# Total training benign images: 5000
# Total training malignant images: 5000
# Total test benign images: 1500
# Total test malignant images: 1500

# %%
# Load full dataset
full_dataset = datasets.ImageFolder(root=train_dir)

# Extract labels from the dataset
#labels = [label for _, label in full_dataset.samples]

# Stratified split (80% train, 20% validation)
#split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=123456)
#train_idx, val_idx = next(split.split(np.zeros(len(labels)), labels))

# Create training and validation subsets
#train_dataset = Subset(full_dataset, train_idx)
#val_dataset = Subset(full_dataset, val_idx)

#print(f"Training set: {len(train_idx)} samples")
#print(f"Validation set: {len(val_idx)} samples")

# Count the number of samples per class in each split
#train_classes = [full_dataset.targets[idx] for idx in train_dataset.indices]
#val_classes = [full_dataset.targets[idx] for idx in val_dataset.indices]

#print(f"Training set class counts: {np.bincount(train_classes)}")
#print(f"Validation set class counts: {np.bincount(val_classes)}")

# %%
# Custom transform to integrate Albumentations with PyTorch
class AlbumentationsTransform:
    def __init__(self, augmentations):
        self.augmentations = A.Compose(augmentations)

    def __call__(self, image):
        image = np.array(image)  # Convert PIL Image to NumPy array
        augmented = self.augmentations(image=image)
        return augmented["image"]

# Simple augmentations for training
simple_transform = AlbumentationsTransform([
    A.RandomResizedCrop(height=224, width=224, scale=(0.8, 1.0), p=1.0),  # Random crop and resize
    A.HorizontalFlip(p=0.5),  # Horizontal flip
    A.VerticalFlip(p=0.5),  # Vertical flip
    #A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1, p=0.5),  # Color jitter
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  # Normalize to match pre-trained model
    ToTensorV2(),  # Convert to PyTorch tensor and ensure dtype=torch.float32
])


# Use AlbumentationsTransform directly in the loaders for consistency
train_transform = simple_transform

# Albumentations augmentations for validation and test
albumentations_val_test_transform = AlbumentationsTransform([
    A.Resize(height=224, width=224),  # Resize to EfficientNet input size
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  # Normalize to match pre-trained model
    ToTensorV2()  # Convert to PyTorch tensor
])

test_val_transform = albumentations_val_test_transform

# %%
class TransformDataset(Dataset):
    def __init__(self, dataset, transform):
        """
        Args:
            dataset: Original dataset (e.g., Subset of ImageFolder).
            transform: Transform to be applied to the images in the dataset.
        """
        self.dataset = dataset
        self.transform = transform

    def __getitem__(self, idx):
        image, label = self.dataset[idx]
        if self.transform:
            image = self.transform(image)
        return image, label

    def __len__(self):
        return len(self.dataset)

# %%
# Wrap subsets with the respective transforms
#train_dataset = TransformDataset(train_dataset, train_transform)
#val_dataset = TransformDataset(val_dataset, test_val_transform)

# %%
# Load and prepare the test dataset
#test_dataset = datasets.ImageFolder(root=test_dir, transform=test_val_transform)
test_dataset = datasets.ImageFolder(root=test_dir)
test_dataset = TransformDataset(test_dataset, test_val_transform)

# %%
# Create data loaders
batch_size = 64
#num_cpus = multiprocessing.cpu_count()  # Use all CPU cores
#print(f"Number of CPU cores: {num_cpus}")
#num_workers = 16


#train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
#val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
#train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=True)
#val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=True)
#test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=True)

# %%
def initialize_model():
    # Load pre-trained VisionTransformer
    model = models.vit_b_16(weights=models.ViT_B_16_Weights.DEFAULT)

    # Freeze the transformer encoder (feature extractor)
    for param in model.encoder.parameters():
        param.requires_grad = False

    # Replace the classifier (head) with a custom one
    # VisionTransformer's feature size before the classifier is 768
    model.heads = nn.Sequential(
        nn.Dropout(0.5),
        nn.Linear(model.heads.head.in_features, 512),  # ViT's default feature size is 768
        nn.ReLU(),
        nn.Dropout(0.5),
        nn.Linear(512, 256),
        nn.ReLU(),
        nn.Linear(256, 2)  # Output layer for binary classification
    )

    # Ensure the classifier remains trainable
    for param in model.heads.parameters():
        param.requires_grad = True
    
    # Move model to device
    model = model.to(device)
    return model

model = initialize_model()

# %%
# Function to count trainable and non-trainable parameters
def count_trainable_non_trainable_parameters(model):
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    non_trainable = sum(p.numel() for p in model.parameters() if not p.requires_grad)
    return trainable, non_trainable

# Count parameters in the transformer encoder (feature extractor)
encoder_trainable, encoder_non_trainable = count_trainable_non_trainable_parameters(model.encoder)
print(f"Transformer Encoder (Feature Extractor):\n"
      f"  Trainable parameters: {encoder_trainable:,}\n"
      f"  Non-trainable parameters: {encoder_non_trainable:,}")

# Count parameters in the classification head (custom classifier)
classifier_trainable, classifier_non_trainable = count_trainable_non_trainable_parameters(model.heads)
print(f"Classification Head:\n"
      f"  Trainable parameters: {classifier_trainable:,}\n"
      f"  Non-trainable parameters: {classifier_non_trainable:,}")

# Count parameters in the entire model
total_trainable, total_non_trainable = count_trainable_non_trainable_parameters(model)
print(f"Whole model:\n"
      f"  Trainable parameters: {total_trainable:,}\n"
      f"  Non-trainable parameters: {total_non_trainable:,}")
# Out:
# Transformer Encoder (Feature Extractor):
#   Trainable parameters: 0
#   Non-trainable parameters: 85,207,296
# Classification Head:
#   Trainable parameters: 525,570
#   Non-trainable parameters: 0
# Whole model:
#   Trainable parameters: 1,116,930
#   Non-trainable parameters: 85,207,296

# %%
# Early Stopping
class EarlyStopping:
    def __init__(self, patience, delta, path):
        """
        Args:
            patience (int): Number of epochs to wait after last improvement.
            delta (float): Minimum change in monitored metric to qualify as an improvement.
            path (str): Path to save the best model.
        """
        self.patience = patience
        self.delta = delta
        self.path = path
        self.counter = 0
        self.best_score = None
        self.early_stop = False

    def __call__(self, val_loss, model):
        score = -val_loss  # Early stopping is based on minimizing validation loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f"EarlyStopping counter: {self.counter} out of {self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        """Saves model when validation loss decreases."""
        print(f"Validation loss decreased. Saving model to {self.path}")
        torch.save(model.state_dict(), self.path)


# Set the path for saving best_model.pth
#current_dir = os.getcwd()
#model_save_path = os.path.join(current_dir, 'best_model2.pth')

# Initialize EarlyStopping
#early_stopping = EarlyStopping(patience=5, delta=0.001, path=model_save_path)

# %%
# Helper function to evaluate a dataset
def evaluate_model(model, data_loader, device):
    model.eval()  # Set model to evaluation mode
    all_labels = []
    all_preds = []
    all_probs = []

    with torch.no_grad():
        for images, labels in data_loader:
            images, labels = images.to(device), labels.to(device)

            # Forward pass
            outputs = model(images)
            probs = torch.softmax(outputs, dim=1)[:, 1]  # Probabilities for the positive class
            _, preds = torch.max(outputs, 1)

            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())

    return np.array(all_labels), np.array(all_preds), np.array(all_probs)

# Helper function to calculate selected metrics
def calculate_metrics(labels, preds, probs):
    accuracy = accuracy_score(labels, preds)
    precision = precision_score(labels, preds)
    recall = recall_score(labels, preds)
    f1 = f1_score(labels, preds)
    f2 = fbeta_score(labels, preds, beta=2)
    auc = roc_auc_score(labels, probs)
    specificity = recall_score(labels, preds, pos_label=0)
    npv = precision_score(labels, preds, pos_label=0)

    return recall, precision, accuracy, f1, f2, auc, specificity, npv

# %%
# Training loop with 5-fold cross-validation
cv_results = []
cv_metrics = []
n_splits = 5
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=123456)

# Extract labels from the dataset
labels = [label for _, label in full_dataset.samples]

# Cross-validation loop
for fold, (train_idx, val_idx) in enumerate(skf.split(np.zeros(len(labels)), labels), 1):
    print(f"\n========== Fold {fold} ==========\n")
    
    # Create training and validation subsets for this fold
    train_dataset = Subset(full_dataset, train_idx)
    val_dataset = Subset(full_dataset, val_idx)
    
    # Apply transformations
    train_dataset = TransformDataset(train_dataset, train_transform)
    val_dataset = TransformDataset(val_dataset, test_val_transform)
    
    # Create data loaders
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    
    # Initialize model and optimizer for each fold
    model = initialize_model()
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    # EarlyStopping initialization
    early_stopping = EarlyStopping(patience=10, delta=0.0001, path=os.path.join(os.getcwd(), f"{file_name}_fold_{fold}.pth"))

    # Training loop
    num_epochs = 100
    train_losses = []
    val_losses = []
    
    for epoch in range(num_epochs):
        # Training phase
        model.train()
        train_loss = 0
        train_correct = 0
        
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            
            # Forward pass
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            train_correct += torch.sum(preds == labels)
        
        train_loss /= len(train_loader)
        train_accuracy = train_correct.double() / len(train_dataset)
        train_losses.append(train_loss)
        
        # Validation phase
        model.eval()
        val_loss = 0
        val_correct = 0
        
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                
                outputs = model(images)
                loss = criterion(outputs, labels)
                
                val_loss += loss.item()
                _, preds = torch.max(outputs, 1)
                val_correct += torch.sum(preds == labels)
        
        val_loss /= len(val_loader)
        val_accuracy = val_correct.double() / len(val_dataset)
        val_losses.append(val_loss)
        
        print(f"Epoch {epoch + 1}/{num_epochs} | "
              f"Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.4f} | "
              f"Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.4f}")
        
        # Call EarlyStopping
        early_stopping(val_loss, model)
        if early_stopping.early_stop:
            print("Early stopping triggered. Ending training.")
            break
    
    # Store results for this fold
    cv_results.append({
        "fold": fold,
        "train_loss": train_loss,
        "train_accuracy": train_accuracy.item(),
        "val_loss": val_loss,
        "val_accuracy": val_accuracy.item()
        })
        
    # Load the best model for evaluation
    model.load_state_dict(torch.load(f"{file_name}_fold_{fold}.pth", weights_only=True))

    # Evaluate on validation set
    labels, preds, probs = evaluate_model(model, val_loader, device)
    metrics = calculate_metrics(labels, preds, probs)
    recall, precision, accuracy, f1, f2, auc, specificity, npv = metrics

    # Record metrics for the fold
    cv_metrics.append({
        "Fold": fold,
        "Recall": recall,
        "Precision": precision,
        "Accuracy": accuracy,
        "F1 Score": f1,
        "F2 Score": f2,
        "AUC": auc,
        "Specificity": specificity,
        "NPV": npv,
    })

# Summarize cross-validation results
df_cv_results = pd.DataFrame(cv_results)
print("\n========== Cross-Validation Results ==========\n")
print(df_cv_results)

print("\nAverage Validation Accuracy: {:.4f}".format(df_cv_results["val_accuracy"].mean()))
# Out:
# ========== Fold 1 ==========
#
# Epoch 1/100 | Train Loss: 0.6496, Train Acc: 0.6200 | Val Loss: 0.6330, Val Acc: 0.6060
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_1.pth
# Epoch 2/100 | Train Loss: 0.6050, Train Acc: 0.6628 | Val Loss: 0.5668, Val Acc: 0.6915
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_1.pth
# Epoch 3/100 | Train Loss: 0.5744, Train Acc: 0.6985 | Val Loss: 0.5790, Val Acc: 0.6885
# EarlyStopping counter: 1 out of 10
# Epoch 4/100 | Train Loss: 0.5652, Train Acc: 0.7023 | Val Loss: 0.5536, Val Acc: 0.7045
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_1.pth
# Epoch 5/100 | Train Loss: 0.5641, Train Acc: 0.7000 | Val Loss: 0.5387, Val Acc: 0.7160
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_1.pth
# Epoch 6/100 | Train Loss: 0.5583, Train Acc: 0.7056 | Val Loss: 0.5377, Val Acc: 0.7200
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_1.pth
# Epoch 7/100 | Train Loss: 0.5496, Train Acc: 0.7161 | Val Loss: 0.5362, Val Acc: 0.7100
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_1.pth
# Epoch 8/100 | Train Loss: 0.5538, Train Acc: 0.7156 | Val Loss: 0.5492, Val Acc: 0.7095
# EarlyStopping counter: 1 out of 10
# Epoch 9/100 | Train Loss: 0.5454, Train Acc: 0.7181 | Val Loss: 0.5254, Val Acc: 0.7235
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_1.pth
# Epoch 10/100 | Train Loss: 0.5432, Train Acc: 0.7245 | Val Loss: 0.5407, Val Acc: 0.7190
# EarlyStopping counter: 1 out of 10
# Epoch 11/100 | Train Loss: 0.5393, Train Acc: 0.7189 | Val Loss: 0.5627, Val Acc: 0.7235
# EarlyStopping counter: 2 out of 10
# Epoch 12/100 | Train Loss: 0.5407, Train Acc: 0.7219 | Val Loss: 0.5353, Val Acc: 0.7195
# EarlyStopping counter: 3 out of 10
# Epoch 13/100 | Train Loss: 0.5345, Train Acc: 0.7216 | Val Loss: 0.5338, Val Acc: 0.7185
# EarlyStopping counter: 4 out of 10
# Epoch 14/100 | Train Loss: 0.5320, Train Acc: 0.7306 | Val Loss: 0.5290, Val Acc: 0.7240
# EarlyStopping counter: 5 out of 10
# Epoch 15/100 | Train Loss: 0.5311, Train Acc: 0.7285 | Val Loss: 0.5459, Val Acc: 0.7115
# EarlyStopping counter: 6 out of 10
# Epoch 16/100 | Train Loss: 0.5333, Train Acc: 0.7245 | Val Loss: 0.5437, Val Acc: 0.7215
# EarlyStopping counter: 7 out of 10
# Epoch 17/100 | Train Loss: 0.5339, Train Acc: 0.7306 | Val Loss: 0.5281, Val Acc: 0.7335
# EarlyStopping counter: 8 out of 10
# Epoch 18/100 | Train Loss: 0.5293, Train Acc: 0.7289 | Val Loss: 0.5335, Val Acc: 0.7220
# EarlyStopping counter: 9 out of 10
# Epoch 19/100 | Train Loss: 0.5302, Train Acc: 0.7281 | Val Loss: 0.5366, Val Acc: 0.7270
# EarlyStopping counter: 10 out of 10
# Early stopping triggered. Ending training.
#
# ========== Fold 2 ==========
#
# Epoch 1/100 | Train Loss: 0.6542, Train Acc: 0.6120 | Val Loss: 0.6086, Val Acc: 0.6905
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_2.pth
# Epoch 2/100 | Train Loss: 0.5983, Train Acc: 0.6779 | Val Loss: 0.5545, Val Acc: 0.7095
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_2.pth
# Epoch 3/100 | Train Loss: 0.5780, Train Acc: 0.6913 | Val Loss: 0.5526, Val Acc: 0.7125
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_2.pth
# Epoch 4/100 | Train Loss: 0.5666, Train Acc: 0.6973 | Val Loss: 0.5336, Val Acc: 0.7205
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_2.pth
# Epoch 5/100 | Train Loss: 0.5628, Train Acc: 0.6986 | Val Loss: 0.5435, Val Acc: 0.7220
# EarlyStopping counter: 1 out of 10
# Epoch 6/100 | Train Loss: 0.5567, Train Acc: 0.7034 | Val Loss: 0.5521, Val Acc: 0.7040
# EarlyStopping counter: 2 out of 10
# Epoch 7/100 | Train Loss: 0.5542, Train Acc: 0.7067 | Val Loss: 0.5511, Val Acc: 0.6950
# EarlyStopping counter: 3 out of 10
# Epoch 8/100 | Train Loss: 0.5520, Train Acc: 0.7070 | Val Loss: 0.5394, Val Acc: 0.7295
# EarlyStopping counter: 4 out of 10
# Epoch 9/100 | Train Loss: 0.5474, Train Acc: 0.7114 | Val Loss: 0.5306, Val Acc: 0.7240
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_2.pth
# Epoch 10/100 | Train Loss: 0.5478, Train Acc: 0.7114 | Val Loss: 0.5272, Val Acc: 0.7325
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_2.pth
# Epoch 11/100 | Train Loss: 0.5460, Train Acc: 0.7177 | Val Loss: 0.5428, Val Acc: 0.7200
# EarlyStopping counter: 1 out of 10
# Epoch 12/100 | Train Loss: 0.5368, Train Acc: 0.7238 | Val Loss: 0.5254, Val Acc: 0.7275
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_2.pth
# Epoch 13/100 | Train Loss: 0.5359, Train Acc: 0.7244 | Val Loss: 0.5284, Val Acc: 0.7165
# EarlyStopping counter: 1 out of 10
# Epoch 14/100 | Train Loss: 0.5366, Train Acc: 0.7175 | Val Loss: 0.5341, Val Acc: 0.7280
# EarlyStopping counter: 2 out of 10
# Epoch 15/100 | Train Loss: 0.5389, Train Acc: 0.7175 | Val Loss: 0.5259, Val Acc: 0.7350
# EarlyStopping counter: 3 out of 10
# Epoch 16/100 | Train Loss: 0.5382, Train Acc: 0.7256 | Val Loss: 0.5185, Val Acc: 0.7405
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_2.pth
# Epoch 17/100 | Train Loss: 0.5336, Train Acc: 0.7259 | Val Loss: 0.5582, Val Acc: 0.6860
# EarlyStopping counter: 1 out of 10
# Epoch 18/100 | Train Loss: 0.5392, Train Acc: 0.7244 | Val Loss: 0.5173, Val Acc: 0.7290
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_2.pth
# Epoch 19/100 | Train Loss: 0.5345, Train Acc: 0.7215 | Val Loss: 0.5101, Val Acc: 0.7410
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_2.pth
# Epoch 20/100 | Train Loss: 0.5340, Train Acc: 0.7245 | Val Loss: 0.5221, Val Acc: 0.7245
# EarlyStopping counter: 1 out of 10
# Epoch 21/100 | Train Loss: 0.5261, Train Acc: 0.7308 | Val Loss: 0.5323, Val Acc: 0.7200
# EarlyStopping counter: 2 out of 10
# Epoch 22/100 | Train Loss: 0.5301, Train Acc: 0.7324 | Val Loss: 0.5271, Val Acc: 0.7310
# EarlyStopping counter: 3 out of 10
# Epoch 23/100 | Train Loss: 0.5277, Train Acc: 0.7265 | Val Loss: 0.5018, Val Acc: 0.7490
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_2.pth
# Epoch 24/100 | Train Loss: 0.5228, Train Acc: 0.7338 | Val Loss: 0.5189, Val Acc: 0.7280
# EarlyStopping counter: 1 out of 10
# Epoch 25/100 | Train Loss: 0.5257, Train Acc: 0.7291 | Val Loss: 0.5117, Val Acc: 0.7420
# EarlyStopping counter: 2 out of 10
# Epoch 26/100 | Train Loss: 0.5292, Train Acc: 0.7229 | Val Loss: 0.5147, Val Acc: 0.7440
# EarlyStopping counter: 3 out of 10
# Epoch 27/100 | Train Loss: 0.5253, Train Acc: 0.7306 | Val Loss: 0.5151, Val Acc: 0.7350
# EarlyStopping counter: 4 out of 10
# Epoch 28/100 | Train Loss: 0.5225, Train Acc: 0.7351 | Val Loss: 0.5095, Val Acc: 0.7440
# EarlyStopping counter: 5 out of 10
# Epoch 29/100 | Train Loss: 0.5263, Train Acc: 0.7338 | Val Loss: 0.5152, Val Acc: 0.7285
# EarlyStopping counter: 6 out of 10
# Epoch 30/100 | Train Loss: 0.5190, Train Acc: 0.7376 | Val Loss: 0.5127, Val Acc: 0.7355
# EarlyStopping counter: 7 out of 10
# Epoch 31/100 | Train Loss: 0.5242, Train Acc: 0.7354 | Val Loss: 0.5297, Val Acc: 0.7305
# EarlyStopping counter: 8 out of 10
# Epoch 32/100 | Train Loss: 0.5171, Train Acc: 0.7331 | Val Loss: 0.5019, Val Acc: 0.7365
# EarlyStopping counter: 9 out of 10
# Epoch 33/100 | Train Loss: 0.5206, Train Acc: 0.7328 | Val Loss: 0.5095, Val Acc: 0.7445
# EarlyStopping counter: 10 out of 10
# Early stopping triggered. Ending training.
#
# ========== Fold 3 ==========
#
# Epoch 1/100 | Train Loss: 0.6529, Train Acc: 0.6179 | Val Loss: 0.6224, Val Acc: 0.6420
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_3.pth
# Epoch 2/100 | Train Loss: 0.5983, Train Acc: 0.6754 | Val Loss: 0.6119, Val Acc: 0.6595
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_3.pth
# Epoch 3/100 | Train Loss: 0.5745, Train Acc: 0.6946 | Val Loss: 0.5623, Val Acc: 0.7010
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_3.pth
# Epoch 4/100 | Train Loss: 0.5639, Train Acc: 0.6930 | Val Loss: 0.5605, Val Acc: 0.7060
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_3.pth
# Epoch 5/100 | Train Loss: 0.5623, Train Acc: 0.7083 | Val Loss: 0.5686, Val Acc: 0.6970
# EarlyStopping counter: 1 out of 10
# Epoch 6/100 | Train Loss: 0.5521, Train Acc: 0.7097 | Val Loss: 0.5666, Val Acc: 0.7015
# EarlyStopping counter: 2 out of 10
# Epoch 7/100 | Train Loss: 0.5441, Train Acc: 0.7137 | Val Loss: 0.5492, Val Acc: 0.7210
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_3.pth
# Epoch 8/100 | Train Loss: 0.5408, Train Acc: 0.7149 | Val Loss: 0.5575, Val Acc: 0.6995
# EarlyStopping counter: 1 out of 10
# Epoch 9/100 | Train Loss: 0.5403, Train Acc: 0.7169 | Val Loss: 0.5515, Val Acc: 0.7105
# EarlyStopping counter: 2 out of 10
# Epoch 10/100 | Train Loss: 0.5368, Train Acc: 0.7205 | Val Loss: 0.5515, Val Acc: 0.7225
# EarlyStopping counter: 3 out of 10
# Epoch 11/100 | Train Loss: 0.5348, Train Acc: 0.7130 | Val Loss: 0.5572, Val Acc: 0.7015
# EarlyStopping counter: 4 out of 10
# Epoch 12/100 | Train Loss: 0.5288, Train Acc: 0.7256 | Val Loss: 0.5504, Val Acc: 0.7050
# EarlyStopping counter: 5 out of 10
# Epoch 13/100 | Train Loss: 0.5351, Train Acc: 0.7170 | Val Loss: 0.5641, Val Acc: 0.6990
# EarlyStopping counter: 6 out of 10
# Epoch 14/100 | Train Loss: 0.5351, Train Acc: 0.7239 | Val Loss: 0.5627, Val Acc: 0.7080
# EarlyStopping counter: 7 out of 10
# Epoch 15/100 | Train Loss: 0.5313, Train Acc: 0.7290 | Val Loss: 0.5529, Val Acc: 0.7175
# EarlyStopping counter: 8 out of 10
# Epoch 16/100 | Train Loss: 0.5288, Train Acc: 0.7254 | Val Loss: 0.5517, Val Acc: 0.7085
# EarlyStopping counter: 9 out of 10
# Epoch 17/100 | Train Loss: 0.5340, Train Acc: 0.7235 | Val Loss: 0.5498, Val Acc: 0.7185
# EarlyStopping counter: 10 out of 10
# Early stopping triggered. Ending training.
#
# ========== Fold 4 ==========
#
# Epoch 1/100 | Train Loss: 0.6419, Train Acc: 0.6288 | Val Loss: 0.5792, Val Acc: 0.6970
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_4.pth
# Epoch 2/100 | Train Loss: 0.5902, Train Acc: 0.6794 | Val Loss: 0.5419, Val Acc: 0.7070
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_4.pth
# Epoch 3/100 | Train Loss: 0.5761, Train Acc: 0.6901 | Val Loss: 0.6074, Val Acc: 0.6905
# EarlyStopping counter: 1 out of 10
# Epoch 4/100 | Train Loss: 0.5660, Train Acc: 0.7021 | Val Loss: 0.5732, Val Acc: 0.6960
# EarlyStopping counter: 2 out of 10
# Epoch 5/100 | Train Loss: 0.5564, Train Acc: 0.7070 | Val Loss: 0.5476, Val Acc: 0.7125
# EarlyStopping counter: 3 out of 10
# Epoch 6/100 | Train Loss: 0.5564, Train Acc: 0.7054 | Val Loss: 0.5490, Val Acc: 0.7065
# EarlyStopping counter: 4 out of 10
# Epoch 7/100 | Train Loss: 0.5451, Train Acc: 0.7120 | Val Loss: 0.5368, Val Acc: 0.7175
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_4.pth
# Epoch 8/100 | Train Loss: 0.5499, Train Acc: 0.7143 | Val Loss: 0.5286, Val Acc: 0.7250
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_4.pth
# Epoch 9/100 | Train Loss: 0.5443, Train Acc: 0.7205 | Val Loss: 0.5317, Val Acc: 0.7215
# EarlyStopping counter: 1 out of 10
# Epoch 10/100 | Train Loss: 0.5417, Train Acc: 0.7199 | Val Loss: 0.5302, Val Acc: 0.7270
# EarlyStopping counter: 2 out of 10
# Epoch 11/100 | Train Loss: 0.5366, Train Acc: 0.7210 | Val Loss: 0.5372, Val Acc: 0.7215
# EarlyStopping counter: 3 out of 10
# Epoch 12/100 | Train Loss: 0.5453, Train Acc: 0.7135 | Val Loss: 0.5315, Val Acc: 0.7310
# EarlyStopping counter: 4 out of 10
# Epoch 13/100 | Train Loss: 0.5341, Train Acc: 0.7259 | Val Loss: 0.5359, Val Acc: 0.7200
# EarlyStopping counter: 5 out of 10
# Epoch 14/100 | Train Loss: 0.5348, Train Acc: 0.7226 | Val Loss: 0.5469, Val Acc: 0.7250
# EarlyStopping counter: 6 out of 10
# Epoch 15/100 | Train Loss: 0.5308, Train Acc: 0.7271 | Val Loss: 0.5329, Val Acc: 0.7240
# EarlyStopping counter: 7 out of 10
# Epoch 16/100 | Train Loss: 0.5303, Train Acc: 0.7266 | Val Loss: 0.5312, Val Acc: 0.7240
# EarlyStopping counter: 8 out of 10
# Epoch 17/100 | Train Loss: 0.5278, Train Acc: 0.7323 | Val Loss: 0.5265, Val Acc: 0.7285
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_4.pth
# Epoch 18/100 | Train Loss: 0.5307, Train Acc: 0.7250 | Val Loss: 0.5283, Val Acc: 0.7350
# EarlyStopping counter: 1 out of 10
# Epoch 19/100 | Train Loss: 0.5274, Train Acc: 0.7299 | Val Loss: 0.5252, Val Acc: 0.7395
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_4.pth
# Epoch 20/100 | Train Loss: 0.5288, Train Acc: 0.7275 | Val Loss: 0.5392, Val Acc: 0.7190
# EarlyStopping counter: 1 out of 10
# Epoch 21/100 | Train Loss: 0.5269, Train Acc: 0.7333 | Val Loss: 0.5231, Val Acc: 0.7335
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_4.pth
# Epoch 22/100 | Train Loss: 0.5253, Train Acc: 0.7301 | Val Loss: 0.5248, Val Acc: 0.7375
# EarlyStopping counter: 1 out of 10
# Epoch 23/100 | Train Loss: 0.5227, Train Acc: 0.7341 | Val Loss: 0.5125, Val Acc: 0.7425
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_4.pth
# Epoch 24/100 | Train Loss: 0.5194, Train Acc: 0.7404 | Val Loss: 0.5138, Val Acc: 0.7380
# EarlyStopping counter: 1 out of 10
# Epoch 25/100 | Train Loss: 0.5214, Train Acc: 0.7274 | Val Loss: 0.5167, Val Acc: 0.7375
# EarlyStopping counter: 2 out of 10
# Epoch 26/100 | Train Loss: 0.5205, Train Acc: 0.7329 | Val Loss: 0.5279, Val Acc: 0.7235
# EarlyStopping counter: 3 out of 10
# Epoch 27/100 | Train Loss: 0.5175, Train Acc: 0.7375 | Val Loss: 0.5154, Val Acc: 0.7500
# EarlyStopping counter: 4 out of 10
# Epoch 28/100 | Train Loss: 0.5141, Train Acc: 0.7391 | Val Loss: 0.5309, Val Acc: 0.7280
# EarlyStopping counter: 5 out of 10
# Epoch 29/100 | Train Loss: 0.5241, Train Acc: 0.7300 | Val Loss: 0.5162, Val Acc: 0.7365
# EarlyStopping counter: 6 out of 10
# Epoch 30/100 | Train Loss: 0.5117, Train Acc: 0.7408 | Val Loss: 0.5079, Val Acc: 0.7485
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_4.pth
# Epoch 31/100 | Train Loss: 0.5120, Train Acc: 0.7405 | Val Loss: 0.5269, Val Acc: 0.7440
# EarlyStopping counter: 1 out of 10
# Epoch 32/100 | Train Loss: 0.5131, Train Acc: 0.7419 | Val Loss: 0.5497, Val Acc: 0.7165
# EarlyStopping counter: 2 out of 10
# Epoch 33/100 | Train Loss: 0.5140, Train Acc: 0.7349 | Val Loss: 0.5345, Val Acc: 0.7170
# EarlyStopping counter: 3 out of 10
# Epoch 34/100 | Train Loss: 0.5115, Train Acc: 0.7409 | Val Loss: 0.5051, Val Acc: 0.7470
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_4.pth
# Epoch 35/100 | Train Loss: 0.5123, Train Acc: 0.7412 | Val Loss: 0.5065, Val Acc: 0.7415
# EarlyStopping counter: 1 out of 10
# Epoch 36/100 | Train Loss: 0.5123, Train Acc: 0.7411 | Val Loss: 0.5086, Val Acc: 0.7490
# EarlyStopping counter: 2 out of 10
# Epoch 37/100 | Train Loss: 0.5106, Train Acc: 0.7385 | Val Loss: 0.5341, Val Acc: 0.7245
# EarlyStopping counter: 3 out of 10
# Epoch 38/100 | Train Loss: 0.5074, Train Acc: 0.7462 | Val Loss: 0.5095, Val Acc: 0.7510
# EarlyStopping counter: 4 out of 10
# Epoch 39/100 | Train Loss: 0.5086, Train Acc: 0.7475 | Val Loss: 0.5135, Val Acc: 0.7425
# EarlyStopping counter: 5 out of 10
# Epoch 40/100 | Train Loss: 0.5071, Train Acc: 0.7408 | Val Loss: 0.5027, Val Acc: 0.7450
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_4.pth
# Epoch 41/100 | Train Loss: 0.5169, Train Acc: 0.7344 | Val Loss: 0.5127, Val Acc: 0.7435
# EarlyStopping counter: 1 out of 10
# Epoch 42/100 | Train Loss: 0.5075, Train Acc: 0.7440 | Val Loss: 0.5195, Val Acc: 0.7470
# EarlyStopping counter: 2 out of 10
# Epoch 43/100 | Train Loss: 0.5044, Train Acc: 0.7466 | Val Loss: 0.5097, Val Acc: 0.7420
# EarlyStopping counter: 3 out of 10
# Epoch 44/100 | Train Loss: 0.5027, Train Acc: 0.7448 | Val Loss: 0.5051, Val Acc: 0.7435
# EarlyStopping counter: 4 out of 10
# Epoch 45/100 | Train Loss: 0.5022, Train Acc: 0.7479 | Val Loss: 0.5011, Val Acc: 0.7510
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_4.pth
# Epoch 46/100 | Train Loss: 0.5032, Train Acc: 0.7462 | Val Loss: 0.5073, Val Acc: 0.7415
# EarlyStopping counter: 1 out of 10
# Epoch 47/100 | Train Loss: 0.5051, Train Acc: 0.7446 | Val Loss: 0.5265, Val Acc: 0.7430
# EarlyStopping counter: 2 out of 10
# Epoch 48/100 | Train Loss: 0.5092, Train Acc: 0.7365 | Val Loss: 0.4993, Val Acc: 0.7495
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_4.pth
# Epoch 49/100 | Train Loss: 0.5045, Train Acc: 0.7504 | Val Loss: 0.4988, Val Acc: 0.7540
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_4.pth
# Epoch 50/100 | Train Loss: 0.5057, Train Acc: 0.7464 | Val Loss: 0.5088, Val Acc: 0.7420
# EarlyStopping counter: 1 out of 10
# Epoch 51/100 | Train Loss: 0.5014, Train Acc: 0.7460 | Val Loss: 0.4987, Val Acc: 0.7480
# EarlyStopping counter: 2 out of 10
# Epoch 52/100 | Train Loss: 0.5063, Train Acc: 0.7431 | Val Loss: 0.4934, Val Acc: 0.7540
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_4.pth
# Epoch 53/100 | Train Loss: 0.4981, Train Acc: 0.7525 | Val Loss: 0.5061, Val Acc: 0.7565
# EarlyStopping counter: 1 out of 10
# Epoch 54/100 | Train Loss: 0.4965, Train Acc: 0.7501 | Val Loss: 0.5170, Val Acc: 0.7405
# EarlyStopping counter: 2 out of 10
# Epoch 55/100 | Train Loss: 0.5021, Train Acc: 0.7404 | Val Loss: 0.4982, Val Acc: 0.7560
# EarlyStopping counter: 3 out of 10
# Epoch 56/100 | Train Loss: 0.4987, Train Acc: 0.7464 | Val Loss: 0.5189, Val Acc: 0.7475
# EarlyStopping counter: 4 out of 10
# Epoch 57/100 | Train Loss: 0.4991, Train Acc: 0.7495 | Val Loss: 0.5056, Val Acc: 0.7505
# EarlyStopping counter: 5 out of 10
# Epoch 58/100 | Train Loss: 0.4930, Train Acc: 0.7532 | Val Loss: 0.5102, Val Acc: 0.7500
# EarlyStopping counter: 6 out of 10
# Epoch 59/100 | Train Loss: 0.5007, Train Acc: 0.7485 | Val Loss: 0.5024, Val Acc: 0.7515
# EarlyStopping counter: 7 out of 10
# Epoch 60/100 | Train Loss: 0.4910, Train Acc: 0.7564 | Val Loss: 0.4968, Val Acc: 0.7555
# EarlyStopping counter: 8 out of 10
# Epoch 61/100 | Train Loss: 0.4987, Train Acc: 0.7468 | Val Loss: 0.4981, Val Acc: 0.7575
# EarlyStopping counter: 9 out of 10
# Epoch 62/100 | Train Loss: 0.4980, Train Acc: 0.7519 | Val Loss: 0.4906, Val Acc: 0.7580
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_4.pth
# Epoch 63/100 | Train Loss: 0.4897, Train Acc: 0.7564 | Val Loss: 0.5009, Val Acc: 0.7560
# EarlyStopping counter: 1 out of 10
# Epoch 64/100 | Train Loss: 0.4910, Train Acc: 0.7518 | Val Loss: 0.5006, Val Acc: 0.7580
# EarlyStopping counter: 2 out of 10
# Epoch 65/100 | Train Loss: 0.5022, Train Acc: 0.7520 | Val Loss: 0.5163, Val Acc: 0.7355
# EarlyStopping counter: 3 out of 10
# Epoch 66/100 | Train Loss: 0.4872, Train Acc: 0.7561 | Val Loss: 0.4954, Val Acc: 0.7535
# EarlyStopping counter: 4 out of 10
# Epoch 67/100 | Train Loss: 0.4919, Train Acc: 0.7525 | Val Loss: 0.4913, Val Acc: 0.7555
# EarlyStopping counter: 5 out of 10
# Epoch 68/100 | Train Loss: 0.4980, Train Acc: 0.7486 | Val Loss: 0.4915, Val Acc: 0.7555
# EarlyStopping counter: 6 out of 10
# Epoch 69/100 | Train Loss: 0.4861, Train Acc: 0.7579 | Val Loss: 0.4967, Val Acc: 0.7530
# EarlyStopping counter: 7 out of 10
# Epoch 70/100 | Train Loss: 0.4907, Train Acc: 0.7582 | Val Loss: 0.4990, Val Acc: 0.7500
# EarlyStopping counter: 8 out of 10
# Epoch 71/100 | Train Loss: 0.4903, Train Acc: 0.7555 | Val Loss: 0.4921, Val Acc: 0.7595
# EarlyStopping counter: 9 out of 10
# Epoch 72/100 | Train Loss: 0.4864, Train Acc: 0.7570 | Val Loss: 0.4929, Val Acc: 0.7535
# EarlyStopping counter: 10 out of 10
# Early stopping triggered. Ending training.
#
# ========== Fold 5 ==========
#
# Epoch 1/100 | Train Loss: 0.6441, Train Acc: 0.6170 | Val Loss: 0.6026, Val Acc: 0.6595
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_5.pth
# Epoch 2/100 | Train Loss: 0.5964, Train Acc: 0.6804 | Val Loss: 0.5551, Val Acc: 0.6865
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_5.pth
# Epoch 3/100 | Train Loss: 0.5890, Train Acc: 0.6789 | Val Loss: 0.5542, Val Acc: 0.7000
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_5.pth
# Epoch 4/100 | Train Loss: 0.5769, Train Acc: 0.6845 | Val Loss: 0.5446, Val Acc: 0.7050
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_5.pth
# Epoch 5/100 | Train Loss: 0.5635, Train Acc: 0.7081 | Val Loss: 0.5430, Val Acc: 0.7060
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_5.pth
# Epoch 6/100 | Train Loss: 0.5614, Train Acc: 0.7040 | Val Loss: 0.5419, Val Acc: 0.7160
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_5.pth
# Epoch 7/100 | Train Loss: 0.5602, Train Acc: 0.7007 | Val Loss: 0.5608, Val Acc: 0.7060
# EarlyStopping counter: 1 out of 10
# Epoch 8/100 | Train Loss: 0.5589, Train Acc: 0.7045 | Val Loss: 0.5311, Val Acc: 0.7130
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_5.pth
# Epoch 9/100 | Train Loss: 0.5503, Train Acc: 0.7089 | Val Loss: 0.5299, Val Acc: 0.7220
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_5.pth
# Epoch 10/100 | Train Loss: 0.5450, Train Acc: 0.7154 | Val Loss: 0.5289, Val Acc: 0.7185
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_5.pth
# Epoch 11/100 | Train Loss: 0.5523, Train Acc: 0.7083 | Val Loss: 0.5336, Val Acc: 0.7145
# EarlyStopping counter: 1 out of 10
# Epoch 12/100 | Train Loss: 0.5366, Train Acc: 0.7286 | Val Loss: 0.5489, Val Acc: 0.7020
# EarlyStopping counter: 2 out of 10
# Epoch 13/100 | Train Loss: 0.5475, Train Acc: 0.7203 | Val Loss: 0.5277, Val Acc: 0.7235
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_5.pth
# Epoch 14/100 | Train Loss: 0.5437, Train Acc: 0.7226 | Val Loss: 0.5209, Val Acc: 0.7245
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_5.pth
# Epoch 15/100 | Train Loss: 0.5370, Train Acc: 0.7234 | Val Loss: 0.5238, Val Acc: 0.7290
# EarlyStopping counter: 1 out of 10
# Epoch 16/100 | Train Loss: 0.5399, Train Acc: 0.7246 | Val Loss: 0.5255, Val Acc: 0.7245
# EarlyStopping counter: 2 out of 10
# Epoch 17/100 | Train Loss: 0.5361, Train Acc: 0.7231 | Val Loss: 0.5137, Val Acc: 0.7300
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_5.pth
# Epoch 18/100 | Train Loss: 0.5303, Train Acc: 0.7261 | Val Loss: 0.5193, Val Acc: 0.7340
# EarlyStopping counter: 1 out of 10
# Epoch 19/100 | Train Loss: 0.5336, Train Acc: 0.7229 | Val Loss: 0.5138, Val Acc: 0.7295
# EarlyStopping counter: 2 out of 10
# Epoch 20/100 | Train Loss: 0.5282, Train Acc: 0.7333 | Val Loss: 0.5171, Val Acc: 0.7360
# EarlyStopping counter: 3 out of 10
# Epoch 21/100 | Train Loss: 0.5288, Train Acc: 0.7368 | Val Loss: 0.5188, Val Acc: 0.7270
# EarlyStopping counter: 4 out of 10
# Epoch 22/100 | Train Loss: 0.5307, Train Acc: 0.7320 | Val Loss: 0.5205, Val Acc: 0.7360
# EarlyStopping counter: 5 out of 10
# Epoch 23/100 | Train Loss: 0.5271, Train Acc: 0.7324 | Val Loss: 0.5189, Val Acc: 0.7340
# EarlyStopping counter: 6 out of 10
# Epoch 24/100 | Train Loss: 0.5389, Train Acc: 0.7204 | Val Loss: 0.5424, Val Acc: 0.7075
# EarlyStopping counter: 7 out of 10
# Epoch 25/100 | Train Loss: 0.5351, Train Acc: 0.7280 | Val Loss: 0.5165, Val Acc: 0.7305
# EarlyStopping counter: 8 out of 10
# Epoch 26/100 | Train Loss: 0.5229, Train Acc: 0.7345 | Val Loss: 0.5101, Val Acc: 0.7355
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_5.pth
# Epoch 27/100 | Train Loss: 0.5221, Train Acc: 0.7386 | Val Loss: 0.5242, Val Acc: 0.7230
# EarlyStopping counter: 1 out of 10
# Epoch 28/100 | Train Loss: 0.5228, Train Acc: 0.7362 | Val Loss: 0.5204, Val Acc: 0.7340
# EarlyStopping counter: 2 out of 10
# Epoch 29/100 | Train Loss: 0.5219, Train Acc: 0.7362 | Val Loss: 0.5149, Val Acc: 0.7335
# EarlyStopping counter: 3 out of 10
# Epoch 30/100 | Train Loss: 0.5206, Train Acc: 0.7378 | Val Loss: 0.5102, Val Acc: 0.7390
# EarlyStopping counter: 4 out of 10
# Epoch 31/100 | Train Loss: 0.5225, Train Acc: 0.7398 | Val Loss: 0.5061, Val Acc: 0.7420
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_5.pth
# Epoch 32/100 | Train Loss: 0.5190, Train Acc: 0.7331 | Val Loss: 0.5066, Val Acc: 0.7420
# EarlyStopping counter: 1 out of 10
# Epoch 33/100 | Train Loss: 0.5205, Train Acc: 0.7365 | Val Loss: 0.5048, Val Acc: 0.7405
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_5.pth
# Epoch 34/100 | Train Loss: 0.5178, Train Acc: 0.7365 | Val Loss: 0.4998, Val Acc: 0.7445
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_5.pth
# Epoch 35/100 | Train Loss: 0.5158, Train Acc: 0.7435 | Val Loss: 0.5035, Val Acc: 0.7415
# EarlyStopping counter: 1 out of 10
# Epoch 36/100 | Train Loss: 0.5154, Train Acc: 0.7426 | Val Loss: 0.5074, Val Acc: 0.7330
# EarlyStopping counter: 2 out of 10
# Epoch 37/100 | Train Loss: 0.5147, Train Acc: 0.7422 | Val Loss: 0.5012, Val Acc: 0.7460
# EarlyStopping counter: 3 out of 10
# Epoch 38/100 | Train Loss: 0.5152, Train Acc: 0.7418 | Val Loss: 0.5059, Val Acc: 0.7400
# EarlyStopping counter: 4 out of 10
# Epoch 39/100 | Train Loss: 0.5162, Train Acc: 0.7386 | Val Loss: 0.4977, Val Acc: 0.7435
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_5.pth
# Epoch 40/100 | Train Loss: 0.5143, Train Acc: 0.7372 | Val Loss: 0.5065, Val Acc: 0.7430
# EarlyStopping counter: 1 out of 10
# Epoch 41/100 | Train Loss: 0.5066, Train Acc: 0.7460 | Val Loss: 0.5063, Val Acc: 0.7410
# EarlyStopping counter: 2 out of 10
# Epoch 42/100 | Train Loss: 0.5129, Train Acc: 0.7384 | Val Loss: 0.5023, Val Acc: 0.7380
# EarlyStopping counter: 3 out of 10
# Epoch 43/100 | Train Loss: 0.5096, Train Acc: 0.7432 | Val Loss: 0.4981, Val Acc: 0.7425
# EarlyStopping counter: 4 out of 10
# Epoch 44/100 | Train Loss: 0.5063, Train Acc: 0.7491 | Val Loss: 0.5089, Val Acc: 0.7435
# EarlyStopping counter: 5 out of 10
# Epoch 45/100 | Train Loss: 0.5072, Train Acc: 0.7426 | Val Loss: 0.5242, Val Acc: 0.7325
# EarlyStopping counter: 6 out of 10
# Epoch 46/100 | Train Loss: 0.5052, Train Acc: 0.7482 | Val Loss: 0.5003, Val Acc: 0.7395
# EarlyStopping counter: 7 out of 10
# Epoch 47/100 | Train Loss: 0.5110, Train Acc: 0.7425 | Val Loss: 0.5219, Val Acc: 0.7320
# EarlyStopping counter: 8 out of 10
# Epoch 48/100 | Train Loss: 0.5067, Train Acc: 0.7471 | Val Loss: 0.4981, Val Acc: 0.7510
# EarlyStopping counter: 9 out of 10
# Epoch 49/100 | Train Loss: 0.5037, Train Acc: 0.7509 | Val Loss: 0.4970, Val Acc: 0.7540
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_5.pth
# Epoch 50/100 | Train Loss: 0.5074, Train Acc: 0.7472 | Val Loss: 0.4936, Val Acc: 0.7375
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_5.pth
# Epoch 51/100 | Train Loss: 0.5014, Train Acc: 0.7500 | Val Loss: 0.5110, Val Acc: 0.7305
# EarlyStopping counter: 1 out of 10
# Epoch 52/100 | Train Loss: 0.5022, Train Acc: 0.7471 | Val Loss: 0.5019, Val Acc: 0.7445
# EarlyStopping counter: 2 out of 10
# Epoch 53/100 | Train Loss: 0.5041, Train Acc: 0.7485 | Val Loss: 0.4961, Val Acc: 0.7440
# EarlyStopping counter: 3 out of 10
# Epoch 54/100 | Train Loss: 0.4977, Train Acc: 0.7552 | Val Loss: 0.4908, Val Acc: 0.7555
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_5.pth
# Epoch 55/100 | Train Loss: 0.4987, Train Acc: 0.7501 | Val Loss: 0.4913, Val Acc: 0.7455
# EarlyStopping counter: 1 out of 10
# Epoch 56/100 | Train Loss: 0.5008, Train Acc: 0.7570 | Val Loss: 0.4893, Val Acc: 0.7475
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_5.pth
# Epoch 57/100 | Train Loss: 0.4998, Train Acc: 0.7525 | Val Loss: 0.4933, Val Acc: 0.7535
# EarlyStopping counter: 1 out of 10
# Epoch 58/100 | Train Loss: 0.5021, Train Acc: 0.7536 | Val Loss: 0.4958, Val Acc: 0.7425
# EarlyStopping counter: 2 out of 10
# Epoch 59/100 | Train Loss: 0.4983, Train Acc: 0.7479 | Val Loss: 0.4931, Val Acc: 0.7475
# EarlyStopping counter: 3 out of 10
# Epoch 60/100 | Train Loss: 0.5023, Train Acc: 0.7516 | Val Loss: 0.4948, Val Acc: 0.7485
# EarlyStopping counter: 4 out of 10
# Epoch 61/100 | Train Loss: 0.4982, Train Acc: 0.7499 | Val Loss: 0.4955, Val Acc: 0.7470
# EarlyStopping counter: 5 out of 10
# Epoch 62/100 | Train Loss: 0.4989, Train Acc: 0.7568 | Val Loss: 0.4913, Val Acc: 0.7540
# EarlyStopping counter: 6 out of 10
# Epoch 63/100 | Train Loss: 0.4960, Train Acc: 0.7572 | Val Loss: 0.4908, Val Acc: 0.7580
# EarlyStopping counter: 7 out of 10
# Epoch 64/100 | Train Loss: 0.5018, Train Acc: 0.7501 | Val Loss: 0.4899, Val Acc: 0.7565
# EarlyStopping counter: 8 out of 10
# Epoch 65/100 | Train Loss: 0.4956, Train Acc: 0.7494 | Val Loss: 0.4871, Val Acc: 0.7490
# Validation loss decreased. Saving model to /home/pxk409/Skin_EfficientNet/Benchmark_VisionTransformer_CV_fold_5.pth
# Epoch 66/100 | Train Loss: 0.4987, Train Acc: 0.7486 | Val Loss: 0.4937, Val Acc: 0.7460
# EarlyStopping counter: 1 out of 10
# Epoch 67/100 | Train Loss: 0.4965, Train Acc: 0.7526 | Val Loss: 0.4976, Val Acc: 0.7445
# EarlyStopping counter: 2 out of 10
# Epoch 68/100 | Train Loss: 0.4954, Train Acc: 0.7515 | Val Loss: 0.4971, Val Acc: 0.7445
# EarlyStopping counter: 3 out of 10
# Epoch 69/100 | Train Loss: 0.4948, Train Acc: 0.7541 | Val Loss: 0.5011, Val Acc: 0.7485
# EarlyStopping counter: 4 out of 10
# Epoch 70/100 | Train Loss: 0.4933, Train Acc: 0.7554 | Val Loss: 0.4957, Val Acc: 0.7450
# EarlyStopping counter: 5 out of 10
# Epoch 71/100 | Train Loss: 0.4879, Train Acc: 0.7589 | Val Loss: 0.5410, Val Acc: 0.7185
# EarlyStopping counter: 6 out of 10
# Epoch 72/100 | Train Loss: 0.4990, Train Acc: 0.7515 | Val Loss: 0.4946, Val Acc: 0.7515
# EarlyStopping counter: 7 out of 10
# Epoch 73/100 | Train Loss: 0.4950, Train Acc: 0.7508 | Val Loss: 0.4965, Val Acc: 0.7485
# EarlyStopping counter: 8 out of 10
# Epoch 74/100 | Train Loss: 0.4936, Train Acc: 0.7534 | Val Loss: 0.4894, Val Acc: 0.7565
# EarlyStopping counter: 9 out of 10
# Epoch 75/100 | Train Loss: 0.4988, Train Acc: 0.7538 | Val Loss: 0.4919, Val Acc: 0.7565
# EarlyStopping counter: 10 out of 10
# Early stopping triggered. Ending training.
#
# ========== Cross-Validation Results ==========
#
#    fold  train_loss  train_accuracy  val_loss  val_accuracy
# 0     1    0.530210        0.728125  0.536589        0.7270
# 1     2    0.520552        0.732750  0.509467        0.7445
# 2     3    0.533967        0.723500  0.549814        0.7185
# 3     4    0.486369        0.757000  0.492881        0.7535
# 4     5    0.498790        0.753750  0.491932        0.7565
#
# Average Validation Accuracy: 0.7400

# %%
# Convert results to DataFrame
cv_metrics_df = pd.DataFrame(cv_metrics)

# Calculate average metrics
avg_metrics = cv_metrics_df.mean().to_dict()
avg_metrics["Fold"] = "Average"

# Add the average metrics to the DataFrame
cv_metrics_df = cv_metrics_df.append(avg_metrics, ignore_index=True)

# Save results to CSV file
csv_file_name = f"CV_Results/{file_name}.csv"
cv_metrics_df.to_csv(csv_file_name, index=False)

print(f"Cross-validation metrics saved to {csv_file_name}")
# Out:
# /tmp/job.2295410.hpc/ipykernel_4175814/1908723448.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cv_metrics_df = cv_metrics_df.append(avg_metrics, ignore_index=True)
# Cross-validation metrics saved to CV_Results/Benchmark_VisionTransformer_CV.csv
